# %%
#To improve, add key word cross validation! 
# To improve, add papers that cite the original paper to create the author corpus!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Bio import Entrez
from Bio import Medline

# %matplotlib inline

# %%
Entrez.email = "ajwright@gmail.com"
Entrez.api_key = "86ac8038bfc913213f007df2803127ebc908"

# %%
def user_entered_info():
    """Stores user-provided scientist name and affiliation.
    
    Arguments:
    none
    
    Returns:
    name - str; scientist name in the format "firstname middleinit lastname"
    affiliation - str; scientist's institutional affiliation
    """
    print("Type the answer to each question then press return.  If you do not know the answer, just hit return.")
    first_name = input("What is the first name of the scientist of interest? ")
    middle_name = input("What is the middle initial of the scientist of interest? ")
    try:
        middle_initial = middle_name[0]
    except IndexError:
        middle_initial = ""
    last_name = input("What is the last name of the scientist of interest? ")
    affliation = input("What is the affiliation of the scientist of interest? No abbreviations, please. ")
    name = "{0} {1} {2}".format(first_name.lower(), middle_initial.lower(), last_name.lower())
    return name, affliation

# %%
name, affiliation = user_entered_info()
# Out:
# Type the answer to each question then press return.  If you do not know the answer, just hit return.
# What is the first name of the scientist of interest? Carolyn
# What is the middle initial of the scientist of interest? G
# What is the last name of the scientist of interest? Rasmussen
# What is the affliation of the scientist of interest? No abbreviations please. University of California Riverside

# %%
print(name, affiliation)
# Out:
# carolyn g rasmussen University of California Riverside

# %%
# Given a scientist's name and optional affliation, retrive a list of their papers from pubmed

# package as a dictionary?
def get_scientist_papers(name, affiliation=None):
    """Search PubMed for papers whose author list and affiliation list contain the provided author name and
    affiliation. 
    
    Arguments:
    name - str; complete scientist name in the format "lastname, firstname middleinitial"
    affiliation (optional) - str
    
    Returns:
    ids - list; list of paper IDs
    webenv - str; used to reference cached NCBI search session in future efetch queries
    query_key - str; used to reference cached NCBI search session in future efetch queries
    """
    if affiliation == None:
        handle = Entrez.esearch(db='pubmed', term=name, retmax=200, usehistory="y")
    else: 
        terms = "{} AND {}".format(name, affiliation)
        handle = Entrez.esearch(db='pubmed', term=terms, retmax=200, usehistory="y")
    record = Entrez.read(handle)
    ids = record['IdList']
    webenv = record["WebEnv"]
    query_key = record["QueryKey"]
    return ids, webenv, query_key

# %%
id_list, webenv, query_key = get_scientist_papers(name, affiliation)

# %%
# Allow the user to select up to 3 papers by the scientist

# need to return the number of references as well! 

# To do:  write a new function that returns a citation and use it in this function 

def user_selected_papers(id_list, webenv, query_key):
    """Allows the user to select up to 3 papers authored by a scientist of interest. Uses NCBI cached search
    history.
    
    Arguments:  
    id_list - list; paper ids
    webenv - str; used to reference cached NCBI search session in efetch queries
    query_key - str; used to reference cached NCBI search session in efetch queries
    
    Returns 
    select_list - list; paper ids of user selected papers
    """ 
    from Bio import Medline
    print("Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
    handle = Entrez.efetch(db="pubmed", id=id_list, rettype='medline', retmode='text', webenv=webenv, query_key=query_key)
    records = Medline.parse(handle)
    for index, record in enumerate(records, 1):
        print("{}. {} {}. {}. {}. ({})".format(index, record.get("TI", "?"), record.get("AU", "?"), record.get("JT", "?"),
                                         record.get("DP", "?"), record.get("PMID", "?")))
    paper_num = input("Which papers would you like to select? ")
    paper_num = paper_num.split(',')
    #print(paper_num)
    while paper_num == ['']:
        paper_num = input("No papers selected.  Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
        paper_num = paper_num.split(',')
    while len(paper_num) > 4:
        paper_num = input("Too many papers selected.  Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
        paper_num = paper_num.split(',')
    select_list = []
    for num in paper_num:
        select_list.append(id_list[int(num)-1])
    return select_list

# %%
chosen_papers = user_selected_papers(id_list, webenv, query_key)
# Out:
# Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.
# 1. Cell-Based Model of the Generation and Maintenance of the Shape and Structure of the Multilayered Shoot Apical Meristem of Arabidopsis thaliana. ['Banwarth-Kuhn M', 'Nematbakhsh A', 'Rodriguez KW', 'Snipes S', 'Rasmussen CG', 'Reddy GV', 'Alber M']. Bulletin of mathematical biology. 2019 Aug. (30552627)
# 2. A plane choice: coordinating timing and orientation of cell division during plant development. ['Facette MR', 'Rasmussen CG', 'Van Norman JM']. Current opinion in plant biology. 2019 Feb. (30261337)
# 3. Predicting Division Planes of Three-Dimensional Cells by Soap-Film Minimization. ['Martinez P', 'Allsman LA', 'Brakke KA', 'Hoyt C', 'Hayes J', 'Liang H', 'Neher W', 'Rui Y', 'Roberts AM', 'Moradifam A', 'Goldstein B', 'Anderson CT', 'Rasmussen CG']. The Plant cell. 2018 Oct. (30150312)
# 4. The Microtubule-Associated Protein IQ67 DOMAIN5 Modulates Microtubule Dynamics and Pavement Cell Shape. ['Liang H', 'Zhang Y', 'Martinez P', 'Rasmussen CG', 'Xu T', 'Yang Z']. Plant physiology. 2018 Aug. (29976837)
# 5. An overview of plant division-plane orientation. ['Rasmussen CG', 'Bellinger M']. The New phytologist. 2018 Jul. (29701870)
# 6. Division Plane Orientation Defects Revealed by a Synthetic Double Mutant Phenotype. ['Mir R', 'Morris VH', 'Buschmann H', 'Rasmussen CG']. Plant physiology. 2018 Jan. (29146775)
# 7. Proper division plane orientation and mitotic progression together allow normal growth of maize. ['Martinez P', 'Luo A', 'Sylvester A', 'Rasmussen CG']. Proceedings of the National Academy of Sciences of the United States of America. 2017 Mar 7. (28202734)
# 8. A DII Domain-Based Auxin Reporter Uncovers Low Auxin Signaling during Telophase and Early G1. ['Mir R', 'Aranda LZ', 'Biaocchi T', 'Luo A', 'Sylvester AW', 'Rasmussen CG']. Plant physiology. 2017 Jan. (27881728)
# 9. Using Live-Cell Markers in Maize to Analyze Cell Division Orientation and Timing. ['Rasmussen CG']. Methods in molecular biology (Clifton, N.J.). 2016. (26659965)
# Which papers would you like to select? 3,6,7

# %%
print(chosen_papers)
# Out:
# ['30150312', '29146775', '28202734']

# %%
# Currently not used 
def get_citedin_refs(paper_id):
    """Returns paper ids corresponding to all the papers that cite a given paper.

    Arguments:
    paper_id - str; unique paper id
    
    Returns:
    ref_ids - list of strs; paper ids of the references
    """
    pubmed_refs = []
    ref_ids = []
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", id=paper_id))
    for entry in pub_records[0]["LinkSetDb"]:
        #print(entry)
        if entry["LinkName"] == 'pubmed_pubmed_citedin':
            pubmed_refs = entry["Link"]
    for ref in pubmed_refs:
        ref_ids.append(ref['Id'])      
    return ref_ids

# %%
# Currently not used
def get_paper_refs(paper_id):
    """Returns paper ids corresponding to all the papers cited by a given paper.

    Arguments:
    paper_id - str; unique paper id
    
    Returns:
    ref_ids - list of strs; paper ids of the references
    """
    pubmed_refs = []
    ref_ids = []
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", id=paper_id))
    for entry in pub_records[0]["LinkSetDb"]:
        #print(entry)
        if entry["LinkName"] == 'pubmed_pubmed_refs':
            pubmed_refs = entry["Link"]
    for ref in pubmed_refs:
        ref_ids.append(ref['Id'])      
    return ref_ids

# %%
print(len(get_citedin_refs("28202734")))
print(len(get_paper_refs("28202734")))

# %%
# Currently not used  
def compile_refs(paper_list):
    """Takes a list of paper IDs and returns a list of all the references they contain.  Alerts the user if the there
    are no references available for any of the papers.  
    
    Arguments:
    paper_list - list; paper IDs (str)
    
    Returns:
    all_ref_list - list; paper IDs (str)
    """
    all_ref_list = []
    for paper in paper_list:
        ref_list = get_paper_refs(paper)
        print("For paper {}, {} references were retrieved.".format(paper, len(ref_list)))
        all_ref_list.extend(ref_list)  
    return all_ref_list

# %%
# replaces the original get_paper_refs and compile_refs functions.  Uses epost and efetch to similify the process

def compile_refs_and_citedin(paper_list):
    """Takes a list of paper IDs and returns a list of the IDs for papers referenced in the original paper list.  The 
    reference list may be incomplete since PubMed does not provide references for all papers.  If concerned, run
    the related function 'compile_refs' to identify which papers are missing references.
    
    Arguments:
    paper_list - list; paper IDs (str)
    
    Returns:
    pubmed_refs - list; paper IDs (str)
    """
    str_paper_list = ",".join(paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=str_paper_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", WebEnv=webenv, query_key=query_key))
    ref_ids = []
    for entry in pub_records[0]["LinkSetDb"]:
        if entry["LinkName"] == 'pubmed_pubmed_refs':
            refs = entry["Link"]
            try:
                for ref in refs:
                    ref_ids.append(ref['Id'])
            except UnboundLocalError:
                print("No references found")        
        if entry["LinkName"] == 'pubmed_pubmed_citedin':
            cites = entry["Link"]
            try:
                for cite in cites:
                    ref_ids.append(cite['Id'])
            except UnboundLocalError:
                print("No cited in found")
    print("Length ref_ids list", len(ref_ids))
    print("Length ref_ids set", len(set(ref_ids)))
    return list(set(ref_ids))

# %%
# if user is not happy with the number of references retrieved - need to have some way to restart the selection process.

# %%
def get_first_last_authors(paper_id):
    """Given a paper, returns the first and last authors of the paper.
    
    Arguments:
    paper_id - str; paper ids
    
    Returns:
    authors - list of strs; list of full names of the first and last authors of the provided paper id
    """
    handle = Entrez.efetch(db='pubmed', id=paper_id, rettype='medline', retmode="text", retmax=200)
    record = Medline.read(handle)
    authors = record.get("FAU", "?")
    first_last_authors = [authors[0], authors[-1]]
    print(first_last_authors)
    return first_last_authors

# %%
def author_formatting(author_list):
    """Changes the formatting of author name strings to give the best PubMed search results. 
    
    Arguments:
    author_list - list of str; list of author names
    
    Returns:
    formatted_author_list - list of str; alphabetized list of author names formatted "lastname, firstname"
    """
    formatted_author_list = []
    for author in author_list:
        #print(author)
        last_name = author.split(',')[0]
        first_name = author.split(',')[1].lstrip()
        try:
            if first_name[1] == " ":
                try:
                    first_name = first_name[0] + first_name[-1]
                except:
                    first_name = first_name[0]
        except:            
            first_name = first_name[0]
        new_name = "{}, {}".format(last_name, first_name)
        #print(new_name)
        formatted_author_list.append(new_name)
    return sorted(formatted_author_list)

# %%
author_formatting(['Ambrose, J Christian'])

# %%
def remove_duplicates(sorted_list):
    """Takes a sorted list of authors and if 2 authors have the same last name and first initial, removes the name
    with only the first initial leaving behind the one that has the full first name. 
    
    Arguments:
    sorted_list - list; alphabetized list of authors in the format "lastname, firstname middleinit" OR 
    "lastname, firstinit middleinit"
    
    Returns:
    author_no_dup_list - list; alphabetized list of authors with duplicates removed 
    """
    author_no_dup_list = []
    most_recent_author = " , "
    for i, author in enumerate(sorted_list):
        if author.split(',')[0] == most_recent_author.split(',')[0]:
            if author.split(',')[1].lstrip()[0] != most_recent_author.split(',')[1].lstrip()[0]:
                author_no_dup_list.append(author)
                #print("(1) Compared {} to {} and appended {}".format(author, most_recent_author, author))
            else:
                #print("(2) Compared {} to {} and deleted {} and appended {}".format(author, most_recent_author, author_no_dup_list[-1], author)) 
                del author_no_dup_list[-1]
                author_no_dup_list.append(author)                       
        else:
            author_no_dup_list.append(author)
            #print("(3) Compared {} to {} and appended {}".format(author, most_recent_author, author))
        most_recent_author = author
    return author_no_dup_list

# %%
# create a list of scientists who wrote the paper(s) referenced by or who cited the user selected scientist 

def create_master_biologist_list(paper_list):
    """Searches PubMed for all the papers cited by or that cites a paper on the paper list.  Returns a list
    of the first and last authors of those papers (duplicates removed).
    
    Arguments:
    paper_list - list; paper IDs (str)
    
    Returns: 
    biologist_master_list - list; biologist names (str)
    """
    ref_citedin_ids = compile_refs_and_citedin(paper_list)
    first_last_author_list = []   
    for paper in ref_citedin_ids:
        print("Getting the authors of paper {}.".format(paper))
        authors = get_first_last_authors(paper)
        first_last_author_list.extend(authors) 
    set_f_l_author_list = list(set(first_last_author_list)) 
    print(len(set_f_l_author_list))
    format_f_l_author_list = author_formatting(set_f_l_author_list)
    print(len(format_f_l_author_list))
    no_dup_f_l_author_list = remove_duplicates(format_f_l_author_list)
    print(len(no_dup_f_l_author_list))
    return no_dup_f_l_author_list

# %%
master_biologist_list = create_master_biologist_list(chosen_papers)
# Out:
# Length ref_ids list 168
# Lenght ref_ids set 167
# Getting the authors of paper 22045917.
# ['Van Damme, Daniel', 'Russinova, Eugenia']
# Getting the authors of paper 11044722.
# ['Hellens, R', 'Klee, H']
# Getting the authors of paper 18583534.
# ['Paredez, Alexander R', 'Somerville, Chris R']
# Getting the authors of paper 16179950.
# ['Thery, Manuel', 'Bornens, Michel']
# Getting the authors of paper 19825595.
# ['Ambrose, J Christian', 'Cyr, Richard']
# Getting the authors of paper 22645544.
# ['Weizbauer, Renate', 'Schulz, Burkhard']
# Getting the authors of paper 30742612.
# ['Moukhtar, Julien', 'Andrey, Philippe']
# Getting the authors of paper 24258577.
# ['Lang Selker, J M', 'Green, P B']
# Getting the authors of paper 22301654.
# ['Wadsworth, Patricia', 'Wadsworth, Patricia']
# Getting the authors of paper 15155883.
# ['Sedbrook, John C', 'Somerville, Chris R']
# Getting the authors of paper 30804009.
# ['Rui, Yue', 'Anderson, Charles T']
# Getting the authors of paper 29394250.
# ['Chakrabortty, Bandan', 'Mulder, Bela M']
# Getting the authors of paper 30150312.
# ['Martinez, Pablo', 'Rasmussen, Carolyn G']
# Getting the authors of paper 26707611.
# ['Fisher, Adam P', 'Sozzani, Rosangela']
# Getting the authors of paper 11385579.
# ['Whittington, A T', 'Wasteneys, G O']
# Getting the authors of paper 25989832.
# ['Wachsman, Guy', 'Benfey, Philip N']
# Getting the authors of paper 12711226.
# ['Beemster, Gerrit T S', 'Inze, Dirk']
# Getting the authors of paper 23769888.
# ['Feng, Ying', 'Fearon, Eric R']
# Getting the authors of paper 19268593.
# ['Krupnova, Tamara', 'Jurgens, Gerd']
# Getting the authors of paper 12000963.
# ['Thitamadee, Siripong', 'Hashimoto, Takashi']
# Getting the authors of paper 9013934.
# ['Lynch, T M', 'Lintilhac, P M']
# Getting the authors of paper 15862097.
# ['Jurgens, Gerd', 'Jurgens, Gerd']
# Getting the authors of paper 20133808.
# ['Dupuy, Lionel', 'Haseloff, Jim']
# Getting the authors of paper 28408602.
# ['Schaefer, Estelle', 'Bouchez, David']
# Getting the authors of paper 12354954.
# ['Gunning, BES.', 'Sammut, M.']
# Getting the authors of paper 28369169.
# ['Arganda-Carreras, Ignacio', 'Sebastian Seung, H']
# Getting the authors of paper 22329999.
# ['May, Sophie F', 'Hammarton, Tansy C']
# Getting the authors of paper 20663817.
# ['Spinner, Lara', 'Schaefer, Didier G']
# Getting the authors of paper 20976043.
# ['Heisler, Marcus G', 'Meyerowitz, Elliot M']
# Getting the authors of paper 24912195.
# ['Bassel, George W', 'Smith, Richard S']
# Getting the authors of paper 21970704.
# ['Millar, Katherine D L', 'Kiss, John Z']
# Getting the authors of paper 21391814.
# ['Rasmussen, Carolyn G', 'Smith, Laurie G']
# Getting the authors of paper 22743772.
# ['Schindelin, Johannes', 'Cardona, Albert']
# Getting the authors of paper 26832441.
# ['von Wangenheim, Daniel', 'Maizel, Alexis']
# Getting the authors of paper 21346731.
# ['De Smet, Ive', 'Beeckman, Tom']
# Getting the authors of paper 10406715.
# ['Zhao, L', 'Sack, F D']
# Getting the authors of paper 29462151.
# ['Mirabet, Vincent', 'Boudaoud, Arezki']
# Getting the authors of paper 16333576.
# ['Marcus, A I', 'Cyr, R J']
# Getting the authors of paper 24172707.
# ['Lee, Yuh-Ru Julie', 'Liu, Bo']
# Getting the authors of paper 12805636.
# ['Buer, Charles S', 'Masle, Josette']
# Getting the authors of paper 26893344.
# ['Zhang, Yanwen', 'Costa, Silvia']
# Getting the authors of paper 26051555.
# ['Gunther, Manuel Ingo', 'Blesch, Armin']
# Getting the authors of paper 21622382.
# ['Marcotrigiano, Michael', 'Marcotrigiano, Michael']
# Getting the authors of paper 30448943.
# ['Gerien, Kenneth S', 'Wu, Jian-Qiu']
# Getting the authors of paper 29146775.
# ['Mir, Ricardo', 'Rasmussen, Carolyn G']
# Getting the authors of paper 22383847.
# ['Kierzkowski, Daniel', 'Smith, Richard S']
# Getting the authors of paper 15509858.
# ['Nakamura, Masayoshi', 'Hashimoto, Takashi']
# Getting the authors of paper 24616724.
# ['Takada, Shinobu', 'Iida, Hiroyuki']
# Getting the authors of paper 15879559.
# ['Chan, Jordi', 'Lloyd, Clive']
# Getting the authors of paper 24240534.
# ['Pietra, Stefano', 'Grebe, Markus']
# Getting the authors of paper 25346746.
# ['Besson, Sebastien', 'Dumais, Jacques']
# Getting the authors of paper 21873296.
# ['Wu, Shu-Zon', 'Bezanilla, Magdalena']
# Getting the authors of paper 10080694.
# ['Neuteboom, L W', 'van der Zaal, B J']
# Getting the authors of paper 23551516.
# ['Landrein, Benoit', 'Hamant, Olivier']
# Getting the authors of paper 28943203.
# ['Smertenko, Andrei', 'Zarsky, Viktor']
# Getting the authors of paper 27501519.
# ['Stockle, Dorothee', 'Muller, Sabine']
# Getting the authors of paper 19168717.
# ['Wright, Amanda J', 'Smith, Laurie G']
# Getting the authors of paper 11232561.
# ['Hartman, J L 4th', 'Hartwell, L']
# Getting the authors of paper 8625799.
# ['Smith, L G', 'Sylvester, A W']
# Getting the authors of paper 16278345.
# ['Jenik, Pablo D', 'Barton, M Kathryn']
# Getting the authors of paper 9811795.
# ['Cleary, A L', 'Smith, L G']
# Getting the authors of paper 25449723.
# ['van Dop, Maritza', 'Weijers, Dolf']
# Getting the authors of paper 10069079.
# ['Clough, S J', 'Bent, A F']
# Getting the authors of paper 26019693.
# ['Hashimoto, Takashi', 'Hashimoto, Takashi']
# Getting the authors of paper 24026117.
# ['Poulton, John S', 'Peifer, Mark']
# Getting the authors of paper 23770826.
# ['Murata, Takashi', 'Hasebe, Mitsuyasu']
# Getting the authors of paper 27095491.
# ['Han, Soon-Ki', 'Torii, Keiko U']
# Getting the authors of paper 19704687.
# ['Buschmann, Henrik', 'Lloyd, Clive W']
# Getting the authors of paper 19531350.
# ['Abrash, Emily B', 'Bergmann, Dominique C']
# Getting the authors of paper 26886796.
# ['Bosveld, Floris', 'Bellaiche, Yohanns']
# Getting the authors of paper 19144522.
# ['Wasteneys, Geoffrey O', 'Ambrose, J Christian']
# Getting the authors of paper 19201915.
# ['Mohanty, Amitabh', 'Jackson, David']
# Getting the authors of paper 12000456.
# ['Menges, Margit', 'Murray, James A H']
# Getting the authors of paper 11971138.
# ['Camilleri, Christine', 'Bouchez, David']
# Getting the authors of paper 17765597.
# ['Van Damme, Daniel', 'Geelen, Danny']
# Getting the authors of paper 25908862.
# ['Buschmann, Henrik', 'Lloyd, Clive W']
# Getting the authors of paper 11149933.
# ['Smith, L G', 'Levy, J']
# Getting the authors of paper 24825294.
# ['Kajala, Kaisa', 'Brady, Siobhan M']
# Getting the authors of paper 17488810.
# ['Ishida, Takashi', 'Hashimoto, Takashi']
# Getting the authors of paper 24166436.
# ['Wu, Qingyu', 'Jackson, Dave']
# Getting the authors of paper 28399805.
# ['Roy, Rahul', 'Bassham, Diane C']
# Getting the authors of paper 11115865.
# ['Sugimoto, K', 'Wasteneys, G O']
# Getting the authors of paper 19378001.
# ['Mohanty, Amitabh', 'Jackson, David']
# Getting the authors of paper 19638477.
# ['Buschmann, Henrik', 'Schaffner, Anton R']
# Getting the authors of paper 25415978.
# ['Galva, Charitha', 'Sedbrook, John C']
# Getting the authors of paper 18042620.
# ['Kirik, Viktor', 'Hulskamp, Martin']
# Getting the authors of paper 25646318.
# ['Zhu, Chuanmei', 'Dixit, Ram']
# Getting the authors of paper 16261190.
# ['Cosgrove, Daniel J', 'Cosgrove, Daniel J']
# Getting the authors of paper 19523675.
# ['Dong, Juan', 'Bergmann, Dominique C']
# Getting the authors of paper 10679454.
# ['Sylvester, A W', 'Sylvester, A W']
# Getting the authors of paper 26485667.
# ['Boruc, Joanna', 'Van Damme, Daniel']
# Getting the authors of paper 21680355.
# ['Pickett-Heaps, J D', 'Cleary, A L']
# Getting the authors of paper 11123800.
# ['Wang, H', 'Fowke, L C']
# Getting the authors of paper 21383128.
# ['Besson, Sebastien', 'Dumais, Jacques']
# Getting the authors of paper 20689588.
# ['Sahlin, Patrik', 'Jonsson, Henrik']
# Getting the authors of paper 24972597.
# ['Lipka, Elisabeth', 'Muller, Sabine']
# Getting the authors of paper 16682350.
# ['Muller, Sabine', 'Smith, Laurie G']
# Getting the authors of paper 12782733.
# ['Sugimoto, Keiko', 'Wasteneys, Geoffrey O']
# Getting the authors of paper 23044038.
# ['Facette, Michelle R', 'Smith, Laurie G']
# Getting the authors of paper 27997824.
# ['Pierre, Anaelle', 'Minc, Nicolas']
# Getting the authors of paper 21172800.
# ['Rasmussen, Carolyn G', 'Smith, Laurie G']
# Getting the authors of paper 26635855.
# ['Beauzamy, Lena', 'Boudaoud, Arezki']
# Getting the authors of paper 15470418.
# ['Hayashi, Takashi', 'Carthew, Richard W']
# Getting the authors of paper 30281798.
# ['Vofely, Roza V', 'Braybrook, Siobhan A']
# Getting the authors of paper 12586874.
# ['Yuen, Christen Y L', 'Masson, Patrick H']
# Getting the authors of paper 3867671.
# ['Gunning, B E', 'Wick, S M']
# Getting the authors of paper 23299369.
# ['Peterson, Kylee M', 'Torii, Keiko U']
# Getting the authors of paper 2391003.
# ['Becraft, P W', 'Freeling, M']
# Getting the authors of paper 11738380.
# ['Migliaccio, F', 'Piconese, S']
# Getting the authors of paper 17964159.
# ['Walker, Keely L', 'Smith, Laurie G']
# Getting the authors of paper 2324196.
# ['Flanders, D J', 'Lloyd, C W']
# Getting the authors of paper 27930326.
# ['Willis, Lisa', 'Jonsson, Henrik']
# Getting the authors of paper 29317523.
# ['Szymanski, Dan', 'Sakamoto, Wataru']
# Getting the authors of paper 27426272.
# ['Van Norman, Jaimie M', 'Van Norman, Jaimie M']
# Getting the authors of paper 18932023.
# ['Sakaguchi, Jun', 'Fukuda, Hiroo']
# Getting the authors of paper 11732054.
# ['Baskin, T I', 'Baskin, T I']
# Getting the authors of paper 30987599.
# ['Jaquez-Gutierrez, Marybel', 'Moreno, Vicente']
# Getting the authors of paper 7664733.
# ['Hemerly, A', 'Ferreira, P']
# Getting the authors of paper 26659965.
# ['Rasmussen, Carolyn G', 'Rasmussen, Carolyn G']
# Getting the authors of paper 26735065.
# ['Walbot, Virginia', 'Egger, Rachel L']
# Getting the authors of paper 5929804.
# ['Pickett-Heaps, J D', 'Northcote, D H']
# Getting the authors of paper 12970569.
# ['Yamashita, Yukiko M', 'Fuller, Margaret T']
# Getting the authors of paper 9657151.
# ['Neufeld, T P', 'Edgar, B A']
# Getting the authors of paper 17684564.
# ['Winter, Debbie', 'Provart, Nicholas J']
# Getting the authors of paper 25825722.
# ['Shapiro, Bruce E', 'Meyerowitz, Elliot M']
# Getting the authors of paper 28285992.
# ['Bringmann, Martin', 'Bergmann, Dominique C']
# Getting the authors of paper 23496276.
# ['Rasmussen, Carolyn G', 'Muller, Sabine']
# Getting the authors of paper 20596025.
# ['Sozzani, R', 'Benfey, P N']
# Getting the authors of paper 18757558.
# ['Azimzadeh, Juliette', 'Bouchez, David']
# Getting the authors of paper 24740969.
# ['Sampathkumar, Arun', 'Meyerowitz, Elliot M']
# Getting the authors of paper 22079114.
# ['Smertenko, Andrei P', 'Hussey, Patrick J']
# Getting the authors of paper 23673648.
# ['Spinner, Lara', 'Pastuglia, Martine']
# Getting the authors of paper 30002118.
# ['Herrmann, Arvid', 'Muller, Sabine']
# Getting the authors of paper 29763857.
# ['Serrano-Mislata, Antonio', 'Sablowski, Robert']
# Getting the authors of paper 22395485.
# ['Kirik, Angela', 'Kirik, Viktor']
# Getting the authors of paper 26945038.
# ['Voxeur, Aline', 'Hofte, Herman']
# Getting the authors of paper 19850508.
# ['Van Damme, Daniel', 'Van Damme, Daniel']
# Getting the authors of paper 17027491.
# ['Buschmann, Henrik', 'Lloyd, Clive W']
# Getting the authors of paper 16377747.
# ['Kawamura, Eiko', 'Wasteneys, Geoffrey O']
# Getting the authors of paper 19154365.
# ['Shen, Li', 'McPeek, Mark A']
# Getting the authors of paper 25303534.
# ['Xiong, Fengzhu', 'Megason, Sean G']
# Getting the authors of paper 22190487.
# ['Li, Shundai', 'Gu, Ying']
# Getting the authors of paper 21295702.
# ['Gibson, William T', 'Gibson, Matthew C']
# Getting the authors of paper 28202734.
# ['Martinez, Pablo', 'Rasmussen, Carolyn G']
# Getting the authors of paper 24656334.
# ['Roy, Rahul', 'Bassham, Diane C']
# Getting the authors of paper 15324671.
# ['Buschmann, Henrik', 'Schaffner, Anton R']
# Getting the authors of paper 25247701.
# ['Wu, Shu-Zon', 'Bezanilla, Magdalena']
# Getting the authors of paper 27475487.
# ['Shao, Wanchen', 'Dong, Juan']
# Getting the authors of paper 29348144.
# ['Heppert, Jennifer K', 'Goldstein, Bob']
# Getting the authors of paper 24408367.
# ['Gunning, B E', 'Hughes, J E']
# Getting the authors of paper 18003929.
# ['Kafer, Jos', 'Graner, Francois']
# Getting the authors of paper 27436908.
# ['Louveaux, Marion', 'Hamant, Olivier']
# Getting the authors of paper 28596780.
# ['Komis, George', 'Samaj, Jozef']
# Getting the authors of paper 11598229.
# ['Carpita, N C', 'McCann, M C']
# Getting the authors of paper 23531846.
# ['Asada, Tetsuhiro', 'Asada, Tetsuhiro']
# Getting the authors of paper 27624830.
# ['Galletti, Roberta', 'Ingram, Gwyneth C']
# Getting the authors of paper 10737809.
# ['Cutler, S R', 'Somerville, C R']
# Getting the authors of paper 27889635.
# ['Brunkard, Jacob O', 'Zambryski, Patricia C']
# Getting the authors of paper 24684831.
# ['Yoshida, Saiko', 'Weijers, Dolf']
# Getting the authors of paper 30150310.
# ['Lockhart, Jennifer', 'Lockhart, Jennifer']
# Getting the authors of paper 29701870.
# ['Rasmussen, Carolyn G', 'Bellinger, Marschal']
# Getting the authors of paper 19346324.
# ['Preibisch, Stephan', 'Tomancak, Pavel']
# Getting the authors of paper 2088734.
# ['Sylvester, A W', 'Freeling, M']
# Getting the authors of paper 11003843.
# ['Furutani, I', 'Hashimoto, T']
# Getting the authors of paper 22321291.
# ['Minc, Nicolas', 'Piel, Matthieu']
# Getting the authors of paper 7744956.
# ['Goldstein, B', 'Goldstein, B']
# Getting the authors of paper 20067996.
# ['Komaki, Shinichiro', 'Hashimoto, Takashi']
# 251
# 251
# 237

# %%
def create_biologist_paper_dict(biologist_list):
    """Takes a list of biologists and looks up the IDs of all the papers they authored in PubMed.  Returns
    a dictionary where the biologist's name is the key and the value is a list of their paper IDs. 
    
    Arguments:
    biologist_list - list; biologist names (str)
    
    Returns:
    biologist_paper_dict - dict; keys are biologist names (str) and the values are a list of IDs of the papers 
    authored by the biologist
    """
    biologist_papers_dict = {}
    for biologist in biologist_list[0:5]:
        biologist_nocomma = biologist.replace(',', '')
        print("Getting papers authored by {}.".format(biologist_nocomma))
        papers = get_scientist_papers(biologist_nocomma)[0]
        biologist_papers_dict[biologist] = papers
    zero_papers = []
    has_papers = []
    total = 0
    for key, value in biologist_papers_dict.items():
        if len(value) == 0:
            zero_papers.append(key)
        else:
            has_papers.append(key)
        total += len(value)
    print("total papers:", total)
    print("Zero papers were retrieved for the following authors:", zero_papers)
    print("More than one paper was retreieved for the following authors:", has_papers)
    return biologist_papers_dict

# %%
the_biologist_paper_dict = create_biologist_paper_dict(master_biologist_list)
# Out:
# Getting papers authored by Abrash Emily B.
# Getting papers authored by Ambrose Jn.
# Getting papers authored by Anderson Charles T.
# Getting papers authored by Andrey Philippe.
# Getting papers authored by Arganda-Carreras Ignacio.
# Getting papers authored by Asada Tetsuhiro.
# Getting papers authored by Azimzadeh Juliette.
# Getting papers authored by Barton Mn.
# Getting papers authored by Baskin TI.
# Getting papers authored by Bassel George W.
# Getting papers authored by Bassham Diane C.
# Getting papers authored by Beauzamy Lena.
# Getting papers authored by Becraft PW.
# Getting papers authored by Beeckman Tom.
# Getting papers authored by Beemster Gerrit T S.
# Getting papers authored by Bellaiche Yohanns.
# Getting papers authored by Bellinger Marschal.
# Getting papers authored by Benfey Philip N.
# Getting papers authored by Bent AF.
# Getting papers authored by Bergmann Dominique C.
# Getting papers authored by Besson Sebastien.
# Getting papers authored by Bezanilla Magdalena.
# Getting papers authored by Blesch Armin.
# Getting papers authored by Bornens Michel.
# Getting papers authored by Boruc Joanna.
# Getting papers authored by Bosveld Floris.
# Getting papers authored by Bouchez David.
# Getting papers authored by Boudaoud Arezki.
# Getting papers authored by Brady Siobhan M.
# Getting papers authored by Braybrook Siobhan A.
# Getting papers authored by Bringmann Martin.
# Getting papers authored by Brunkard Jacob O.
# Getting papers authored by Buer Charles S.
# Getting papers authored by Buschmann Henrik.
# Getting papers authored by Camilleri Christine.
# Getting papers authored by Cardona Albert.
# Getting papers authored by Carpita NC.
# Getting papers authored by Carthew Richard W.
# Getting papers authored by Chakrabortty Bandan.
# Getting papers authored by Chan Jordi.
# Getting papers authored by Cleary AL.
# Getting papers authored by Clough SJ.
# Getting papers authored by Cosgrove Daniel J.
# Getting papers authored by Costa Silvia.
# Getting papers authored by Cutler SR.
# Getting papers authored by Cyr Richard.
# Getting papers authored by De Smet Ive.
# Getting papers authored by Dixit Ram.
# Getting papers authored by Dong Juan.
# Getting papers authored by Dumais Jacques.
# Getting papers authored by Dupuy Lionel.
# Getting papers authored by Edgar BA.
# Getting papers authored by Egger Rachel L.
# Getting papers authored by Facette Michelle R.
# Getting papers authored by Fearon Eric R.
# Getting papers authored by Feng Ying.
# Getting papers authored by Ferreira P.
# Getting papers authored by Fisher Adam P.
# Getting papers authored by Flanders DJ.
# Getting papers authored by Fowke LC.
# Getting papers authored by Freeling M.
# Getting papers authored by Fukuda Hiroo.
# Getting papers authored by Fuller Margaret T.
# Getting papers authored by Furutani I.
# Getting papers authored by Galletti Roberta.
# Getting papers authored by Galva Charitha.
# Getting papers authored by Geelen Danny.
# Getting papers authored by Gerien Kenneth S.
# Getting papers authored by Gibson Matthew C.
# Getting papers authored by Gibson William T.
# Getting papers authored by Goldstein Bob.
# Getting papers authored by Graner Francois.
# Getting papers authored by Grebe Markus.
# Getting papers authored by Green PB.
# Getting papers authored by Gu Ying.
# Getting papers authored by Gunning BES..
# Getting papers authored by Gunther Manuel Ingo.
# Getting papers authored by Hamant Olivier.
# Getting papers authored by Hammarton Tansy C.
# Getting papers authored by Han Soon-Ki.
# Getting papers authored by Hartman Jh.
# Getting papers authored by Hartwell L.
# Getting papers authored by Hasebe Mitsuyasu.
# Getting papers authored by Haseloff Jim.
# Getting papers authored by Hashimoto Takashi.
# Getting papers authored by Hayashi Takashi.
# Getting papers authored by Heisler Marcus G.
# Getting papers authored by Hellens R.
# Getting papers authored by Hemerly A.
# Getting papers authored by Heppert Jennifer K.
# Getting papers authored by Herrmann Arvid.
# Getting papers authored by Hofte Herman.
# Getting papers authored by Hughes JE.
# Getting papers authored by Hulskamp Martin.
# Getting papers authored by Hussey Patrick J.
# Getting papers authored by Iida Hiroyuki.
# Getting papers authored by Ingram Gwyneth C.
# Getting papers authored by Inze Dirk.
# Getting papers authored by Ishida Takashi.
# Getting papers authored by Jackson David.
# Getting papers authored by Jaquez-Gutierrez Marybel.
# Getting papers authored by Jenik Pablo D.
# Getting papers authored by Jonsson Henrik.
# Getting papers authored by Jurgens Gerd.
# Getting papers authored by Kafer Jos.
# Getting papers authored by Kajala Kaisa.
# Getting papers authored by Kawamura Eiko.
# Getting papers authored by Kierzkowski Daniel.
# Getting papers authored by Kirik Angela.
# Getting papers authored by Kirik Viktor.
# Getting papers authored by Kiss John Z.
# Getting papers authored by Klee H.
# Getting papers authored by Komaki Shinichiro.
# Getting papers authored by Komis George.
# Getting papers authored by Krupnova Tamara.
# Getting papers authored by Landrein Benoit.
# Getting papers authored by Lang Selker JM.
# Getting papers authored by Lee Yuh-Ru Julie.
# Getting papers authored by Levy J.
# Getting papers authored by Li Shundai.
# Getting papers authored by Lintilhac PM.
# Getting papers authored by Lipka Elisabeth.
# Getting papers authored by Liu Bo.
# Getting papers authored by Lloyd Clive W.
# Getting papers authored by Lockhart Jennifer.
# Getting papers authored by Louveaux Marion.
# Getting papers authored by Lynch TM.
# Getting papers authored by Maizel Alexis.
# Getting papers authored by Marcotrigiano Michael.
# Getting papers authored by Marcus AI.
# Getting papers authored by Martinez Pablo.
# Getting papers authored by Masle Josette.
# Getting papers authored by Masson Patrick H.
# Getting papers authored by May Sophie F.
# Getting papers authored by McCann MC.
# Getting papers authored by McPeek Mark A.
# Getting papers authored by Megason Sean G.
# Getting papers authored by Menges Margit.
# Getting papers authored by Meyerowitz Elliot M.
# Getting papers authored by Migliaccio F.
# Getting papers authored by Millar Katherine D L.
# Getting papers authored by Minc Nicolas.
# Getting papers authored by Mir Ricardo.
# Getting papers authored by Mirabet Vincent.
# Getting papers authored by Mohanty Amitabh.
# Getting papers authored by Moreno Vicente.
# Getting papers authored by Moukhtar Julien.
# Getting papers authored by Mulder Bela M.
# Getting papers authored by Muller Sabine.
# Getting papers authored by Murata Takashi.
# Getting papers authored by Murray James A H.
# Getting papers authored by Nakamura Masayoshi.
# Getting papers authored by Neufeld TP.
# Getting papers authored by Neuteboom LW.
# Getting papers authored by Northcote DH.
# Getting papers authored by Paredez Alexander R.
# Getting papers authored by Pastuglia Martine.
# Getting papers authored by Peifer Mark.
# Getting papers authored by Peterson Kylee M.
# Getting papers authored by Pickett-Heaps JD.
# Getting papers authored by Piconese S.
# Getting papers authored by Piel Matthieu.
# Getting papers authored by Pierre Anaelle.
# Getting papers authored by Pietra Stefano.
# Getting papers authored by Poulton John S.
# Getting papers authored by Preibisch Stephan.
# Getting papers authored by Provart Nicholas J.
# Getting papers authored by Rasmussen Carolyn G.
# Getting papers authored by Roy Rahul.
# Getting papers authored by Rui Yue.
# Getting papers authored by Russinova Eugenia.
# Getting papers authored by Sablowski Robert.
# Getting papers authored by Sack FD.
# Getting papers authored by Sahlin Patrik.
# Getting papers authored by Sakaguchi Jun.
# Getting papers authored by Sakamoto Wataru.
# Getting papers authored by Samaj Jozef.
# Getting papers authored by Sammut M..
# Getting papers authored by Sampathkumar Arun.
# Getting papers authored by Schaefer Didier G.
# Getting papers authored by Schaefer Estelle.
# Getting papers authored by Schaffner Anton R.
# Getting papers authored by Schindelin Johannes.
# Getting papers authored by Schulz Burkhard.
# Getting papers authored by Sebastian Seung H.
# Getting papers authored by Sedbrook John C.
# Getting papers authored by Serrano-Mislata Antonio.
# Getting papers authored by Shao Wanchen.
# Getting papers authored by Shapiro Bruce E.
# Getting papers authored by Shen Li.
# Getting papers authored by Smertenko Andrei P.
# Getting papers authored by Smith Laurie G.
# Getting papers authored by Smith Richard S.
# Getting papers authored by Somerville Chris R.
# Getting papers authored by Sozzani Rosangela.
# Getting papers authored by Spinner Lara.
# Getting papers authored by Stockle Dorothee.
# Getting papers authored by Sugimoto Keiko.
# Getting papers authored by Sylvester AW.
# Getting papers authored by Szymanski Dan.
# Getting papers authored by Takada Shinobu.
# Getting papers authored by Thery Manuel.
# Getting papers authored by Thitamadee Siripong.
# Getting papers authored by Tomancak Pavel.
# Getting papers authored by Torii Keiko U.
# Getting papers authored by Van Damme Daniel.
# Getting papers authored by Van Norman Jaimie M.
# Getting papers authored by Vofely Roza V.
# Getting papers authored by Voxeur Aline.
# Getting papers authored by Wachsman Guy.
# Getting papers authored by Wadsworth Patricia.
# Getting papers authored by Walbot Virginia.
# Getting papers authored by Walker Keely L.
# Getting papers authored by Wang H.
# Getting papers authored by Wasteneys Geoffrey O.
# Getting papers authored by Weijers Dolf.
# Getting papers authored by Weizbauer Renate.
# Getting papers authored by Whittington AT.
# Getting papers authored by Wick SM.
# Getting papers authored by Willis Lisa.
# Getting papers authored by Winter Debbie.
# Getting papers authored by Wright Amanda J.
# Getting papers authored by Wu Jian-Qiu.
# Getting papers authored by Wu Qingyu.
# Getting papers authored by Wu Shu-Zon.
# Getting papers authored by Xiong Fengzhu.
# Getting papers authored by Yamashita Yukiko M.
# Getting papers authored by Yoshida Saiko.
# Getting papers authored by Yuen Christen Y L.
# Getting papers authored by Zambryski Patricia C.
# Getting papers authored by Zarsky Viktor.
# Getting papers authored by Zhang Yanwen.
# Getting papers authored by Zhao L.
# Getting papers authored by Zhu Chuanmei.
# Getting papers authored by van Dop Maritza.
# Getting papers authored by van der Zaal BJ.
# Getting papers authored by von Wangenheim Daniel.
# total papers: 19
# Zero papers were retrieved for the following authors: ['Ambrose, Jn']
# More than one paper was retreieved for the following authors: ['Abrash, Emily B', 'Anderson, Charles T', 'Andrey, Philippe', 'Arganda-Carreras, Ignacio', 'Asada, Tetsuhiro', 'Azimzadeh, Juliette', 'Barton, Mn', 'Baskin, TI', 'Bassel, George W', 'Bassham, Diane C', 'Beauzamy, Lena', 'Becraft, PW', 'Beeckman, Tom', 'Beemster, Gerrit T S', 'Bellaiche, Yohanns', 'Bellinger, Marschal', 'Benfey, Philip N', 'Bent, AF', 'Bergmann, Dominique C', 'Besson, Sebastien', 'Bezanilla, Magdalena', 'Blesch, Armin', 'Bornens, Michel', 'Boruc, Joanna', 'Bosveld, Floris', 'Bouchez, David', 'Boudaoud, Arezki', 'Brady, Siobhan M', 'Braybrook, Siobhan A', 'Bringmann, Martin', 'Brunkard, Jacob O', 'Buer, Charles S', 'Buschmann, Henrik', 'Camilleri, Christine', 'Cardona, Albert', 'Carpita, NC', 'Carthew, Richard W', 'Chakrabortty, Bandan', 'Chan, Jordi', 'Cleary, AL', 'Clough, SJ', 'Cosgrove, Daniel J', 'Costa, Silvia', 'Cutler, SR', 'Cyr, Richard', 'De Smet, Ive', 'Dixit, Ram', 'Dong, Juan', 'Dumais, Jacques', 'Dupuy, Lionel', 'Edgar, BA', 'Egger, Rachel L', 'Facette, Michelle R', 'Fearon, Eric R', 'Feng, Ying', 'Ferreira, P', 'Fisher, Adam P', 'Flanders, DJ', 'Fowke, LC', 'Freeling, M', 'Fukuda, Hiroo', 'Fuller, Margaret T', 'Furutani, I', 'Galletti, Roberta', 'Galva, Charitha', 'Geelen, Danny', 'Gerien, Kenneth S', 'Gibson, Matthew C', 'Gibson, William T', 'Goldstein, Bob', 'Graner, Francois', 'Grebe, Markus', 'Green, PB', 'Gu, Ying', 'Gunning, BES.', 'Gunther, Manuel Ingo', 'Hamant, Olivier', 'Hammarton, Tansy C', 'Han, Soon-Ki', 'Hartman, Jh', 'Hartwell, L', 'Hasebe, Mitsuyasu', 'Haseloff, Jim', 'Hashimoto, Takashi', 'Hayashi, Takashi', 'Heisler, Marcus G', 'Hellens, R', 'Hemerly, A', 'Heppert, Jennifer K', 'Herrmann, Arvid', 'Hofte, Herman', 'Hughes, JE', 'Hulskamp, Martin', 'Hussey, Patrick J', 'Iida, Hiroyuki', 'Ingram, Gwyneth C', 'Inze, Dirk', 'Ishida, Takashi', 'Jackson, David', 'Jaquez-Gutierrez, Marybel', 'Jenik, Pablo D', 'Jonsson, Henrik', 'Jurgens, Gerd', 'Kafer, Jos', 'Kajala, Kaisa', 'Kawamura, Eiko', 'Kierzkowski, Daniel', 'Kirik, Angela', 'Kirik, Viktor', 'Kiss, John Z', 'Klee, H', 'Komaki, Shinichiro', 'Komis, George', 'Krupnova, Tamara', 'Landrein, Benoit', 'Lang Selker, JM', 'Lee, Yuh-Ru Julie', 'Levy, J', 'Li, Shundai', 'Lintilhac, PM', 'Lipka, Elisabeth', 'Liu, Bo', 'Lloyd, Clive W', 'Lockhart, Jennifer', 'Louveaux, Marion', 'Lynch, TM', 'Maizel, Alexis', 'Marcotrigiano, Michael', 'Marcus, AI', 'Martinez, Pablo', 'Masle, Josette', 'Masson, Patrick H', 'May, Sophie F', 'McCann, MC', 'McPeek, Mark A', 'Megason, Sean G', 'Menges, Margit', 'Meyerowitz, Elliot M', 'Migliaccio, F', 'Millar, Katherine D L', 'Minc, Nicolas', 'Mir, Ricardo', 'Mirabet, Vincent', 'Mohanty, Amitabh', 'Moreno, Vicente', 'Moukhtar, Julien', 'Mulder, Bela M', 'Muller, Sabine', 'Murata, Takashi', 'Murray, James A H', 'Nakamura, Masayoshi', 'Neufeld, TP', 'Neuteboom, LW', 'Northcote, DH', 'Paredez, Alexander R', 'Pastuglia, Martine', 'Peifer, Mark', 'Peterson, Kylee M', 'Pickett-Heaps, JD', 'Piconese, S', 'Piel, Matthieu', 'Pierre, Anaelle', 'Pietra, Stefano', 'Poulton, John S', 'Preibisch, Stephan', 'Provart, Nicholas J', 'Rasmussen, Carolyn G', 'Roy, Rahul', 'Rui, Yue', 'Russinova, Eugenia', 'Sablowski, Robert', 'Sack, FD', 'Sahlin, Patrik', 'Sakaguchi, Jun', 'Sakamoto, Wataru', 'Samaj, Jozef', 'Sammut, M.', 'Sampathkumar, Arun', 'Schaefer, Didier G', 'Schaefer, Estelle', 'Schaffner, Anton R', 'Schindelin, Johannes', 'Schulz, Burkhard', 'Sebastian Seung, H', 'Sedbrook, John C', 'Serrano-Mislata, Antonio', 'Shao, Wanchen', 'Shapiro, Bruce E', 'Shen, Li', 'Smertenko, Andrei P', 'Smith, Laurie G', 'Smith, Richard S', 'Somerville, Chris R', 'Sozzani, Rosangela', 'Spinner, Lara', 'Stockle, Dorothee', 'Sugimoto, Keiko', 'Sylvester, AW', 'Szymanski, Dan', 'Takada, Shinobu', 'Thery, Manuel', 'Thitamadee, Siripong', 'Tomancak, Pavel', 'Torii, Keiko U', 'Van Damme, Daniel', 'Van Norman, Jaimie M', 'Vofely, Roza V', 'Voxeur, Aline', 'Wachsman, Guy', 'Wadsworth, Patricia ...

# %%
def get_and_compile_refs(paper_list):
    """Takes a list of paper IDs and returns a list of the IDs of the papers referenced by papers in the original list.
    The reference list may be incomplete since PubMed does not provide references for all papers.  If concerned, run
    the related function 'compile_refs' to identify which papers are missing references.
    
    Arguments:
    paper_list - list, paper IDs (str)
    
    Returns:
    pubmed_refs - list, paper IDs 
    """
    str_paper_list = ",".join(paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=str_paper_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", WebEnv=webenv, query_key=query_key))
    for entry in pub_records[0]["LinkSetDb"]:
        if entry["LinkName"] == 'pubmed_pubmed_refs':
            pubmed_refs = entry["Link"]
    ref_ids = []
    try:
        for ref in pubmed_refs:
            ref_ids.append(ref['Id'])
    except UnboundLocalError:
        print("No references found")
    return ref_ids

# %%
def create_biologist_cited_papers_dict(biologist_paper_dict):
    """Takes a dictionary of biologists and the papers they wrote, looks up each paper in PubMed and returns a new
    dictionary containing the biologist and a list of all the papers they cite(reference) within the papers they wrote. 
    
    Arguments:
    biologist_paper_dict - dict; keys are biologist's names (str) and the values are a list of IDs of the papers 
    authored by the biologist
    
    Returns:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of IDS of papers
    cited by the biologist 
    """
    biologist_cited_papers_dict = {}
    for key, value in biologist_paper_dict.items():
        print("Looking up papers cited by ", key)
        try:
            paper_list = get_and_compile_refs(value)
            biologist_cited_papers_dict[key] = paper_list
        except:
            biologist_cited_papers_dict[key] = []
    return biologist_cited_papers_dict

# %%
the_biologist_cited_papers_dict = create_biologist_cited_papers_dict(the_biologist_paper_dict)
# Out:
# Looking up papers cited by  Abrash, Emily B
# Looking up papers cited by  Ambrose, Jn
# Looking up papers cited by  Anderson, Charles T
# Looking up papers cited by  Andrey, Philippe
# Looking up papers cited by  Arganda-Carreras, Ignacio
# Looking up papers cited by  Asada, Tetsuhiro
# Looking up papers cited by  Azimzadeh, Juliette
# Looking up papers cited by  Barton, Mn
# No references found
# Looking up papers cited by  Baskin, TI
# Looking up papers cited by  Bassel, George W
# Looking up papers cited by  Bassham, Diane C
# Looking up papers cited by  Beauzamy, Lena
# Looking up papers cited by  Becraft, PW
# Looking up papers cited by  Beeckman, Tom
# Looking up papers cited by  Beemster, Gerrit T S
# Looking up papers cited by  Bellaiche, Yohanns
# Looking up papers cited by  Bellinger, Marschal
# Looking up papers cited by  Benfey, Philip N
# Looking up papers cited by  Bent, AF
# Looking up papers cited by  Bergmann, Dominique C
# Looking up papers cited by  Besson, Sebastien
# Looking up papers cited by  Bezanilla, Magdalena
# Looking up papers cited by  Blesch, Armin
# Looking up papers cited by  Bornens, Michel
# Looking up papers cited by  Boruc, Joanna
# Looking up papers cited by  Bosveld, Floris
# Looking up papers cited by  Bouchez, David
# Looking up papers cited by  Boudaoud, Arezki
# Looking up papers cited by  Brady, Siobhan M
# Looking up papers cited by  Braybrook, Siobhan A
# Looking up papers cited by  Bringmann, Martin
# Looking up papers cited by  Brunkard, Jacob O
# Looking up papers cited by  Buer, Charles S
# Looking up papers cited by  Buschmann, Henrik
# Looking up papers cited by  Camilleri, Christine
# Looking up papers cited by  Cardona, Albert
# Looking up papers cited by  Carpita, NC
# Looking up papers cited by  Carthew, Richard W
# Looking up papers cited by  Chakrabortty, Bandan
# Looking up papers cited by  Chan, Jordi
# Looking up papers cited by  Cleary, AL
# Looking up papers cited by  Clough, SJ
# Looking up papers cited by  Cosgrove, Daniel J
# Looking up papers cited by  Costa, Silvia
# Looking up papers cited by  Cutler, SR
# Looking up papers cited by  Cyr, Richard
# Looking up papers cited by  De Smet, Ive
# Looking up papers cited by  Dixit, Ram
# Looking up papers cited by  Dong, Juan
# Looking up papers cited by  Dumais, Jacques
# Looking up papers cited by  Dupuy, Lionel
# Looking up papers cited by  Edgar, BA
# Looking up papers cited by  Egger, Rachel L
# Looking up papers cited by  Facette, Michelle R
# Looking up papers cited by  Fearon, Eric R
# Looking up papers cited by  Feng, Ying
# Looking up papers cited by  Ferreira, P
# Looking up papers cited by  Fisher, Adam P
# Looking up papers cited by  Flanders, DJ
# Looking up papers cited by  Fowke, LC
# Looking up papers cited by  Freeling, M
# Looking up papers cited by  Fukuda, Hiroo
# Looking up papers cited by  Fuller, Margaret T
# Looking up papers cited by  Furutani, I
# Looking up papers cited by  Galletti, Roberta
# Looking up papers cited by  Galva, Charitha
# Looking up papers cited by  Geelen, Danny
# Looking up papers cited by  Gerien, Kenneth S
# Looking up papers cited by  Gibson, Matthew C
# Looking up papers cited by  Gibson, William T
# Looking up papers cited by  Goldstein, Bob
# Looking up papers cited by  Graner, Francois
# Looking up papers cited by  Grebe, Markus
# Looking up papers cited by  Green, PB
# Looking up papers cited by  Gu, Ying
# Looking up papers cited by  Gunning, BES.
# Looking up papers cited by  Gunther, Manuel Ingo
# No references found
# Looking up papers cited by  Hamant, Olivier
# Looking up papers cited by  Hammarton, Tansy C
# Looking up papers cited by  Han, Soon-Ki
# Looking up papers cited by  Hartman, Jh
# Looking up papers cited by  Hartwell, L
# Looking up papers cited by  Hasebe, Mitsuyasu
# Looking up papers cited by  Haseloff, Jim
# Looking up papers cited by  Hashimoto, Takashi
# Looking up papers cited by  Hayashi, Takashi
# Looking up papers cited by  Heisler, Marcus G
# Looking up papers cited by  Hellens, R
# Looking up papers cited by  Hemerly, A
# Looking up papers cited by  Heppert, Jennifer K
# Looking up papers cited by  Herrmann, Arvid
# Looking up papers cited by  Hofte, Herman
# Looking up papers cited by  Hughes, JE
# Looking up papers cited by  Hulskamp, Martin
# Looking up papers cited by  Hussey, Patrick J
# Looking up papers cited by  Iida, Hiroyuki
# Looking up papers cited by  Ingram, Gwyneth C
# Looking up papers cited by  Inze, Dirk
# Looking up papers cited by  Ishida, Takashi
# Looking up papers cited by  Jackson, David
# Looking up papers cited by  Jaquez-Gutierrez, Marybel
# Looking up papers cited by  Jenik, Pablo D
# Looking up papers cited by  Jonsson, Henrik
# Looking up papers cited by  Jurgens, Gerd
# Looking up papers cited by  Kafer, Jos
# Looking up papers cited by  Kajala, Kaisa
# Looking up papers cited by  Kawamura, Eiko
# Looking up papers cited by  Kierzkowski, Daniel
# Looking up papers cited by  Kirik, Angela
# Looking up papers cited by  Kirik, Viktor
# Looking up papers cited by  Kiss, John Z
# Looking up papers cited by  Klee, H
# Looking up papers cited by  Komaki, Shinichiro
# Looking up papers cited by  Komis, George
# Looking up papers cited by  Krupnova, Tamara
# No references found
# Looking up papers cited by  Landrein, Benoit
# Looking up papers cited by  Lang Selker, JM
# Looking up papers cited by  Lee, Yuh-Ru Julie
# Looking up papers cited by  Levy, J
# Looking up papers cited by  Li, Shundai
# Looking up papers cited by  Lintilhac, PM
# Looking up papers cited by  Lipka, Elisabeth
# Looking up papers cited by  Liu, Bo
# Looking up papers cited by  Lloyd, Clive W
# Looking up papers cited by  Lockhart, Jennifer
# Looking up papers cited by  Louveaux, Marion
# Looking up papers cited by  Lynch, TM
# Looking up papers cited by  Maizel, Alexis
# Looking up papers cited by  Marcotrigiano, Michael
# Looking up papers cited by  Marcus, AI
# Looking up papers cited by  Martinez, Pablo
# Looking up papers cited by  Masle, Josette
# Looking up papers cited by  Masson, Patrick H
# Looking up papers cited by  May, Sophie F
# Looking up papers cited by  McCann, MC
# Looking up papers cited by  McPeek, Mark A
# Looking up papers cited by  Megason, Sean G
# Looking up papers cited by  Menges, Margit
# Looking up papers cited by  Meyerowitz, Elliot M
# Looking up papers cited by  Migliaccio, F
# Looking up papers cited by  Millar, Katherine D L
# Looking up papers cited by  Minc, Nicolas
# Looking up papers cited by  Mir, Ricardo
# Looking up papers cited by  Mirabet, Vincent
# Looking up papers cited by  Mohanty, Amitabh
# Looking up papers cited by  Moreno, Vicente
# Looking up papers cited by  Moukhtar, Julien
# Looking up papers cited by  Mulder, Bela M
# Looking up papers cited by  Muller, Sabine
# Looking up papers cited by  Murata, Takashi
# Looking up papers cited by  Murray, James A H
# Looking up papers cited by  Nakamura, Masayoshi
# Looking up papers cited by  Neufeld, TP
# Looking up papers cited by  Neuteboom, LW
# Looking up papers cited by  Northcote, DH
# Looking up papers cited by  Paredez, Alexander R
# Looking up papers cited by  Pastuglia, Martine
# Looking up papers cited by  Peifer, Mark
# Looking up papers cited by  Peterson, Kylee M
# Looking up papers cited by  Pickett-Heaps, JD
# Looking up papers cited by  Piconese, S
# Looking up papers cited by  Piel, Matthieu
# Looking up papers cited by  Pierre, Anaelle
# Looking up papers cited by  Pietra, Stefano
# Looking up papers cited by  Poulton, John S
# Looking up papers cited by  Preibisch, Stephan
# Looking up papers cited by  Provart, Nicholas J
# Looking up papers cited by  Rasmussen, Carolyn G
# Looking up papers cited by  Roy, Rahul
# Looking up papers cited by  Rui, Yue
# Looking up papers cited by  Russinova, Eugenia
# Looking up papers cited by  Sablowski, Robert
# Looking up papers cited by  Sack, FD
# Looking up papers cited by  Sahlin, Patrik
# Looking up papers cited by  Sakaguchi, Jun
# Looking up papers cited by  Sakamoto, Wataru
# Looking up papers cited by  Samaj, Jozef
# Looking up papers cited by  Sammut, M.
# Looking up papers cited by  Sampathkumar, Arun
# Looking up papers cited by  Schaefer, Didier G
# Looking up papers cited by  Schaefer, Estelle
# Looking up papers cited by  Schaffner, Anton R
# Looking up papers cited by  Schindelin, Johannes
# Looking up papers cited by  Schulz, Burkhard
# Looking up papers cited by  Sebastian Seung, H
# No references found
# Looking up papers cited by  Sedbrook, John C
# Looking up papers cited by  Serrano-Mislata, Antonio
# Looking up papers cited by  Shao, Wanchen
# Looking up papers cited by  Shapiro, Bruce E
# Looking up papers cited by  Shen, Li
# Looking up papers cited by  Smertenko, Andrei P
# Looking up papers cited by  Smith, Laurie G
# Looking up papers cited by  Smith, Richard S
# Looking up papers cited by  Somerville, Chris R
# Looking up papers cited by  Sozzani, Rosangela
# Looking up papers cited by  Spinner, Lara
# Looking up papers cited by  Stockle, Dorothee
# Looking up papers cited by  Sugimoto, Keiko
# Looking up papers cited by  Sylvester, AW
# Looking up papers cited by  Szymanski, Dan
# Looking up papers cited by  Takada, Shinobu
# Looking up papers cited by  Thery, Manuel
# Looking up papers cited by  Thitamadee, Siripong
# Looking up papers cited by  Tomancak, Pavel
# Looking up papers cited by  Torii, Keiko U
# Looking up papers cited by  Van Damme, Daniel
# Looking up papers cited by  Van Norman, Jaimie M
# Looking up papers cited by  Vofely, Roza V
# Looking up papers cited by  Voxeur, Aline
# Looking up papers cited by  Wachsman, Guy
# Looking up papers cited by  Wadsworth, Patricia
# Looking up papers cited by  Walbot, Virginia
# Looking up papers cited by  Walker, Keely L
# Looking up papers cited by  Wang, H
# Looking up papers cited by  Wasteneys, Geoffrey O
# Looking up papers cited by  Weijers, Dolf
# Looking up papers cited by  Weizbauer, Renate
# Looking up papers cited by  Whittington, AT
# Looking up papers cited by  Wick, SM
# Looking up papers cited by  Willis, Lisa
# Looking up papers cited by  Winter, Debbie
# Looking up papers cited by  Wright, Amanda J
# Looking up papers cited by  Wu, Jian-Qiu
# Looking up papers cited by  Wu, Qingyu
# Looking up papers cited by  Wu, Shu-Zon
# Looking up papers cited by  Xiong, Fengzhu
# Looking up papers cited by  Yamashita, Yukiko M
# Looking up papers cited by  Yoshida, Saiko
# Looking up papers cited by  Yuen, Christen Y L
# Looking up papers cited by  Zambryski, Patricia C
# Looking up papers cited by  Zarsky, Viktor
# Looking up papers cited by  Zhang, Yanwen
# Looking up papers cited by  Zhao, L
# Looking up papers cited by  Zhu, Chuanmei
# Looking up papers cited by  van Dop, Maritza
# Looking up papers cited by  van der Zaal, BJ
# Looking up papers cited by  von Wangenheim, Daniel

# %%
# combine all the cited papers (removing duplicates) to create the feature set aka repo vocabulary

def create_paper_features_list(biologist_cited_papers_dict):
    """Takes a dictionary of cited papers and combines them into a list with no duplicates.
    
    Arguments:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of paper IDs cited in 
    papers authored by the biologist
    
    Returns:
    paper_features - list; list of all the papers cited by every author in the starting dict (no duplicates)
    """
    paper_features_temp = []
    for value in biologist_cited_papers_dict.values():
        paper_features_temp.extend(value)
    print(len(paper_features_temp))    
    paper_features = list(set(paper_features_temp))
    print(len(paper_features))
    return paper_features

# %%
the_paper_features_list = create_paper_features_list(the_biologist_cited_papers_dict)
# Out:
# 220727
# 137462

# %%
# run every author against the feature set to create a binary vector that contains a 1 if they cited a paper or a 0 if not

def create_binary_feature_vectors(biologist_cited_papers_dict, paper_features_list):
    """Builds a set of feature vectors for each biologist (key) in the biologist_cited_papers_dict by looking to see 
    if each paper in the paper_feature_list is cited by the biologist (a list of cited papers is the value associated 
    with each biologist key).  Adds a one to the feature vector if the paper is cited and a 0 if it is not. 
    
    Arguments:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of paper IDs cited 
    in papers authored by the biologist 
    paper_features_list - list; list of all the papers cited by every author in the starting dict
    
    Returns:
    all_binary_feature_vectors - list of lists; lists of 1s and 0s that indicate if a biologist cited a paper in the 
    paper_features_list or not
    """
    all_binary_feature_vectors = []
    for key, value in biologist_cited_papers_dict.items():
        biologist_vector = []
        for paper in paper_features_list:
            if paper in value:
                biologist_vector.append(1)
            else:
                biologist_vector.append(0)
        all_binary_feature_vectors.append(biologist_vector)
    return all_binary_feature_vectors

# %%
the_binary_feature_vectors = create_binary_feature_vectors(the_biologist_cited_papers_dict, the_paper_features_list)

# %%
def create_comparison_binary_vector(paper_list, paper_features_list):
    """Builds a feature vector for the originating set of papers by looking to see if each paper in the paper_
    features_list is cited by any of the originating set of papers. Adds a one to the feature vector if the paper is 
    cited and a 0 if it is not. 
    
    Arguments:
    paper_list - list; list of paper IDs (str) corresponding to the originating set of papers
    paper_features_list - list; list of all the papers cited by every author in the biologist_cited_papers_dict
    
    Returns:
    comparision_binary_vector - list; list of 1s and 0s that indicate if the originating set of papers cited a paper
    in the paper_features_list or not
    """
    comparison_binary_vector = []
    comparison_refs = get_and_compile_refs(chosen_papers)
    for i in paper_features_list:
        if i in comparison_refs:
            comparison_binary_vector.append(1)
        else:
            comparison_binary_vector.append(0)
    return comparison_binary_vector

# %%
the_comparision_binary_vector = create_comparison_binary_vector(chosen_papers, the_paper_features_list)

# %%
def create_biologist_finder_df(binary_feature_vectors, paper_features_list, biologist_cited_papers_dict, comparison_vector):
    """Takes the binary feature vectors and comparison binary vector and builds a pandas dataframe that has biologist's names
    as the index and paper IDs as the columns.  Dataframe is filled with 1s and 0s to indicate if a biologist has cited
    the column paper or not. The last row contains the data for the originating set of papers. 
    
    Arguments: 
    binary_feature_vectors - list of lists; lists of 0s and 1s that indicate if a biologist cited a paper in the 
    paper_features_list
    paper_features_list - list; list of all the papers cited by every author in the starting dict
    biologist_cited_papers_dict - dict; keys are biologist names (str) and the values are a list of paper IDS 
    corresponding to papers cited by the biologist
    comparison_vector - list; list of 0s and 1s that indicates if the originating set of papers cited a paper
    in the paper_features_list
    
    Returns:
    final_df - Pandas df; has biologist's names as the index and paper IDs as the columns.  Dataframe is filled with 
    1s and 0s to indicate if a biologist has cited the column paper or not. The last row represents the originating 
    set of papers and is indexed as "comparison" 
    """
    temp_df = pd.DataFrame(binary_feature_vectors, columns=paper_features_list, index=biologist_cited_papers_dict.keys())
    comp_series = pd.Series(comparison_vector).to_frame("comparison").T
    comp_series.columns = temp_df.columns
    final_df = pd.concat([temp_df, comp_series])
    final_df.dropna(axis=0, inplace=True)
    return final_df

# %%
bf_df = create_biologist_finder_df(the_binary_feature_vectors, the_paper_features_list, the_biologist_cited_papers_dict, 
                                   the_comparision_binary_vector, name)

# %%
bf_df.shape
# Out:
# (238, 137462)

# %%
bf_df.head()
# Out:
#                            18337155  20379956  20974816  15048123  24249263  \
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            30178601  20625003  25657044  20926419  23711327  \
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            ...  23970914  11877373  12239373  24012599  \
# Abrash, Emily B            ...         0         0         0         0
# Ambrose, Jn                ...         0         0         0         0
# Anderson, Charles T        ...         0         0         0         0
# Andrey, Philippe           ...         0         0         0         0
# Arganda-Carreras, Ignacio  ...         0         0         0         0
#
#                            26523777  24921257  23318657  25089249  11430871  \
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            12195433
# Abrash, Emily B                   0
# Ambrose, Jn                       0
# Anderson, Charles T               0
# Andrey, Philippe                  0
# Arganda-Carreras, Ignacio         0
#
# [5 rows x 137462 columns]

# %%
bf_df.tail()
# Out:
#                         18337155  20379956  20974816  15048123  24249263  \
# Zhu, Chuanmei                  0         0         0         0         0
# van Dop, Maritza               0         0         0         0         0
# van der Zaal, BJ               0         0         0         0         0
# von Wangenheim, Daniel         0         0         0         0         0
# comparision                    0         0         0         0         0
#
#                         30178601  20625003  25657044  20926419  23711327  ...  \
# Zhu, Chuanmei                  0         0         0         0         0  ...
# van Dop, Maritza               0         0         0         0         0  ...
# van der Zaal, BJ               0         0         0         0         0  ...
# von Wangenheim, Daniel         0         0         0         0         0  ...
# comparision                    0         0         0         0         0  ...
#
#                         23970914  11877373  12239373  24012599  26523777  \
# Zhu, Chuanmei                  0         0         0         0         0
# van Dop, Maritza               0         0         0         0         0
# van der Zaal, BJ               0         0         0         0         0
# von Wangenheim, Daniel         0         0         0         0         0
# comparision                    0         0         0         0         0
#
#                         24921257  23318657  25089249  11430871  12195433
# Zhu, Chuanmei                  0         0         0         0         0
# van Dop, Maritza               0         0         0         0         0
# van der Zaal, BJ               0         0         0         0         0
# von Wangenheim, Daniel         0         0         0         0         0
# comparision                    0         0         0         0         0
#
# [5 rows x 137462 columns]

# %%
from fastparquet import write

write('Rasmussen_ver3_df.parq',bf_df)

# %%
# Find out which scientists are closest to the original scientist.

from sklearn.metrics import jaccard_similarity_score
from scipy.stats import pearsonr

# %%
def create_similarity_scores_df(biologist_finder_df):
    """
    """
    from sklearn.metrics import jaccard_similarity_score
    from scipy.stats import pearsonr
    sim_score = {}
    for i in range(len(biologist_finder_df)):
        score = pearsonr(biologist_finder_df.iloc[-1,:], biologist_finder_df.iloc[i, :])
        sim_score.update({i: score[0]})
    sim_df = pd.Series(sim_score).to_frame("similarity")
    sim_df["Scientist"]= biologist_finder_df.index
    sorted_sim_df = sim_df.sort_values('similarity', ascending=False)
    return sorted_sim_df

# %%
ss_df = create_similarity_scores_df(bf_df)
# Out:
# /Users/ajwright/anaconda3/envs/my_conda/lib/python3.7/site-packages/scipy/stats/stats.py:3399: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
ss_df.shape
# Out:
# (238, 2)

# %%
top_15_per = int(author_num * .15)
print(top_15_per)
sorted_sim_df.head(top_15_per)

# %%
# function to return a list of the X% of scientists on the list

def return_most_sim_biologists(similarity_df, per):
    """
    """
    num_biologists = similarity_df.shape[0]
    top_per = int(num_biologists * per)
    print(similarity_df.head(top_per)
    return similarity_df.head(top_per)

# %%
def get_citations(rec_paper_list):
    """
    """
    id_list = ",".join(rec_paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=id_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    handle = Entrez.efetch(db="pubmed", id=id_list, rettype='medline', retmode='text', webenv=webenv, query_key=query_key)
    records = Medline.parse(handle)
    for index, record in enumerate(records, 1):
        print("{}. {} {}. {}. {}. ({})".format(index, record.get("TI", "?"), record.get("AU", "?"), record.get("JT", "?"),
                                         record.get("DP", "?"), record.get("PMID", "?")))

# %%
# function to return a list of the shared citations of the X% of scientists on the list

def return_most_cited_papers(biologist_finder_df, most_sim_biologist_df):
    """
    """
    top_per_biologists = list(most_sim_biologist_df.iloc[1:, 1])
    num_top_biologists = len(top_per_biologists)
    most_cited_papers = biologist_finder_df.loc[top_per_biologist, :][biologist_finder_df.loc[top_per_biologist, :] ==1].fillna(0).T
    most_cited_papers['sum'] = most_cited_papers.sum(axis=1)
    most_cited_papers_sort = most_cited_papers.sort_values('sum', ascending=False)
    
    total_num_papers = most_cited_papers_sort.shape[0]
    print("{} papers were cited by at least one of the most similar biologists.".format(total_num_papers))
    25_per_df = top_per_biologist *.25
    print("{} papers were cited at least once by 25% of the most similar biologists".format())
    print("{} papers were cited at least once by 50% of the most similar biologists".format())
    print("{} papers were cited at least once by 75% of the most similar biologists".format())
    print("{} papers were cited at least once by 100% of the most similar biologists".format())
    print("Papers are now sorted by most cited to least cited.")
    num_papers = input("How many papers do you want on the recommended reading list?")
    get_citations(most_cited_papers_sort[iloc[num_papers, :].index.to_list())

# %%
# function for interaction

# %%
top_15per_scientists = list(sorted_sim_df.iloc[1:top_15_per+1, 1])

# %%
recommendations_15 = final_df.loc[top_15per_scientists, :][final_df.loc[top_15per_scientists, :]==1].fillna(0).T

# %%
recommendations_15.shape

# %%
recommendations_15['sum'] = recommendations_15.sum(axis=1)

# %%
recommendations_15_sort = recommendations_15.sort_values('sum', ascending=False)

# %%
rank = recommendations_15_sort.iloc[30, -1]
rank

# %%
def get_citations(rec_paper_list):
    id_list = ",".join(rec_paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=id_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    handle = Entrez.efetch(db="pubmed", id=id_list, rettype='medline', retmode='text', webenv=webenv, query_key=query_key)
    records = Medline.parse(handle)
    for index, record in enumerate(records, 1):
        print("{}. {} {}. {}. {}. ({})".format(index, record.get("TI", "?"), record.get("AU", "?"), record.get("JT", "?"),
                                         record.get("DP", "?"), record.get("PMID", "?")))


get_citations(recommendations_15_sort[recommendations_15_sort["sum"] >= rank].index.to_list())

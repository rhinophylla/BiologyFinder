# %%
# To improve, add key word cross validation!

# %%
import pandas as pd
from Bio import Entrez
from Bio import Medline
from fastparquet import write
from scipy.stats import pearsonr

# %%
# PubMed credentials
Entrez.email = "ajwright@gmail.com"
Entrez.api_key = "86ac8038bfc913213f007df2803127ebc908"

# %%
def user_entered_info():
    """Stores user-provided scientist name and affiliation.
    
    Arguments:
    none
    
    Returns:
    name - str; scientist name in the format "firstname middleinit lastname"
    affiliation - str; scientist's institutional affiliation
    """
    print("Type the answer to each question then press return.  If you do not know the answer, just hit return.")
    first_name = input("What is the first name of the scientist of interest? ")
    middle_name = input("What is the middle initial of the scientist of interest? ")
    try:
        middle_initial = middle_name[0]
    except IndexError:
        middle_initial = ""
    last_name = input("What is the last name of the scientist of interest? ")
    affliation = input("What is the affiliation of the scientist of interest? No abbreviations, please. ")
    name = "{0} {1} {2}".format(first_name.lower(), middle_initial.lower(), last_name.lower())
    return name, affliation

# %%
# Obtains name and affiliation of the biologist of interest
name, affiliation = user_entered_info()
# Out:
# Type the answer to each question then press return.  If you do not know the answer, just hit return.
# What is the first name of the scientist of interest? Carolyn
# What is the middle initial of the scientist of interest? G
# What is the last name of the scientist of interest? Rasmussen
# What is the affliation of the scientist of interest? No abbreviations please. University of California Riverside

# %%
print(name, affiliation)
# Out:
# carolyn g rasmussen University of California Riverside

# %%
def get_scientist_papers(name, affiliation=None):
    """Searches PubMed for papers whose author list and affiliation list contain the provided author name and
    affiliation. 
    
    Arguments:
    name - str; complete scientist name in the format "lastname, firstname middleinitial"
    affiliation (optional) - str
    
    Returns:
    ids - list; list of paper IDs
    webenv - str; used to reference cached NCBI search session in future efetch queries
    query_key - str; used to reference cached NCBI search session in future efetch queries
    """
    if affiliation == None:
        handle = Entrez.esearch(db='pubmed', term=name, retmax=200, usehistory="y")
    else: 
        terms = "{} AND {}".format(name, affiliation)
        handle = Entrez.esearch(db='pubmed', term=terms, retmax=200, usehistory="y")
    record = Entrez.read(handle)
    ids = record['IdList']
    webenv = record["WebEnv"]
    query_key = record["QueryKey"]
    return ids, webenv, query_key

# %%
# Retrieves papers authored by the biologist of interest
id_list, webenv, query_key = get_scientist_papers(name, affiliation)

# %%
def user_selected_papers(id_list, webenv, query_key):
    """Allows the user to select up to 3 papers authored by a scientist of interest. Uses NCBI cached search
    history.
    
    Arguments:  
    id_list - list; paper ids
    webenv - str; used to reference cached NCBI search session in efetch queries
    query_key - str; used to reference cached NCBI search session in efetch queries
    
    Returns 
    select_list - list; paper ids of user selected papers
    """ 
    from Bio import Medline
    print("Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
    handle = Entrez.efetch(db="pubmed", id=id_list, rettype='medline', retmode='text', webenv=webenv, query_key=query_key)
    records = Medline.parse(handle)
    for index, record in enumerate(records, 1):
        print("{}. {} {}. {}. {}. ({})".format(index, record.get("TI", "?"), record.get("AU", "?"), record.get("JT", "?"),
                                         record.get("DP", "?"), record.get("PMID", "?")))
    paper_num = input("Which papers would you like to select? ")
    paper_num = paper_num.split(',')
    #print(paper_num)
    while paper_num == ['']:
        paper_num = input("No papers selected.  Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
        paper_num = paper_num.split(',')
    while len(paper_num) > 4:
        paper_num = input("Too many papers selected.  Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.")
        paper_num = paper_num.split(',')
    select_list = []
    for num in paper_num:
        select_list.append(id_list[int(num)-1])
    return select_list

# %%
# User specifies up to 3 papers authored by the biologist of interest to base BiologyFinder session on
chosen_papers = user_selected_papers(id_list, webenv, query_key)
# Out:
# Please select up to 3 papers by keying in the corresponding number(s). Seperate each number by a comma.
# 1. Cell-Based Model of the Generation and Maintenance of the Shape and Structure of the Multilayered Shoot Apical Meristem of Arabidopsis thaliana. ['Banwarth-Kuhn M', 'Nematbakhsh A', 'Rodriguez KW', 'Snipes S', 'Rasmussen CG', 'Reddy GV', 'Alber M']. Bulletin of mathematical biology. 2019 Aug. (30552627)
# 2. A plane choice: coordinating timing and orientation of cell division during plant development. ['Facette MR', 'Rasmussen CG', 'Van Norman JM']. Current opinion in plant biology. 2019 Feb. (30261337)
# 3. Predicting Division Planes of Three-Dimensional Cells by Soap-Film Minimization. ['Martinez P', 'Allsman LA', 'Brakke KA', 'Hoyt C', 'Hayes J', 'Liang H', 'Neher W', 'Rui Y', 'Roberts AM', 'Moradifam A', 'Goldstein B', 'Anderson CT', 'Rasmussen CG']. The Plant cell. 2018 Oct. (30150312)
# 4. The Microtubule-Associated Protein IQ67 DOMAIN5 Modulates Microtubule Dynamics and Pavement Cell Shape. ['Liang H', 'Zhang Y', 'Martinez P', 'Rasmussen CG', 'Xu T', 'Yang Z']. Plant physiology. 2018 Aug. (29976837)
# 5. An overview of plant division-plane orientation. ['Rasmussen CG', 'Bellinger M']. The New phytologist. 2018 Jul. (29701870)
# 6. Division Plane Orientation Defects Revealed by a Synthetic Double Mutant Phenotype. ['Mir R', 'Morris VH', 'Buschmann H', 'Rasmussen CG']. Plant physiology. 2018 Jan. (29146775)
# 7. Proper division plane orientation and mitotic progression together allow normal growth of maize. ['Martinez P', 'Luo A', 'Sylvester A', 'Rasmussen CG']. Proceedings of the National Academy of Sciences of the United States of America. 2017 Mar 7. (28202734)
# 8. A DII Domain-Based Auxin Reporter Uncovers Low Auxin Signaling during Telophase and Early G1. ['Mir R', 'Aranda LZ', 'Biaocchi T', 'Luo A', 'Sylvester AW', 'Rasmussen CG']. Plant physiology. 2017 Jan. (27881728)
# 9. Using Live-Cell Markers in Maize to Analyze Cell Division Orientation and Timing. ['Rasmussen CG']. Methods in molecular biology (Clifton, N.J.). 2016. (26659965)
# Which papers would you like to select? 3,6,7

# %%
print(chosen_papers)
# Out:
# ['30150312', '29146775', '28202734']

# %%
def compile_refs_and_citedin(paper_list):
    """Takes a list of paper IDs and returns a list of the IDs for papers referenced in the original paper list.  The 
    reference list may be incomplete since PubMed does not provide references for all papers.  If concerned, run
    the related function 'compile_refs' to identify which papers are missing references.
    
    Arguments:
    paper_list - list; paper IDs (str)
    
    Returns:
    pubmed_refs - list; paper IDs (str)
    """
    str_paper_list = ",".join(paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=str_paper_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", WebEnv=webenv, query_key=query_key))
    ref_ids = []
    for entry in pub_records[0]["LinkSetDb"]:
        if entry["LinkName"] == 'pubmed_pubmed_refs':
            refs = entry["Link"]
            try:
                for ref in refs:
                    ref_ids.append(ref['Id'])
            except UnboundLocalError:
                print("No references found")        
        if entry["LinkName"] == 'pubmed_pubmed_citedin':
            cites = entry["Link"]
            try:
                for cite in cites:
                    ref_ids.append(cite['Id'])
            except UnboundLocalError:
                print("No cited in found")
    print("Length ref_ids list", len(ref_ids))
    print("Length ref_ids set", len(set(ref_ids)))
    return list(set(ref_ids))

# %%
# Ian has provided the ref IDs for the papers of interest, so I do not need to run compile_refs_and_citedin

ref_IDs_8970153 = ['24827152', '24296585', '23812750', '22836995', '26225566', '10731023', '9360927', 
                     '15514006', '18794201', '9021050', '1597853', '26891037', '15457682', '26225771', '12682019', 
                     '12134017', '11698284', '25822022', '22292937', '21461149', '22500169', '26047941', '27189225',
                     '22074367', '27349729', '26974532', '19564922', '24385908', '27350006', '16014943', '27768313', 
                     '28473734', '28067535', '15284245', '19924079', '23270785']
ref_IDs_Tietjen_2016 = ['3016298', '25569520', '23330927', '23812750', '16182382', '18671200', '24152939', '10731023',
                        '21860787', '2944961', '22326358', '22465592', '26152583', '22817991', '25522685',
                        '15081276', '20542300', '23289738', '10616956', '23450245', '18678237', '25493601', '25830320',
                        '17504362', '31634862', '15951145', '23210782']
ref_IDs_Yang_2019 = ['24827152', '23984250', '28714868', '22837004', '25402363', '19897215', '19100719', '22020221',
                     '11514226', '19696893', '7665567', '23255218', '26681773', '24658076', '27977742', '9371822',
                     '25730868', '10611346', '26225566', '22836995', '22814509', '27757411', '26199173', '23541084',
                     '23134979', '22739395', '26614966', '19239360', '9360927', '9287228', '26891037', '26775808', 
                     '24804860', '25287643', '26225771', '29457784', '12682019', '11285236', '23907534', '25375990',
                     '11698284', '23087374', '30031972', '25963564', '21498519', '25014309', '9144290', '12563294', 
                     '23804764', '26974532', '23370291', '26423811', '26690612', '19265012','18525257','23536672',
                     '23517573', '26169416', '26691297', '30481211', '12350140', '28842560', '24722454', '27898737',
                     '15284245', '9360926', '23270785', '24896263']
ref_IDs_Sun_2019 = ['18833270', '21051991', '24107261', '25185360', '25190350', '26577109', '25361696', '26699285',
                    '25533861', '21287791']

ref_IDs_Mediouni_2018 = ['14999114', '21848464', '11533182', '18264102', '19933330', '10721995', '14610207', 
                         '10332737', '10644369', '9641673', '21377881', '22470838', '14998221', '14519027', '22686620',
                         '16251317', '19249948', '22001594', '23009669', '21355238', '26048637', '25679337', '20036771', 
                         '24339367', '23677886', '24760888', '20145735', '12386343', '15040537', '16302461',
                         '1975844', '26035023', '28099856', '28679752', '21357743', '21672195', '10581250', '15797855',
                         '22817991', '26995550', '19493996', '26152583', '12554735', '15947137', '26810656',
                         '12719560']

ref_IDs_Wang_2017 = ['26577109', '21695615', '7603178', '19295331', '19852669', '27349729', '26130226', '20467286']

# %%
all_ref_IDs = ref_IDs_8970153 + ref_IDs_Tietjen_2016 + ref_IDs_Yang_2019 + ref_IDs_Sun_2019 + ref_IDs_Mediouni_2018 + ref_IDs_Wang_2017
print(len(all_ref_IDs))
print(len(set(all_ref_IDs)))
# Out:
# 195
# 178

# %%
def get_first_last_authors(paper_id):
    """Given a paper, returns the first and last authors of the paper.
    
    Arguments:
    paper_id - str; paper ids
    
    Returns:
    authors - list of strs; list of full names of the first and last authors of the provided paper id
    """
    handle = Entrez.efetch(db='pubmed', id=paper_id, rettype='medline', retmode="text", retmax=200)
    record = Medline.read(handle)
    authors = record.get("FAU", "?")
    first_last_authors = [authors[0], authors[-1]]
    print(first_last_authors)
    return first_last_authors

# %%
def author_formatting(author_list):
    """Changes the formatting of author name strings to give the best PubMed search results. 
    
    Arguments:
    author_list - list of str; list of author names
    
    Returns:
    formatted_author_list - list of str; alphabetized list of author names formatted "lastname, firstname"
    """
    formatted_author_list = []
    for author in author_list:
        print(author)
        last_name = author.split(',')[0]
        first_name = author.split(',')[1].lstrip()
        try:
            if first_name[1] == " ":
                try:
                    first_name = first_name[0] + first_name[-1]
                except:
                    first_name = first_name[0]
        except:            
            first_name = first_name[0]
        new_name = "{}, {}".format(last_name, first_name)
        print(new_name)
        formatted_author_list.append(new_name)
    return sorted(formatted_author_list)

# %%
def remove_duplicates(sorted_list):
    """Takes a sorted list of authors and if 2 authors have the same last name and first initial, removes the name
    with only the first initial leaving behind the one that has the full first name. 
    
    Arguments:
    sorted_list - list; alphabetized list of authors in the format "lastname, firstname middleinit" OR 
    "lastname, firstinit middleinit"
    
    Returns:
    author_no_dup_list - list; alphabetized list of authors with duplicates removed 
    """
    author_no_dup_list = []
    most_recent_author = " , "
    for i, author in enumerate(sorted_list):
        if author.split(',')[0] == most_recent_author.split(',')[0]:
            if author.split(',')[1].lstrip()[0] != most_recent_author.split(',')[1].lstrip()[0]:
                author_no_dup_list.append(author)
                #print("(1) Compared {} to {} and appended {}".format(author, most_recent_author, author))
            else:
                #print("(2) Compared {} to {} and deleted {} and appended {}".format(author, most_recent_author, author_no_dup_list[-1], author)) 
                del author_no_dup_list[-1]
                author_no_dup_list.append(author)                       
        else:
            author_no_dup_list.append(author)
            #print("(3) Compared {} to {} and appended {}".format(author, most_recent_author, author))
        most_recent_author = author
    return author_no_dup_list

# %%
def create_master_biologist_list(paper_list):
    """Searches PubMed for all the papers cited by or that cites a paper on the paper list.  Returns a list
    of the first and last authors of those papers (duplicates removed).
    
    Arguments:
    paper_list - list; paper IDs (str)
    
    Returns: 
    biologist_master_list - list; biologist names (str)
    """
    ref_citedin_ids = compile_refs_and_citedin(paper_list)
    first_last_author_list = []   
    for paper in ref_citedin_ids:
        print("Getting the authors of paper {}.".format(paper))
        authors = get_first_last_authors(paper)
        first_last_author_list.extend(authors) 
    set_f_l_author_list = list(set(first_last_author_list)) 
    print(len(set_f_l_author_list))
    format_f_l_author_list = author_formatting(set_f_l_author_list)
    print(len(format_f_l_author_list))
    no_dup_f_l_author_list = remove_duplicates(format_f_l_author_list)
    print(len(no_dup_f_l_author_list))
    return no_dup_f_l_author_list

# %%
def create_master_biologist_list_from_refIDS(ref_IDs):
    first_last_author_list = []   
    for paper in ref_IDs:
        print("Getting the authors of paper {}.".format(paper))
        authors = get_first_last_authors(paper)
        first_last_author_list.extend(authors) 
    set_f_l_author_list = list(set(first_last_author_list)) 
    print(len(set_f_l_author_list))
    format_f_l_author_list = author_formatting(set_f_l_author_list)
    print(len(format_f_l_author_list))
    no_dup_f_l_author_list = remove_duplicates(format_f_l_author_list)
    print(len(no_dup_f_l_author_list))
    return no_dup_f_l_author_list

# %%
master_biologist_list = create_master_biologist_list_from_refIDS(set(all_ref_IDs))
# Out:
# Getting the authors of paper 25569520.
# ['Akkouh, Ouafae', 'Cheung, Randy Chi Fai']
# Getting the authors of paper 20145735.
# ['Lara, Humberto H', 'Rodriguez-Padilla, Cristina']
# Getting the authors of paper 19933330.
# ['Cicala, Claudia', 'Arthos, James']
# Getting the authors of paper 20542300.
# ['Mulholland, Dulcie A', 'Nuzillard, Jean-Marc']
# Getting the authors of paper 28067535.
# ['Wang, Yifei', 'Suo, Zucai']
# Getting the authors of paper 15947137.
# ['Lindenbach, Brett D', 'Rice, Charles M']
# Getting the authors of paper 15951145.
# ['Woradulayapinij, Warunya', 'Wiwat, Chanpen']
# Getting the authors of paper 24722454.
# ['Wei, Datsen George', 'Cihlar, Tomas']
# Getting the authors of paper 24760888.
# ['Abram, Michael E', 'Hughes, Stephen H']
# Getting the authors of paper 27350006.
# ['Tietjen, Ian', 'Andrae-Marobela, Kerstin']
# Getting the authors of paper 25402363.
# ['Archin, Nancie M', 'Margolis, David M']
# Getting the authors of paper 31634862.
# ['Wensing, Annemarie M', 'Richman, Douglas D']
# Getting the authors of paper 10721995.
# ['Geijtenbeek, T B', 'van Kooyk, Y']
# Getting the authors of paper 21672195.
# ['Rapista, Aprille', 'Chang, Theresa L']
# Getting the authors of paper 19265012.
# ['Richman, Douglas D', 'Pomerantz, Roger J']
# Getting the authors of paper 25287643.
# ['Jiang, Guochun', 'Dandekar, Satya']
# Getting the authors of paper 21848464.
# ['Wainberg, Mark A', 'Brenner, Bluma G']
# Getting the authors of paper 21498519.
# ['Micheva-Viteva, Sofiya', 'Dougherty, Joseph P']
# Getting the authors of paper 14999114.
# ['Clavel, Francois', 'Hance, Allan J']
# Getting the authors of paper 14610207.
# ['Gummuluru, Suryaram', 'Emerman, Michael']
# Getting the authors of paper 21860787.
# ['Kalyesubula, Robert', 'Perazella, Mark A']
# Getting the authors of paper 19924079.
# ['Wu, Qi-Cheng', 'Duan, Jin-Ao']
# Getting the authors of paper 9021050.
# ['Gulakowski, R J', 'Boyd, M R']
# Getting the authors of paper 22814509.
# ['Deeks, Steven G', 'Barre-Sinoussi, Francoise']
# Getting the authors of paper 12134017.
# ['Korin, Yael D', 'Zack, Jerome A']
# Getting the authors of paper 15040537.
# ['Witvrouw, Myriam', 'Heneine, Walid']
# Getting the authors of paper 18525257.
# ['Sagot-Lerolle, Nathalie', 'Lambotte, Olivier']
# Getting the authors of paper 1597853.
# ['Gustafson, K R', 'Beutler, J A']
# Getting the authors of paper 30031972.
# ['Liu, Qingbo', 'Koike, Kazuo']
# Getting the authors of paper 22470838.
# ['Didigu, Chukwuka A', 'Doms, Robert W']
# Getting the authors of paper 16251317.
# ['Dorr, Patrick', 'Perros, Manos']
# Getting the authors of paper 22292937.
# ['Lubinga, S J', 'Asiimwe, S']
# Getting the authors of paper 19100719.
# ['Bedoya, Luis M', 'Alcami, Jose']
# Getting the authors of paper 11533182.
# ['Saphire, A C', 'Gallay, P A']
# Getting the authors of paper 26199173.
# ['Diaz, Laura', 'Munoz-Fernandez, Ma Angeles']
# Getting the authors of paper 26775808.
# ['Ji, Haiyan', 'Zhu, Huanzhang']
# Getting the authors of paper 12350140.
# ['Wang, Li-Yan', 'Kitanaka, Susumu']
# Getting the authors of paper 20467286.
# ['Lok, Judith J', 'Hughes, Michael D']
# Getting the authors of paper 18678237.
# ['Nyiligira, E', 'Steenkamp, P A']
# Getting the authors of paper 22001594.
# ['Fessel, W Jeffrey', 'Shafer, Robert W']
# Getting the authors of paper 10616956.
# ['Ndubani, P', 'Hojer, B']
# Getting the authors of paper 21357743.
# ['Ruprecht, Claudia R', 'Trkola, Alexandra']
# Getting the authors of paper 18833270.
# ['Lu, Lin', 'Zhang, Linqi']
# Getting the authors of paper 19249948.
# ['Hunt, Joshua S', 'Romanelli, Frank']
# Getting the authors of paper 21355238.
# ['Li, Guohui', 'Wang, Yitao']
# Getting the authors of paper 12386343.
# ['Ren, J', 'Stammers, D K']
# Getting the authors of paper 28679752.
# ['Fellinger, Christoph H', 'Farzan, Michael']
# Getting the authors of paper 27349729.
# ['Poorolajal, J', 'Jenabi, E']
# Getting the authors of paper 25493601.
# ['Pham, Quang D', 'Zhang, Lei']
# Getting the authors of paper 14998221.
# ['Hardy, Helene', 'Skolnik, Paul R']
# Getting the authors of paper 26614966.
# ['Elliott, Julian H', 'Lewin, Sharon R']
# Getting the authors of paper 22074367.
# ['Namuddu, Betty', 'Waako, Paul']
# Getting the authors of paper 22020221.
# ['Bernhard, Wendy', 'Sadowski, Ivan']
# Getting the authors of paper 16014943.
# ['Trushin, Sergey A', 'Badley, Andrew D']
# Getting the authors of paper 28842560.
# ['Wang, Pengfei', 'Zhu, Huanzhang']
# Getting the authors of paper 24339367.
# ['Zhou, Yan-Xi', 'Peng, Cheng']
# Getting the authors of paper 15284245.
# ['Williams, Samuel A', 'Greene, Warner C']
# Getting the authors of paper 28714868.
# ['Archin, Nancie M', 'Margolis, David M']
# Getting the authors of paper 26169416.
# ['Spivak, Adam M', 'Planelles, Vicente']
# Getting the authors of paper 26974532.
# ['Rasmussen, Thomas A', 'Lewin, Sharon R']
# Getting the authors of paper 30481211.
# ['Valadao, Ana Luiza Chaves', 'Tanuri, Amilcar']
# Getting the authors of paper 21287791.
# ['Wang, Jian', 'Zou, Wen']
# Getting the authors of paper 26130226.
# ['Lu, Wei', 'Routy, Jean-Pierre']
# Getting the authors of paper 10731023.
# ['El-Mekkawy, S', 'Otake, T']
# Getting the authors of paper 27768313.
# ['Wang, Meng', 'Andersen, Raymond J']
# Getting the authors of paper 26047941.
# ['Nlooto, Manimbulu', 'Nlooto, Manimbulu']
# Getting the authors of paper 7603178.
# ['Wu, Z', 'Detels, R']
# Getting the authors of paper 19696893.
# ['Blazkova, Jana', 'Hirsch, Ivan']
# Getting the authors of paper 26891037.
# ['Gutierrez, Carolina', 'Moreno, Santiago']
# Getting the authors of paper 23087374.
# ['Li, Zichong', 'Zhou, Qiang']
# Getting the authors of paper 23804764.
# ['Qu, Xiying', 'Zhu, Huanzhang']
# Getting the authors of paper 16302461.
# ['Poveda, Eva', 'Soriano, Vincent']
# Getting the authors of paper 28099856.
# ['Rausch, Keiko', 'Cherry, Sara']
# Getting the authors of paper 24152939.
# ['Deeks, Steven G', 'Havlir, Diane V']
# Getting the authors of paper 27898737.
# ['White, Cory H', 'Woelk, Christopher H']
# Getting the authors of paper 26423811.
# ['Rasmussen, Thomas A', 'Sogaard, Ole S']
# Getting the authors of paper 25522685.
# ['Mthethwa, Ningy S', 'Aiyegoro, Olayinka A']
# Getting the authors of paper 25185360.
# ['Jin, Yantao', 'Xu, Liran']
# Getting the authors of paper 19493996.
# ['Pan, Chungen', 'Jiang, Shibo']
# Getting the authors of paper 26152583.
# ['Mousseau, Guillaume', 'Valente, Susana T']
# Getting the authors of paper 23517573.
# ['Shirakawa, Kotaro', 'Verdin, Eric']
# Getting the authors of paper 23536672.
# ['Shan, Liang', 'Siliciano, Robert F']
# Getting the authors of paper 2944961.
# ['Kim, D K', 'Fitch, F W']
# Getting the authors of paper 27189225.
# ['Nlooto, Manimbulu', 'Naidoo, Panjasaram']
# Getting the authors of paper 15457682.
# ['Hezareh, Marjan', 'Foti, Michelangelo']
# Getting the authors of paper 19852669.
# ['Okulicz, Jason F', 'Dolan, Matthew J']
# Getting the authors of paper 12682019.
# ['Jordan, Albert', 'Verdin, Eric']
# Getting the authors of paper 25533861.
# ['Wang, Lan', 'Wang, Lu']
# Getting the authors of paper 15797855.
# ['Vives, Romain R', 'Lortat-Jacob, Hugues']
# Getting the authors of paper 28473734.
# ['Wang, Yifei', 'Suo, Zucai']
# Getting the authors of paper 12563294.
# ['Peterlin, B Matija', 'Trono, Didier']
# Getting the authors of paper 27757411.
# ['Delagreverie, Heloise M', 'Li, Jonathan Z']
# Getting the authors of paper 25375990.
# ['Kim, Michelle', 'Siliciano, Robert F']
# Getting the authors of paper 21051991.
# ['Chow, Eric Pui Fung', 'Zhang, Lei']
# Getting the authors of paper 23812750.
# ['Beans, Elizabeth J', 'Wender, Paul A']
# Getting the authors of paper 25830320.
# ['Tietjen, Ian', 'Fedida, David']
# Getting the authors of paper 26577109.
# ['Zou, Wen', 'Liu, Ying']
# Getting the authors of paper 20036771.
# ['Du, G', 'Wang, Y T']
# Getting the authors of paper 3016298.
# ['Adachi, A', 'Martin, M A']
# Getting the authors of paper 22739395.
# ['Doyon, Genevieve', 'Sluis-Cremer, Nicolas']
# Getting the authors of paper 18264102.
# ['Arthos, James', 'Fauci, Anthony S']
# Getting the authors of paper 26699285.
# ['Liu, Zhi-Bin', 'Xu, Li-Ran']
# Getting the authors of paper 10581250.
# ['Saphire, A C', 'Gallay, P A']
# Getting the authors of paper 22326358.
# ['Leteane, Melvin M', 'Andrae-Marobela, Kerstin']
# Getting the authors of paper 18794201.
# ['Green, Lawrence W', 'Green, Lawrence W']
# Getting the authors of paper 12554735.
# ['Carroll, Steven S', 'Olsen, David B']
# Getting the authors of paper 24827152.
# ['Abreu, Celina M', 'Gama, Lucio']
# Getting the authors of paper 9641673.
# ['Moore, J P', 'Binley, J']
# Getting the authors of paper 26225771.
# ['Jiang, Guochun', 'Dandekar, Satya']
# Getting the authors of paper 9287228.
# ['Gulick, R M', 'Chodakewitz, J A']
# Getting the authors of paper 19897215.
# ['Avila, Liliana', 'Echeverri, Fernando']
# Getting the authors of paper 24296585.
# ['Archin, Nancie M', 'Margolis, David M']
# Getting the authors of paper 23255218.
# ['Boehm, Daniela', 'Ott, Melanie']
# Getting the authors of paper 25190350.
# ['Wang, Jian', 'Wang, Yuguang']
# Getting the authors of paper 14519027.
# ['Duffalo, Melody L', 'James, Christopher W']
# Getting the authors of paper 19239360.
# ['Archin, Nancie M', 'Margolis, David M']
# Getting the authors of paper 11698284.
# ['Kulkosky, J', 'Pomerantz, R J']
# Getting the authors of paper 25679337.
# ['Liu, Bingrui', 'Staerk, Dan']
# Getting the authors of paper 26690612.
# ['Rasmussen, Thomas Aagaard', 'Sogaard, Ole Schmeltz']
# Getting the authors of paper 25014309.
# ['Pandelo Jose, Diego', 'Aguiar, Renato Santana']
# Getting the authors of paper 11514226.
# ['Blanco-Molina, M', 'Appendino, G']
# Getting the authors of paper 9360927.
# ['Finzi, D', 'Siliciano, R F']
# Getting the authors of paper 23907534.
# ['Jorgensen, Lars', 'Baran, Phil S']
# Getting the authors of paper 26225566.
# ['Darcis, Gilles', 'Van Lint, Carine']
# Getting the authors of paper 26035023.
# ['Sato, Yuichiro', 'Hori, Kanji']
# Getting the authors of paper 27977742.
# ['Cary, Daniele C', 'Peterlin, B Matija']
# Getting the authors of paper 9360926.
# ['Wong, J K', 'Richman, D D']
# Getting the authors of paper 19564922.
# ['Reuse, Sophie', 'Van Lint, Carine']
# Getting the authors of paper 22836995.
# ['Deeks, Steven G', 'Deeks, Steven G']
# Getting the authors of paper 9144290.
# ['Perelson, A S', 'Ho, D D']
# Getting the authors of paper 23210782.
# ['Zhou, Xuefeng', 'Liu, Yonghong']
# Getting the authors of paper 26048637.
# ['Penetar, David M', 'Lukas, Scott E']
# Getting the authors of paper 22837004.
# ['Archin, N M', 'Margolis, D M']
# Getting the authors of paper 26681773.
# ['Bouchat, Sophie', 'Van Lint, Carine']
# Getting the authors of paper 23289738.
# ['Mwimanzi, Philip', 'Ueno, Takamasa']
# Getting the authors of paper 25963564.
# ['Miana, Ghulam Abbas', 'Paracha, Usman Zafar']
# Getting the authors of paper 22686620.
# ['Tang, Michele W', 'Shafer, Robert W']
# Getting the authors of paper 19295331.
# ['Madec, Yoann', 'Rouzioux, Christine']
# Getting the authors of paper 23450245.
# ['Ngo, Linh T', 'Folk, William R']
# Getting the authors of paper 15081276.
# ['Mulholland, Dulcie A', 'Drewes, Siegfried E']
# Getting the authors of paper 29457784.
# ['Jiang, Guochun', 'Dandekar, Satya']
# Getting the authors of paper 23009669.
# ['Zhong, Yu', 'Zhao, Yanyun']
# Getting the authors of paper 24658076.
# ['Bullen, C Korin', 'Siliciano, Robert F']
# Getting the authors of paper 24107261.
# ['Zhang, Lei', 'Wilson, David P']
# Getting the authors of paper 23370291.
# ['Rasmussen, Thomas Aagaard', 'Tolstrup, Martin']
# Getting the authors of paper 23270785.
# ['Xing, Sifei', 'Siliciano, Robert F']
# Getting the authors of paper 12719560.
# ['Binley, James M', 'Burton, Dennis R']
# Getting the authors of paper 26691297.
# ['Spivak, Adam M', 'Planelles, Vicente']
# Getting the authors of paper 25730868.
# ['Claiborne, Daniel T', 'Hunter, Eric']
# Getting the authors of paper 24385908.
# ['Spina, Celsa A', 'Planelles, Vicente']
# Getting the authors of paper 10332737.
# ['Clapham, P R', 'McKnight, A']
# Getting the authors of paper 21695615.
# ['Wang, Jian', 'Zou, Wen']
# Getting the authors of paper 23134979.
# ['Doan, Hung Q', 'Levis, William R']
# Getting the authors of paper 10611346.
# ['Davey, R T Jr', 'Lane, H C']
# Getting the authors of paper 23984250.
# ['Aditya, Suruchi', 'Gupta, Sanjeev']
# Getting the authors of paper 26995550.
# ['Tallarida, Ronald J', 'Tallarida, Ronald J']
# Getting the authors of paper 10644369.
# ['Kwong, P D', 'Hendrickson, W A']
# Getting the authors of paper 25822022.
# ['Laird, Gregory M', 'Siliciano, Robert F']
# Getting the authors of paper 7665567.
# ['Lopez-Cabrera, M', 'Sanchez-Madrid, F']
# Getting the authors of paper 24804860.
# ['Jiang, Guochun', 'Dandekar, Satya']
# Getting the authors of paper 18671200.
# ['Cos, Paul', 'Pieters, Luc']
# Getting the authors of paper 25361696.
# ['Zhao, Tingting', 'Dang, Chao']
# Getting the authors of paper 26810656.
# ['Thenin-Houssier, Suzie', 'Valente, Susana T']
# Getting the authors of paper 15514006.
# ['George, Prince', 'Bhalla, Kapil']
# Getting the authors of paper 17504362.
# ['Waters, L', 'Nelson, M']
# Getting the authors of paper 23541084.
# ['Ding, Donglin', 'Zhu, Huanzhang']
# Getting the authors of paper 16182382.
# ['Brockman, Mark A', 'Allen, Todd M']
# Getting the authors of paper 22500169.
# ['McKernan, Lisa N', 'Kulkosky, Joseph']
# Getting the authors of paper 22817991.
# ['Mousseau, Guillaume', 'Valente, Susana T']
# Getting the authors of paper 23330927.
# ['Andrae-Marobela, Kerstin', 'Majinda, Runner R T']
# Getting the authors of paper 11285236.
# ['Jordan, A', 'Verdin, E']
# Getting the authors of paper 23677886.
# ['Zhang, Zhen', 'Zuo, Zhong']
# Getting the authors of paper 9371822.
# ['Chun, T W', 'Fauci, A S']
# Getting the authors of paper 21461149.
# ['Madiba, Sphiwe E', 'Madiba, Sphiwe E']
# Getting the authors of paper 24896263.
# ['Yan, Xiaojing', 'Duan, Jin-Ao']
# Getting the authors of paper 22465592.
# ['Lubbe, Andrea', 'van der Kooy, Frank']
# Getting the authors of paper 21377881.
# ['Caffrey, Michael', 'Caffrey, Michael']
# Getting the authors of paper 1975844.
# ['Schulz, T F', 'Weiss, R A']
# 297
# Kulkosky, Joseph
# Kulkosky, Joseph
# Delagreverie, Heloise M
# Delagreverie, Heloise M
# Beans, Elizabeth J
# Beans, Elizabeth J
# Liu, Zhi-Bin
# Liu, Zhi-Bin
# Binley, James M
# Binley, James M
# Moore, J P
# Moore, JP
# Zhou, Xuefeng
# Zhou, Xuefeng
# Gustafson, K R
# Gustafson, KR
# Kim, Michelle
# Kim, Michelle
# Ding, Donglin
# Ding, Donglin
# Bouchat, Sophie
# Bouchat, Sophie
# Mousseau, Guillaume
# Mousseau, Guillaume
# Trkola, Alexandra
# Trkola, Alexandra
# Emerman, Michael
# Emerman, Michael
# Mthethwa, Ningy S
# Mthethwa, Ningy S
# Perelson, A S
# Perelson, AS
# Aiyegoro, Olayinka A
# Aiyegoro, Olayinka A
# Ndubani, P
# Ndubani, P
# Aditya, Suruchi
# Aditya, Suruchi
# Wang, Y T
# Wang, YT
# Detels, R
# Detels, R
# Ruprecht, Claudia R
# Ruprecht, Claudia R
# Rasmussen, Thomas Aagaard
# Rasmussen, Thomas Aagaard
# Koike, Kazuo
# Koike, Kazuo
# Wang, Lu
# Wang, Lu
# Waters, L
# Waters, L
# Qu, Xiying
# Qu, Xiying
# Brenner, Bluma G
# Brenner, Bluma G
# Binley, J
# Binley, J
# Caffrey, Michael
# Caffrey, Michael
# Otake, T
# Otake, T
# Liu, Bingrui
# Liu, Bingrui
# George, Prince
# George, Prince
# Korin, Yael D
# Korin, Yael D
# Wang, Yifei
# Wang, Yifei
# Lubinga, S J
# Lubinga, SJ
# Zuo, Zhong
# Zuo, Zhong
# McKernan, Lisa N
# McKernan, Lisa N
# Asiimwe, S
# Asiimwe, S
# Verdin, Eric
# Verdin, Eric
# Ji, Haiyan
# Ji, Haiyan
# Sato, Yuichiro
# Sato, Yuichiro
# Wong, J K
# Wong, JK
# Chodakewitz, J A
# Chodakewitz, JA
# Valente, Susana T
# Valente, Susana T
# Lindenbach, Brett D
# Lindenbach, Brett D
# Zhang, Lei
# Zhang, Lei
# Echeverri, Fernando
# Echeverri, Fernando
# Skolnik, Paul R
# Skolnik, Paul R
# Sanchez-Madrid, F
# Sanchez-Madrid, F
# Saphire, A C
# Saphire, AC
# Finzi, D
# Finzi, D
# Lambotte, Olivier
# Lambotte, Olivier
# Fauci, A S
# Fauci, AS
# van Kooyk, Y
# van Kooyk, Y
# Kalyesubula, Robert
# Kalyesubula, Robert
# Wu, Qi-Cheng
# Wu, Qi-Cheng
# Fellinger, Christoph H
# Fellinger, Christoph H
# Gupta, Sanjeev
# Gupta, Sanjeev
# Lu, Lin
# Lu, Lin
# Hunter, Eric
# Hunter, Eric
# Richman, Douglas D
# Richman, Douglas D
# Alcami, Jose
# Alcami, Jose
# Madec, Yoann
# Madec, Yoann
# Yan, Xiaojing
# Yan, Xiaojing
# Doyon, Genevieve
# Doyon, Genevieve
# Kulkosky, J
# Kulkosky, J
# Williams, Samuel A
# Williams, Samuel A
# Gama, Lucio
# Gama, Lucio
# Jenabi, E
# Jenabi, E
# Martin, M A
# Martin, MA
# Gulick, R M
# Gulick, RM
# Chun, T W
# Chun, TW
# Doan, Hung Q
# Doan, Hung Q
# Zou, Wen
# Zou, Wen
# Hughes, Stephen H
# Hughes, Stephen H
# Barre-Sinoussi, Francoise
# Barre-Sinoussi, Francoise
# Wang, Meng
# Wang, Meng
# Peng, Cheng
# Peng, Cheng
# Arthos, James
# Arthos, James
# Jordan, Albert
# Jordan, Albert
# Hance, Allan J
# Hance, Allan J
# Madiba, Sphiwe E
# Madiba, Sphiwe E
# Paracha, Usman Zafar
# Paracha, Usman Zafar
# Kitanaka, Susumu
# Kitanaka, Susumu
# Levis, William R
# Levis, William R
# Weiss, R A
# Weiss, RA
# Soriano, Vincent
# Soriano, Vincent
# Claiborne, Daniel T
# Claiborne, Daniel T
# Drewes, Siegfried E
# Drewes, Siegfried E
# Pomerantz, Roger J
# Pomerantz, Roger J
# Fedida, David
# Fedida, David
# Akkouh, Ouafae
# Akkouh, Ouafae
# Trushin, Sergey A
# Trushin, Sergey A
# Jin, Yantao
# Jin, Yantao
# Wilson, David P
# Wilson, David P
# Dang, Chao
# Dang, Chao
# Dorr, Patrick
# Dorr, Patrick
# Dougherty, Joseph P
# Dougherty, Joseph P
# Gallay, P A
# Gallay, PA
# Lok, Judith J
# Lok, Judith J
# Majinda, Runner R T
# Majinda, Runner R T
# Zhou, Yan-Xi
# Zhou, Yan-Xi
# Verdin, E
# Verdin, E
# Pham, Quang D
# Pham, Quang D
# Blanco-Molina, M
# Blanco-Molina, M
# Cicala, Claudia
# Cicala, Claudia
# Tanuri, Amilcar
# Tanuri, Amilcar
# Woelk, Christopher H
# Woelk, Christopher H
# Olsen, David B
# Olsen, David B
# Chang, Theresa L
# Chang, Theresa L
# Suo, Zucai
# Suo, Zucai
# Naidoo, Panjasaram
# Naidoo, Panjasaram
# Pieters, Luc
# Pieters, Luc
# Routy, Jean-Pierre
# Routy, Jean-Pierre
# Reuse, Sophie
# Reuse, Sophie
# Fauci, Anthony S
# Fauci, Anthony S
# Li, Jonathan Z
# Li, Jonathan Z
# Liu, Ying
# Liu, Ying
# Liu, Yonghong
# Liu, Yonghong
# Jiang, Guochun
# Jiang, Guochun
# Andersen, Raymond J
# Andersen, Raymond J
# Jiang, Shibo
# Jiang, Shibo
# Siliciano, Robert F
# Siliciano, Robert F
# Kim, D K
# Kim, DK
# Xu, Liran
# Xu, Liran
# Shan, Liang
# Shan, Liang
# Hojer, B
# Hojer, B
# Darcis, Gilles
# Darcis, Gilles
# Nuzillard, Jean-Marc
# Nuzillard, Jean-Marc
# Deeks, Steven G
# Deeks, Steven G
# Havlir, Diane V
# Havlir, Diane V
# Lewin, Sharon R
# Lewin, Sharon R
# Witvrouw, Myriam
# Witvrouw, Myriam
# Zhou, Qiang
# Zhou, Qiang
# Peterlin, B Matija
# Peterlin, Ba
# Green, Lawrence W
# Green, Lawrence W
# Hori, Kanji
# Hori, Kanji
# Allen, Todd M
# Allen, Todd M
# Clavel, Francois
# Clavel, Francois
# Ott, Melanie
# Ott, Melanie
# Wender, Paul A
# Wender, Paul A
# Mwimanzi, Philip
# Mwimanzi, Philip
# Woradulayapinij, Warunya
# Woradulayapinij, Warunya
# Badley, Andrew D
# Badley, Andrew D
# Wang, Jian
# Wang, Jian
# Farzan, Michael
# Farzan, Michael
# Bedoya, Luis M
# Bedoya, Luis M
# Trono, Didier
# Trono, Didier
# Rapista, Aprille
# Rapista, Aprille
# Li, Guohui
# Li, Guohui
# Ngo, Linh T
# Ngo, Linh T
# Dandekar, Satya
# Dandekar, Satya
# Perazella, Mark A
# Perazella, Mark A
# Andrae-Marobela, Kerstin
# Andrae-Marobela, Kerstin
# Hirsch, Ivan
# Hirsch, Ivan
# Planelles, Vicente
# Planelles, Vicente
# Penetar, David M
# Penetar, David M
# Doms, Robert W
# Doms, Robert W
# Ren, J
# Ren, J
# Spina, Celsa A
# Spina, Celsa A
# Sagot-Lerolle, Nathalie
# Sagot-Lerolle, Nathalie
# Perros, Manos
# Perros, Manos
# Tolstrup, Martin
# Tolstrup, Martin
# Wang, Pengfei
# Wang, Pengfei
# Diaz, Laura
# Diaz, Laura
# Siliciano, R F
# Siliciano, RF
# van der Kooy, Frank
# van der Kooy, Frank
# Thenin-Houssier, Suzie
# Thenin-Houssier, Suzie
# Munoz-Fernandez, Ma Angeles
# Munoz-Fernandez, Ma Angeles
# Nelson, M
# Nelson, M
# Wainberg, Mark A
# Wainberg, Mark A
# Sluis-Cremer, Nicolas
# Sluis-Cremer, Nicolas
# Heneine, Walid
# Heneine, Walid
# Elliott, Julian H
# Elliott, Julian H
# Tietjen, Ian
# Tietjen, Ian
# Van Lint, Carine
# Van Lint, Carine
# Nlooto, Manimbulu
# Nlooto, Manimbulu
# Hunt, Joshua S
# Hunt, Joshua S
# Rasmussen, Thomas A
# Rasmussen, Thomas A
# Okulicz, Jason F
# Okulicz, Jason F
# Wu, Z
# Wu, Z
# Lane, H C
# Lane, HC
# Moreno, Santiago
# Moreno, Santiago
# Staerk, Dan
# Staerk, Dan
# Blazkova, Jana
# Blazkova, Jana
# Dolan, Matthew J
# Dolan, Matthew J
# Wang, Yuguang
# Wang, Yuguang
# Lortat-Jacob, Hugues
# Lortat-Jacob, Hugues
# Margolis, David M
# Margolis, David M
# Shirakawa, Kotaro
# Shirakawa, Kotaro
# Zhao, Tingting
# Zhao, Tingting
# Liu, Qingbo
# Liu, Qingbo
# Burton, Dennis R
# Burton, Dennis R
# Zhu, Huanzhang
# Zhu, Huanzhang
# Wang, Lan
# Wang, Lan
# Kwong, P D
# Kwong, PD
# Valadao, Ana Luiza Chaves
# Valadao, Ana Luiza Chaves
# Cos, Paul
# Cos, Paul
# Zhang, Zhen
# Zhang, Zhen
# Rausch, Keiko
# Rausch, Keiko
# Bernhard, Wendy
# Bernhard, Wendy
# Richman, D D
# Richman, DD
# Lara, Humberto H
# Lara, Humberto H
# Appendino, G
# Appendino, G
# Bhalla, Kapil
# Bhalla, Kapil
# Cihlar, Tomas
# Cihlar, Tomas
# Aguiar, Renato Santana
# Aguiar, Renato Santana
# Micheva-Viteva, Sofiya
# Micheva-Viteva, Sofiya
# Ueno, Takamasa
# Ueno, Takamasa
# Didigu, Chukwuka A
# Didigu, Chukwuka A
# El-Mekkawy, S
# El-Mekkawy, S
# Duan, Jin-Ao
# Duan, Jin-Ao
# Carroll, Steven S
# Carroll, Steven S
# Jordan, A
# Jordan, A
# Zack, Jerome A
# Zack, Jerome A
# Rouzioux, Christine
# Rouzioux, Christine
# Abram, Michael E
# Abram, Michael E
# Vives, Romain R
# Vives, Romain R
# Fessel, W Jeffrey
# Fessel, Wy
# Mulholland, Dulcie A
# Mulholland, Dulcie A
# Cheung, Randy Chi Fai
# Cheung, Randy Chi Fai
# Spivak, Adam M
# Spivak, Adam M
# Abreu, Celina M
# Abreu, Celina M
# McKnight, A
# McKnight, A
# Leteane, Melvin M
# Leteane, Melvin M
# Stammers, D K
# Stammers, DK
# Hezareh, Marjan
# Hezareh, Marjan
# Zhao, Yanyun
# Zhao, Yanyun
# Foti, Michelangelo
# Foti, Michelangelo
# Lu, Wei
# Lu, Wei
# Gulakowski, R J
# Gulakowski, RJ
# Beutler, J A
# Beutler, JA
# Steenkamp, P A
# Steenkamp, PA
# Greene, Warner C
# Greene, Warner C
# Geijtenbeek, T B
# Geijtenbeek, TB
# Laird, Gregory M
# Laird, Gregory M
# Cary, Daniele C
# Cary, Daniele C
# Poorolajal, J
# Poorolajal, J
# Lubbe, Andrea
# Lubbe, Andrea
# Margolis, D M
# Margolis, DM
# Pan, Chungen
# Pan, Chungen
# James, Christopher W
# James, Christopher W
# Poveda, Eva
# Poveda, Eva
# Archin, N M
# Archin, NM
# Sogaard, Ole S
# Sogaard, Ole S
# Davey, R T Jr
# Davey, Rr
# Lopez-Cabrera, M
# Lopez-Cabrera, M
# Fitch, F W
# Fitch, FW
# Hardy, Helene
# Hardy, Helene
# Rice, Charles M
# Rice, Charles M
# Tallarida, Ronald J
# Tallarida, Ronald J
# Wei, Datsen George
# Wei, Datsen George
# Pandelo Jose, Diego
# Pandelo Jose, Diego
# Shafer, Robert W
# Shafer, Robert W
# Waako, Paul
# Waako, Paul
# Zhong, Yu
# Zhong, Yu
# Schulz, T F
# Schulz, TF
# Pomerantz, R J
# Pomerantz, RJ
# Sadowski, Ivan
# Sadowski, Ivan
# Boyd, M R
# Boyd, MR
# Archin, Nancie M
# Archin, Nancie M
# Li, Zichong
# Li, Zichong
# Jorgensen, Lars
# Jorgensen, Lars
# Baran, Phil S
# Baran, Phil S
# Cherry, Sara
# Cherry, Sara
# Boehm, Daniela
# Boehm, Daniela
# Bullen, C Korin
# Bullen, Cn
# Hendrickson, W A
# Hendrickson, WA
# Romanelli, Frank
# Romanelli, Frank
# Ho, D D
# Ho, DD
# Wiwat, Chanpen
# Wiwat, Chanpen
# Namuddu, Betty
# Namuddu, Betty
# Zhang, Linqi
# Zhang, Linqi
# Wang, Yitao
# Wang, Yitao
# Du, G
# Du, G
# Rodriguez-Padilla, Cristina
# Rodriguez-Padilla, Cristina
# Xu, Li-Ran
# Xu, Li-Ran
# Avila, Liliana
# Avila, Liliana
# Wang, Li-Yan
# Wang, Li-Yan
# Gutierrez, Carolina
# Gutierrez, Carolina
# White, Cory H
# White, Cory H
# Chow, Eric Pui Fung
# Chow, Eric Pui Fung
# Duffalo, Melody L
# Duffalo, Melody L
# Miana, Ghulam Abbas
# Miana, Ghulam Abbas
# Clapham, P R
# Clapham, PR
# Lukas, Scott E
# Lukas, Scott E
# Nyiligira, E
# Nyiligira, E
# Folk, William R
# Folk, William R
# Gummuluru, Suryaram
# Gummuluru, Suryaram
# Hughes, Michael D
# Hughes, Michael D
# Tang, Michele W
# Tang, Michele W
# Adachi, A
# Adachi, A
# Wensing, Annemarie M
# Wensing, Annemarie M
# Sogaard, Ole Schmeltz
# Sogaard, Ole Schmeltz
# Brockman, Mark A
# Brockman, Mark A
# Xing, Sifei
# Xing, Sifei
# 297
# 277

# %%
def create_biologist_paper_dict(biologist_list):
    """Takes a list of biologists and looks up the IDs of all the papers they authored in PubMed.  Returns
    a dictionary where the biologist's name is the key and the value is a list of their paper IDs. 
    
    Arguments:
    biologist_list - list; biologist names (str)
    
    Returns:
    biologist_paper_dict - dict; keys are biologist names (str) and the values are a list of IDs of the papers 
    authored by the biologist
    """
    biologist_papers_dict = {}
    for biologist in biologist_list:
        biologist_nocomma = biologist.replace(',', '')
        print("Getting papers authored by {}.".format(biologist_nocomma))
        papers = get_scientist_papers(biologist_nocomma)[0]
        biologist_papers_dict[biologist] = papers
    zero_papers = []
    has_papers = []
    total = 0
    for key, value in biologist_papers_dict.items():
        if len(value) == 0:
            zero_papers.append(key)
        else:
            has_papers.append(key)
        total += len(value)
    print("Total papers:", total)
    print("Zero papers were retrieved for the following authors:", zero_papers)
    print("More than one paper was retrieved for the following authors:", has_papers)
    return biologist_papers_dict

# %%
the_biologist_paper_dict = create_biologist_paper_dict(master_biologist_list)
# Out:
# Getting papers authored by Abram Michael E.
# Getting papers authored by Abreu Celina M.
# Getting papers authored by Adachi A.
# Getting papers authored by Aditya Suruchi.
# Getting papers authored by Aguiar Renato Santana.
# Getting papers authored by Aiyegoro Olayinka A.
# Getting papers authored by Akkouh Ouafae.
# Getting papers authored by Alcami Jose.
# Getting papers authored by Allen Todd M.
# Getting papers authored by Andersen Raymond J.
# Getting papers authored by Andrae-Marobela Kerstin.
# Getting papers authored by Appendino G.
# Getting papers authored by Archin Nancie M.
# Getting papers authored by Arthos James.
# Getting papers authored by Asiimwe S.
# Getting papers authored by Avila Liliana.
# Getting papers authored by Badley Andrew D.
# Getting papers authored by Baran Phil S.
# Getting papers authored by Barre-Sinoussi Francoise.
# Getting papers authored by Beans Elizabeth J.
# Getting papers authored by Bedoya Luis M.
# Getting papers authored by Bernhard Wendy.
# Getting papers authored by Beutler JA.
# Getting papers authored by Bhalla Kapil.
# Getting papers authored by Binley James M.
# Getting papers authored by Blanco-Molina M.
# Getting papers authored by Blazkova Jana.
# Getting papers authored by Boehm Daniela.
# Getting papers authored by Bouchat Sophie.
# Getting papers authored by Boyd MR.
# Getting papers authored by Brenner Bluma G.
# Getting papers authored by Brockman Mark A.
# Getting papers authored by Bullen Cn.
# Getting papers authored by Burton Dennis R.
# Getting papers authored by Caffrey Michael.
# Getting papers authored by Carroll Steven S.
# Getting papers authored by Cary Daniele C.
# Getting papers authored by Chang Theresa L.
# Getting papers authored by Cherry Sara.
# Getting papers authored by Cheung Randy Chi Fai.
# Getting papers authored by Chodakewitz JA.
# Getting papers authored by Chow Eric Pui Fung.
# Getting papers authored by Chun TW.
# Getting papers authored by Cicala Claudia.
# Getting papers authored by Cihlar Tomas.
# Getting papers authored by Claiborne Daniel T.
# Getting papers authored by Clapham PR.
# Getting papers authored by Clavel Francois.
# Getting papers authored by Cos Paul.
# Getting papers authored by Dandekar Satya.
# Getting papers authored by Dang Chao.
# Getting papers authored by Darcis Gilles.
# Getting papers authored by Davey Rr.
# Getting papers authored by Deeks Steven G.
# Getting papers authored by Delagreverie Heloise M.
# Getting papers authored by Detels R.
# Getting papers authored by Diaz Laura.
# Getting papers authored by Didigu Chukwuka A.
# Getting papers authored by Ding Donglin.
# Getting papers authored by Doan Hung Q.
# Getting papers authored by Dolan Matthew J.
# Getting papers authored by Doms Robert W.
# Getting papers authored by Dorr Patrick.
# Getting papers authored by Dougherty Joseph P.
# Getting papers authored by Doyon Genevieve.
# Getting papers authored by Drewes Siegfried E.
# Getting papers authored by Du G.
# Getting papers authored by Duan Jin-Ao.
# Getting papers authored by Duffalo Melody L.
# Getting papers authored by Echeverri Fernando.
# Getting papers authored by El-Mekkawy S.
# Getting papers authored by Elliott Julian H.
# Getting papers authored by Emerman Michael.
# Getting papers authored by Farzan Michael.
# Getting papers authored by Fauci Anthony S.
# Getting papers authored by Fedida David.
# Getting papers authored by Fellinger Christoph H.
# Getting papers authored by Fessel Wy.
# Getting papers authored by Finzi D.
# Getting papers authored by Fitch FW.
# Getting papers authored by Folk William R.
# Getting papers authored by Foti Michelangelo.
# Getting papers authored by Gallay PA.
# Getting papers authored by Gama Lucio.
# Getting papers authored by Geijtenbeek TB.
# Getting papers authored by George Prince.
# Getting papers authored by Green Lawrence W.
# Getting papers authored by Greene Warner C.
# Getting papers authored by Gulakowski RJ.
# Getting papers authored by Gulick RM.
# Getting papers authored by Gummuluru Suryaram.
# Getting papers authored by Gupta Sanjeev.
# Getting papers authored by Gustafson KR.
# Getting papers authored by Gutierrez Carolina.
# Getting papers authored by Hance Allan J.
# Getting papers authored by Hardy Helene.
# Getting papers authored by Havlir Diane V.
# Getting papers authored by Hendrickson WA.
# Getting papers authored by Heneine Walid.
# Getting papers authored by Hezareh Marjan.
# Getting papers authored by Hirsch Ivan.
# Getting papers authored by Ho DD.
# Getting papers authored by Hojer B.
# Getting papers authored by Hori Kanji.
# Getting papers authored by Hughes Michael D.
# Getting papers authored by Hughes Stephen H.
# Getting papers authored by Hunt Joshua S.
# Getting papers authored by Hunter Eric.
# Getting papers authored by James Christopher W.
# Getting papers authored by Jenabi E.
# Getting papers authored by Ji Haiyan.
# Getting papers authored by Jiang Guochun.
# Getting papers authored by Jiang Shibo.
# Getting papers authored by Jin Yantao.
# Getting papers authored by Jordan Albert.
# Getting papers authored by Jorgensen Lars.
# Getting papers authored by Kalyesubula Robert.
# Getting papers authored by Kim DK.
# Getting papers authored by Kim Michelle.
# Getting papers authored by Kitanaka Susumu.
# Getting papers authored by Koike Kazuo.
# Getting papers authored by Korin Yael D.
# Getting papers authored by Kulkosky Joseph.
# Getting papers authored by Kwong PD.
# Getting papers authored by Laird Gregory M.
# Getting papers authored by Lambotte Olivier.
# Getting papers authored by Lane HC.
# Getting papers authored by Lara Humberto H.
# Getting papers authored by Leteane Melvin M.
# Getting papers authored by Levis William R.
# Getting papers authored by Lewin Sharon R.
# Getting papers authored by Li Guohui.
# Getting papers authored by Li Jonathan Z.
# Getting papers authored by Li Zichong.
# Getting papers authored by Lindenbach Brett D.
# Getting papers authored by Liu Bingrui.
# Getting papers authored by Liu Qingbo.
# Getting papers authored by Liu Yonghong.
# Getting papers authored by Liu Zhi-Bin.
# Getting papers authored by Lok Judith J.
# Getting papers authored by Lopez-Cabrera M.
# Getting papers authored by Lortat-Jacob Hugues.
# Getting papers authored by Lu Lin.
# Getting papers authored by Lu Wei.
# Getting papers authored by Lubbe Andrea.
# Getting papers authored by Lubinga SJ.
# Getting papers authored by Lukas Scott E.
# Getting papers authored by Madec Yoann.
# Getting papers authored by Madiba Sphiwe E.
# Getting papers authored by Majinda Runner R T.
# Getting papers authored by Margolis David M.
# Getting papers authored by Martin MA.
# Getting papers authored by McKernan Lisa N.
# Getting papers authored by McKnight A.
# Getting papers authored by Miana Ghulam Abbas.
# Getting papers authored by Micheva-Viteva Sofiya.
# Getting papers authored by Moore JP.
# Getting papers authored by Moreno Santiago.
# Getting papers authored by Mousseau Guillaume.
# Getting papers authored by Mthethwa Ningy S.
# Getting papers authored by Mulholland Dulcie A.
# Getting papers authored by Munoz-Fernandez Ma Angeles.
# Getting papers authored by Mwimanzi Philip.
# Getting papers authored by Naidoo Panjasaram.
# Getting papers authored by Namuddu Betty.
# Getting papers authored by Ndubani P.
# Getting papers authored by Nelson M.
# Getting papers authored by Ngo Linh T.
# Getting papers authored by Nlooto Manimbulu.
# Getting papers authored by Nuzillard Jean-Marc.
# Getting papers authored by Nyiligira E.
# Getting papers authored by Okulicz Jason F.
# Getting papers authored by Olsen David B.
# Getting papers authored by Otake T.
# Getting papers authored by Ott Melanie.
# Getting papers authored by Pan Chungen.
# Getting papers authored by Pandelo Jose Diego.
# Getting papers authored by Paracha Usman Zafar.
# Getting papers authored by Penetar David M.
# Getting papers authored by Peng Cheng.
# Getting papers authored by Perazella Mark A.
# Getting papers authored by Perelson AS.
# Getting papers authored by Perros Manos.
# Getting papers authored by Peterlin Ba.
# Getting papers authored by Pham Quang D.
# Getting papers authored by Pieters Luc.
# Getting papers authored by Planelles Vicente.
# Getting papers authored by Pomerantz Roger J.
# Getting papers authored by Poorolajal J.
# Getting papers authored by Poveda Eva.
# Getting papers authored by Qu Xiying.
# Getting papers authored by Rapista Aprille.
# Getting papers authored by Rasmussen Thomas Aagaard.
# Getting papers authored by Rausch Keiko.
# Getting papers authored by Ren J.
# Getting papers authored by Reuse Sophie.
# Getting papers authored by Rice Charles M.
# Getting papers authored by Richman Douglas D.
# Getting papers authored by Rodriguez-Padilla Cristina.
# Getting papers authored by Romanelli Frank.
# Getting papers authored by Routy Jean-Pierre.
# Getting papers authored by Rouzioux Christine.
# Getting papers authored by Ruprecht Claudia R.
# Getting papers authored by Sadowski Ivan.
# Getting papers authored by Sagot-Lerolle Nathalie.
# Getting papers authored by Sanchez-Madrid F.
# Getting papers authored by Saphire AC.
# Getting papers authored by Sato Yuichiro.
# Getting papers authored by Schulz TF.
# Getting papers authored by Shafer Robert W.
# Getting papers authored by Shan Liang.
# Getting papers authored by Shirakawa Kotaro.
# Getting papers authored by Siliciano Robert F.
# Getting papers authored by Skolnik Paul R.
# Getting papers authored by Sluis-Cremer Nicolas.
# Getting papers authored by Sogaard Ole Schmeltz.
# Getting papers authored by Soriano Vincent.
# Getting papers authored by Spina Celsa A.
# Getting papers authored by Spivak Adam M.
# Getting papers authored by Staerk Dan.
# Getting papers authored by Stammers DK.
# Getting papers authored by Steenkamp PA.
# Getting papers authored by Suo Zucai.
# Getting papers authored by Tallarida Ronald J.
# Getting papers authored by Tang Michele W.
# Getting papers authored by Tanuri Amilcar.
# Getting papers authored by Thenin-Houssier Suzie.
# Getting papers authored by Tietjen Ian.
# Getting papers authored by Tolstrup Martin.
# Getting papers authored by Trkola Alexandra.
# Getting papers authored by Trono Didier.
# Getting papers authored by Trushin Sergey A.
# Getting papers authored by Ueno Takamasa.
# Getting papers authored by Valadao Ana Luiza Chaves.
# Getting papers authored by Valente Susana T.
# Getting papers authored by Van Lint Carine.
# Getting papers authored by Verdin Eric.
# Getting papers authored by Vives Romain R.
# Getting papers authored by Waako Paul.
# Getting papers authored by Wainberg Mark A.
# Getting papers authored by Wang Jian.
# Getting papers authored by Wang Lu.
# Getting papers authored by Wang Meng.
# Getting papers authored by Wang Pengfei.
# Getting papers authored by Wang Yuguang.
# Getting papers authored by Waters L.
# Getting papers authored by Wei Datsen George.
# Getting papers authored by Weiss RA.
# Getting papers authored by Wender Paul A.
# Getting papers authored by Wensing Annemarie M.
# Getting papers authored by White Cory H.
# Getting papers authored by Williams Samuel A.
# Getting papers authored by Wilson David P.
# Getting papers authored by Witvrouw Myriam.
# Getting papers authored by Wiwat Chanpen.
# Getting papers authored by Woelk Christopher H.
# Getting papers authored by Wong JK.
# Getting papers authored by Woradulayapinij Warunya.
# Getting papers authored by Wu Qi-Cheng.
# Getting papers authored by Wu Z.
# Getting papers authored by Xing Sifei.
# Getting papers authored by Xu Liran.
# Getting papers authored by Yan Xiaojing.
# Getting papers authored by Zack Jerome A.
# Getting papers authored by Zhang Linqi.
# Getting papers authored by Zhang Zhen.
# Getting papers authored by Zhao Tingting.
# Getting papers authored by Zhao Yanyun.
# Getting papers authored by Zhong Yu.
# Getting papers authored by Zhou Qiang.
# Getting papers authored by Zhou Xuefeng.
# Getting papers authored by Zhou Yan-Xi.
# Getting papers authored by Zhu Huanzhang.
# Getting papers authored by Zou Wen.
# Getting papers authored by Zuo Zhong.
# Getting papers authored by van Kooyk Y.
# Getting papers authored by van der Kooy Frank.
# Total papers: 23512
# Zero papers were retrieved for the following authors: ['Fessel, Wy']
# More than one paper was retrieved for the following authors: ['Abram, Michael E', 'Abreu, Celina M', 'Adachi, A', 'Aditya, Suruchi', 'Aguiar, Renato Santana', 'Aiyegoro, Olayinka A', 'Akkouh, Ouafae', 'Alcami, Jose', 'Allen, Todd M', 'Andersen, Raymond J', 'Andrae-Marobela, Kerstin', 'Appendino, G', 'Archin, Nancie M', 'Arthos, James', 'Asiimwe, S', 'Avila, Liliana', 'Badley, Andrew D', 'Baran, Phil S', 'Barre-Sinoussi, Francoise', 'Beans, Elizabeth J', 'Bedoya, Luis M', 'Bernhard, Wendy', 'Beutler, JA', 'Bhalla, Kapil', 'Binley, James M', 'Blanco-Molina, M', 'Blazkova, Jana', 'Boehm, Daniela', 'Bouchat, Sophie', 'Boyd, MR', 'Brenner, Bluma G', 'Brockman, Mark A', 'Bullen, Cn', 'Burton, Dennis R', 'Caffrey, Michael', 'Carroll, Steven S', 'Cary, Daniele C', 'Chang, Theresa L', 'Cherry, Sara', 'Cheung, Randy Chi Fai', 'Chodakewitz, JA', 'Chow, Eric Pui Fung', 'Chun, TW', 'Cicala, Claudia', 'Cihlar, Tomas', 'Claiborne, Daniel T', 'Clapham, PR', 'Clavel, Francois', 'Cos, Paul', 'Dandekar, Satya', 'Dang, Chao', 'Darcis, Gilles', 'Davey, Rr', 'Deeks, Steven G', 'Delagreverie, Heloise M', 'Detels, R', 'Diaz, Laura', 'Didigu, Chukwuka A', 'Ding, Donglin', 'Doan, Hung Q', 'Dolan, Matthew J', 'Doms, Robert W', 'Dorr, Patrick', 'Dougherty, Joseph P', 'Doyon, Genevieve', 'Drewes, Siegfried E', 'Du, G', 'Duan, Jin-Ao', 'Duffalo, Melody L', 'Echeverri, Fernando', 'El-Mekkawy, S', 'Elliott, Julian H', 'Emerman, Michael', 'Farzan, Michael', 'Fauci, Anthony S', 'Fedida, David', 'Fellinger, Christoph H', 'Finzi, D', 'Fitch, FW', 'Folk, William R', 'Foti, Michelangelo', 'Gallay, PA', 'Gama, Lucio', 'Geijtenbeek, TB', 'George, Prince', 'Green, Lawrence W', 'Greene, Warner C', 'Gulakowski, RJ', 'Gulick, RM', 'Gummuluru, Suryaram', 'Gupta, Sanjeev', 'Gustafson, KR', 'Gutierrez, Carolina', 'Hance, Allan J', 'Hardy, Helene', 'Havlir, Diane V', 'Hendrickson, WA', 'Heneine, Walid', 'Hezareh, Marjan', 'Hirsch, Ivan', 'Ho, DD', 'Hojer, B', 'Hori, Kanji', 'Hughes, Michael D', 'Hughes, Stephen H', 'Hunt, Joshua S', 'Hunter, Eric', 'James, Christopher W', 'Jenabi, E', 'Ji, Haiyan', 'Jiang, Guochun', 'Jiang, Shibo', 'Jin, Yantao', 'Jordan, Albert', 'Jorgensen, Lars', 'Kalyesubula, Robert', 'Kim, DK', 'Kim, Michelle', 'Kitanaka, Susumu', 'Koike, Kazuo', 'Korin, Yael D', 'Kulkosky, Joseph', 'Kwong, PD', 'Laird, Gregory M', 'Lambotte, Olivier', 'Lane, HC', 'Lara, Humberto H', 'Leteane, Melvin M', 'Levis, William R', 'Lewin, Sharon R', 'Li, Guohui', 'Li, Jonathan Z', 'Li, Zichong', 'Lindenbach, Brett D', 'Liu, Bingrui', 'Liu, Qingbo', 'Liu, Yonghong', 'Liu, Zhi-Bin', 'Lok, Judith J', 'Lopez-Cabrera, M', 'Lortat-Jacob, Hugues', 'Lu, Lin', 'Lu, Wei', 'Lubbe, Andrea', 'Lubinga, SJ', 'Lukas, Scott E', 'Madec, Yoann', 'Madiba, Sphiwe E', 'Majinda, Runner R T', 'Margolis, David M', 'Martin, MA', 'McKernan, Lisa N', 'McKnight, A', 'Miana, Ghulam Abbas', 'Micheva-Viteva, Sofiya', 'Moore, JP', 'Moreno, Santiago', 'Mousseau, Guillaume', 'Mthethwa, Ningy S', 'Mulholland, Dulcie A', 'Munoz-Fernandez, Ma Angeles', 'Mwimanzi, Philip', 'Naidoo, Panjasaram', 'Namuddu, Betty', 'Ndubani, P', 'Nelson, M', 'Ngo, Linh T', 'Nlooto, Manimbulu', 'Nuzillard, Jean-Marc', 'Nyiligira, E', 'Okulicz, Jason F', 'Olsen, David B', 'Otake, T', 'Ott, Melanie', 'Pan, Chungen', 'Pandelo Jose, Diego', 'Paracha, Usman Zafar', 'Penetar, David M', 'Peng, Cheng', 'Perazella, Mark A', 'Perelson, AS', 'Perros, Manos', 'Peterlin, Ba', 'Pham, Quang D', 'Pieters, Luc', 'Planelles, Vicente', 'Pomerantz, Roger J', 'Poorolajal, J', 'Poveda, Eva', 'Qu, Xiying', 'Rapista, Aprille', 'Rasmussen, Thomas Aagaard', 'Rausch, Keiko', 'Ren, J', 'Reuse, Sophie', 'Rice, Charles M', 'Richman, Douglas D', 'Rodriguez-Padilla, Cristina', 'Romanelli, Frank', 'Routy, Jean-Pierre', 'Rouzioux, Christine', 'Ruprecht, Claudia R', 'Sadowski, Ivan', 'Sagot-Lerolle, Nathalie', 'Sanchez-Madrid, F', 'Saphire, AC', 'Sato, Yuichiro', 'Schulz, TF', 'Shafer, Robert W', 'Shan, Liang', 'Shirakawa, Kotaro', 'Siliciano, Robert F', 'Skolnik, Paul ...

# %%
def get_and_compile_refs(paper_list):
    """Takes a list of paper IDs and returns a list of the IDs of the papers referenced by papers in the original list.
    The reference list may be incomplete since PubMed does not provide references for all papers.  If concerned, run
    the related function 'compile_refs' to identify which papers are missing references.
    
    Arguments:
    paper_list - list, paper IDs (str)
    
    Returns:
    pubmed_refs - list, paper IDs 
    """
    str_paper_list = ",".join(paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=str_paper_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    pub_records = Entrez.read(Entrez.elink(dbfrom="pubmed", WebEnv=webenv, query_key=query_key))
    for entry in pub_records[0]["LinkSetDb"]:
        if entry["LinkName"] == 'pubmed_pubmed_refs':
            pubmed_refs = entry["Link"]
    ref_ids = []
    try:
        for ref in pubmed_refs:
            ref_ids.append(ref['Id'])
    except UnboundLocalError:
        print("No references found")
    return ref_ids

# %%
def create_biologist_cited_papers_dict(biologist_paper_dict):
    """Takes a dictionary of biologists and the papers they wrote, looks up each paper in PubMed and returns a new
    dictionary containing the biologist and a list of all the papers they cite(reference) within the papers they wrote. 
    
    Arguments:
    biologist_paper_dict - dict; keys are biologist's names (str) and the values are a list of IDs of the papers 
    authored by the biologist
    
    Returns:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of IDS of papers
    cited by the biologist 
    """
    biologist_cited_papers_dict = {}
    for key, value in biologist_paper_dict.items():
        print("Looking up papers cited by ", key)
        try:
            paper_list = get_and_compile_refs(value)
            biologist_cited_papers_dict[key] = paper_list
        except:
            biologist_cited_papers_dict[key] = []
    return biologist_cited_papers_dict

# %%
the_biologist_cited_papers_dict = create_biologist_cited_papers_dict(the_biologist_paper_dict)
# Out:
# Looking up papers cited by  Abram, Michael E
# Looking up papers cited by  Abreu, Celina M
# Looking up papers cited by  Adachi, A
# Looking up papers cited by  Aditya, Suruchi
# Looking up papers cited by  Aguiar, Renato Santana
# Looking up papers cited by  Aiyegoro, Olayinka A
# Looking up papers cited by  Akkouh, Ouafae
# Looking up papers cited by  Alcami, Jose
# Looking up papers cited by  Allen, Todd M
# Looking up papers cited by  Andersen, Raymond J
# Looking up papers cited by  Andrae-Marobela, Kerstin
# Looking up papers cited by  Appendino, G
# Looking up papers cited by  Archin, Nancie M
# Looking up papers cited by  Arthos, James
# Looking up papers cited by  Asiimwe, S
# Looking up papers cited by  Avila, Liliana
# No references found
# Looking up papers cited by  Badley, Andrew D
# Looking up papers cited by  Baran, Phil S
# Looking up papers cited by  Barre-Sinoussi, Francoise
# Looking up papers cited by  Beans, Elizabeth J
# Looking up papers cited by  Bedoya, Luis M
# Looking up papers cited by  Bernhard, Wendy
# Looking up papers cited by  Beutler, JA
# Looking up papers cited by  Bhalla, Kapil
# Looking up papers cited by  Binley, James M
# Looking up papers cited by  Blanco-Molina, M
# No references found
# Looking up papers cited by  Blazkova, Jana
# Looking up papers cited by  Boehm, Daniela
# Looking up papers cited by  Bouchat, Sophie
# Looking up papers cited by  Boyd, MR
# Looking up papers cited by  Brenner, Bluma G
# Looking up papers cited by  Brockman, Mark A
# Looking up papers cited by  Bullen, Cn
# Looking up papers cited by  Burton, Dennis R
# Looking up papers cited by  Caffrey, Michael
# Looking up papers cited by  Carroll, Steven S
# Looking up papers cited by  Cary, Daniele C
# Looking up papers cited by  Chang, Theresa L
# Looking up papers cited by  Cherry, Sara
# Looking up papers cited by  Cheung, Randy Chi Fai
# Looking up papers cited by  Chodakewitz, JA
# Looking up papers cited by  Chow, Eric Pui Fung
# Looking up papers cited by  Chun, TW
# Looking up papers cited by  Cicala, Claudia
# Looking up papers cited by  Cihlar, Tomas
# Looking up papers cited by  Claiborne, Daniel T
# Looking up papers cited by  Clapham, PR
# Looking up papers cited by  Clavel, Francois
# Looking up papers cited by  Cos, Paul
# Looking up papers cited by  Dandekar, Satya
# Looking up papers cited by  Dang, Chao
# Looking up papers cited by  Darcis, Gilles
# Looking up papers cited by  Davey, Rr
# Looking up papers cited by  Deeks, Steven G
# Looking up papers cited by  Delagreverie, Heloise M
# Looking up papers cited by  Detels, R
# Looking up papers cited by  Diaz, Laura
# Looking up papers cited by  Didigu, Chukwuka A
# Looking up papers cited by  Ding, Donglin
# Looking up papers cited by  Doan, Hung Q
# Looking up papers cited by  Dolan, Matthew J
# Looking up papers cited by  Doms, Robert W
# Looking up papers cited by  Dorr, Patrick
# Looking up papers cited by  Dougherty, Joseph P
# Looking up papers cited by  Doyon, Genevieve
# Looking up papers cited by  Drewes, Siegfried E
# No references found
# Looking up papers cited by  Du, G
# Looking up papers cited by  Duan, Jin-Ao
# Looking up papers cited by  Duffalo, Melody L
# No references found
# Looking up papers cited by  Echeverri, Fernando
# Looking up papers cited by  El-Mekkawy, S
# Looking up papers cited by  Elliott, Julian H
# Looking up papers cited by  Emerman, Michael
# Looking up papers cited by  Farzan, Michael
# Looking up papers cited by  Fauci, Anthony S
# Looking up papers cited by  Fedida, David
# Looking up papers cited by  Fellinger, Christoph H
# Looking up papers cited by  Fessel, Wy
# Looking up papers cited by  Finzi, D
# Looking up papers cited by  Fitch, FW
# Looking up papers cited by  Folk, William R
# Looking up papers cited by  Foti, Michelangelo
# Looking up papers cited by  Gallay, PA
# Looking up papers cited by  Gama, Lucio
# Looking up papers cited by  Geijtenbeek, TB
# Looking up papers cited by  George, Prince
# Looking up papers cited by  Green, Lawrence W
# Looking up papers cited by  Greene, Warner C
# Looking up papers cited by  Gulakowski, RJ
# Looking up papers cited by  Gulick, RM
# Looking up papers cited by  Gummuluru, Suryaram
# Looking up papers cited by  Gupta, Sanjeev
# Looking up papers cited by  Gustafson, KR
# Looking up papers cited by  Gutierrez, Carolina
# Looking up papers cited by  Hance, Allan J
# Looking up papers cited by  Hardy, Helene
# Looking up papers cited by  Havlir, Diane V
# Looking up papers cited by  Hendrickson, WA
# Looking up papers cited by  Heneine, Walid
# Looking up papers cited by  Hezareh, Marjan
# Looking up papers cited by  Hirsch, Ivan
# Looking up papers cited by  Ho, DD
# Looking up papers cited by  Hojer, B
# Looking up papers cited by  Hori, Kanji
# Looking up papers cited by  Hughes, Michael D
# Looking up papers cited by  Hughes, Stephen H
# Looking up papers cited by  Hunt, Joshua S
# No references found
# Looking up papers cited by  Hunter, Eric
# Looking up papers cited by  James, Christopher W
# No references found
# Looking up papers cited by  Jenabi, E
# Looking up papers cited by  Ji, Haiyan
# Looking up papers cited by  Jiang, Guochun
# Looking up papers cited by  Jiang, Shibo
# Looking up papers cited by  Jin, Yantao
# Looking up papers cited by  Jordan, Albert
# Looking up papers cited by  Jorgensen, Lars
# Looking up papers cited by  Kalyesubula, Robert
# Looking up papers cited by  Kim, DK
# Looking up papers cited by  Kim, Michelle
# Looking up papers cited by  Kitanaka, Susumu
# Looking up papers cited by  Koike, Kazuo
# Looking up papers cited by  Korin, Yael D
# Looking up papers cited by  Kulkosky, Joseph
# Looking up papers cited by  Kwong, PD
# Looking up papers cited by  Laird, Gregory M
# Looking up papers cited by  Lambotte, Olivier
# Looking up papers cited by  Lane, HC
# Looking up papers cited by  Lara, Humberto H
# Looking up papers cited by  Leteane, Melvin M
# No references found
# Looking up papers cited by  Levis, William R
# Looking up papers cited by  Lewin, Sharon R
# Looking up papers cited by  Li, Guohui
# Looking up papers cited by  Li, Jonathan Z
# Looking up papers cited by  Li, Zichong
# Looking up papers cited by  Lindenbach, Brett D
# Looking up papers cited by  Liu, Bingrui
# No references found
# Looking up papers cited by  Liu, Qingbo
# Looking up papers cited by  Liu, Yonghong
# Looking up papers cited by  Liu, Zhi-Bin
# Looking up papers cited by  Lok, Judith J
# Looking up papers cited by  Lopez-Cabrera, M
# Looking up papers cited by  Lortat-Jacob, Hugues
# Looking up papers cited by  Lu, Lin
# Looking up papers cited by  Lu, Wei
# Looking up papers cited by  Lubbe, Andrea
# Looking up papers cited by  Lubinga, SJ
# Looking up papers cited by  Lukas, Scott E
# Looking up papers cited by  Madec, Yoann
# Looking up papers cited by  Madiba, Sphiwe E
# Looking up papers cited by  Majinda, Runner R T
# Looking up papers cited by  Margolis, David M
# Looking up papers cited by  Martin, MA
# Looking up papers cited by  McKernan, Lisa N
# Looking up papers cited by  McKnight, A
# Looking up papers cited by  Miana, Ghulam Abbas
# Looking up papers cited by  Micheva-Viteva, Sofiya
# Looking up papers cited by  Moore, JP
# Looking up papers cited by  Moreno, Santiago
# Looking up papers cited by  Mousseau, Guillaume
# Looking up papers cited by  Mthethwa, Ningy S
# Looking up papers cited by  Mulholland, Dulcie A
# Looking up papers cited by  Munoz-Fernandez, Ma Angeles
# Looking up papers cited by  Mwimanzi, Philip
# Looking up papers cited by  Naidoo, Panjasaram
# Looking up papers cited by  Namuddu, Betty
# Looking up papers cited by  Ndubani, P
# Looking up papers cited by  Nelson, M
# Looking up papers cited by  Ngo, Linh T
# Looking up papers cited by  Nlooto, Manimbulu
# Looking up papers cited by  Nuzillard, Jean-Marc
# Looking up papers cited by  Nyiligira, E
# No references found
# Looking up papers cited by  Okulicz, Jason F
# Looking up papers cited by  Olsen, David B
# Looking up papers cited by  Otake, T
# Looking up papers cited by  Ott, Melanie
# Looking up papers cited by  Pan, Chungen
# Looking up papers cited by  Pandelo Jose, Diego
# Looking up papers cited by  Paracha, Usman Zafar
# Looking up papers cited by  Penetar, David M
# Looking up papers cited by  Peng, Cheng
# Looking up papers cited by  Perazella, Mark A
# Looking up papers cited by  Perelson, AS
# Looking up papers cited by  Perros, Manos
# Looking up papers cited by  Peterlin, Ba
# No references found
# Looking up papers cited by  Pham, Quang D
# Looking up papers cited by  Pieters, Luc
# Looking up papers cited by  Planelles, Vicente
# Looking up papers cited by  Pomerantz, Roger J
# Looking up papers cited by  Poorolajal, J
# Looking up papers cited by  Poveda, Eva
# Looking up papers cited by  Qu, Xiying
# Looking up papers cited by  Rapista, Aprille
# Looking up papers cited by  Rasmussen, Thomas Aagaard
# Looking up papers cited by  Rausch, Keiko
# Looking up papers cited by  Ren, J
# Looking up papers cited by  Reuse, Sophie
# Looking up papers cited by  Rice, Charles M
# Looking up papers cited by  Richman, Douglas D
# Looking up papers cited by  Rodriguez-Padilla, Cristina
# Looking up papers cited by  Romanelli, Frank
# Looking up papers cited by  Routy, Jean-Pierre
# Looking up papers cited by  Rouzioux, Christine
# Looking up papers cited by  Ruprecht, Claudia R
# Looking up papers cited by  Sadowski, Ivan
# Looking up papers cited by  Sagot-Lerolle, Nathalie
# No references found
# Looking up papers cited by  Sanchez-Madrid, F
# Looking up papers cited by  Saphire, AC
# Looking up papers cited by  Sato, Yuichiro
# Looking up papers cited by  Schulz, TF
# Looking up papers cited by  Shafer, Robert W
# Looking up papers cited by  Shan, Liang
# Looking up papers cited by  Shirakawa, Kotaro
# Looking up papers cited by  Siliciano, Robert F
# Looking up papers cited by  Skolnik, Paul R
# Looking up papers cited by  Sluis-Cremer, Nicolas
# Looking up papers cited by  Sogaard, Ole Schmeltz
# Looking up papers cited by  Soriano, Vincent
# Looking up papers cited by  Spina, Celsa A
# Looking up papers cited by  Spivak, Adam M
# Looking up papers cited by  Staerk, Dan
# Looking up papers cited by  Stammers, DK
# Looking up papers cited by  Steenkamp, PA
# Looking up papers cited by  Suo, Zucai
# Looking up papers cited by  Tallarida, Ronald J
# Looking up papers cited by  Tang, Michele W
# Looking up papers cited by  Tanuri, Amilcar
# Looking up papers cited by  Thenin-Houssier, Suzie
# Looking up papers cited by  Tietjen, Ian
# Looking up papers cited by  Tolstrup, Martin
# Looking up papers cited by  Trkola, Alexandra
# Looking up papers cited by  Trono, Didier
# Looking up papers cited by  Trushin, Sergey A
# Looking up papers cited by  Ueno, Takamasa
# Looking up papers cited by  Valadao, Ana Luiza Chaves
# Looking up papers cited by  Valente, Susana T
# Looking up papers cited by  Van Lint, Carine
# Looking up papers cited by  Verdin, Eric
# Looking up papers cited by  Vives, Romain R
# Looking up papers cited by  Waako, Paul
# Looking up papers cited by  Wainberg, Mark A
# Looking up papers cited by  Wang, Jian
# Looking up papers cited by  Wang, Lu
# Looking up papers cited by  Wang, Meng
# Looking up papers cited by  Wang, Pengfei
# Looking up papers cited by  Wang, Yuguang
# Looking up papers cited by  Waters, L
# Looking up papers cited by  Wei, Datsen George
# Looking up papers cited by  Weiss, RA
# Looking up papers cited by  Wender, Paul A
# Looking up papers cited by  Wensing, Annemarie M
# Looking up papers cited by  White, Cory H
# Looking up papers cited by  Williams, Samuel A
# Looking up papers cited by  Wilson, David P
# Looking up papers cited by  Witvrouw, Myriam
# Looking up papers cited by  Wiwat, Chanpen
# No references found
# Looking up papers cited by  Woelk, Christopher H
# Looking up papers cited by  Wong, JK
# Looking up papers cited by  Woradulayapinij, Warunya
# No references found
# Looking up papers cited by  Wu, Qi-Cheng
# Looking up papers cited by  Wu, Z
# Looking up papers cited by  Xing, Sifei
# Looking up papers cited by  Xu, Liran
# Looking up papers cited by  Yan, Xiaojing
# Looking up papers cited by  Zack, Jerome A
# Looking up papers cited by  Zhang, Linqi
# Looking up papers cited by  Zhang, Zhen
# Looking up papers cited by  Zhao, Tingting
# Looking up papers cited by  Zhao, Yanyun
# Looking up papers cited by  Zhong, Yu
# Looking up papers cited by  Zhou, Qiang
# Looking up papers cited by  Zhou, Xuefeng
# Looking up papers cited by  Zhou, Yan-Xi
# Looking up papers cited by  Zhu, Huanzhang
# Looking up papers cited by  Zou, Wen
# Looking up papers cited by  Zuo, Zhong
# Looking up papers cited by  van Kooyk, Y
# Looking up papers cited by  van der Kooy, Frank

# %%
# combine all the cited papers (removing duplicates) to create the feature set aka repo vocabulary

def create_paper_features_list(biologist_cited_papers_dict):
    """Takes a dictionary of cited papers and combines them into a list with no duplicates.
    
    Arguments:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of paper IDs cited in 
    papers authored by the biologist
    
    Returns:
    paper_features - list; list of all the papers cited by every author in the starting dict (no duplicates)
    """
    paper_features_temp = []
    for value in biologist_cited_papers_dict.values():
        paper_features_temp.extend(value)
    print(len(paper_features_temp))    
    paper_features = list(set(paper_features_temp))
    print(len(paper_features))
    return paper_features

# %%
the_paper_features_list = create_paper_features_list(the_biologist_cited_papers_dict)
# Out:
# 384339
# 251858

# %%
# run every author against the feature set to create a binary vector that contains a 1 if they cited a paper or a 0 if not

def create_binary_feature_vectors(biologist_cited_papers_dict, paper_features_list):
    """Builds a set of feature vectors for each biologist (key) in the biologist_cited_papers_dict by looking to see 
    if each paper in the paper_feature_list is cited by the biologist (a list of cited papers is the value associated 
    with each biologist key).  Adds a one to the feature vector if the paper is cited and a 0 if it is not. 
    
    Arguments:
    biologist_cited_papers_dict - dict; keys are biologist's names (str) and the values are a list of paper IDs cited 
    in papers authored by the biologist 
    paper_features_list - list; list of all the papers cited by every author in the starting dict
    
    Returns:
    all_binary_feature_vectors - list of lists; lists of 1s and 0s that indicate if a biologist cited a paper in the 
    paper_features_list or not
    """
    all_binary_feature_vectors = []
    for key, value in biologist_cited_papers_dict.items():
        biologist_vector = []
        for paper in paper_features_list:
            if paper in value:
                biologist_vector.append(1)
            else:
                biologist_vector.append(0)
        all_binary_feature_vectors.append(biologist_vector)
    return all_binary_feature_vectors

# %%
the_binary_feature_vectors = create_binary_feature_vectors(the_biologist_cited_papers_dict, the_paper_features_list)

# %%
def create_comparison_binary_vector(paper_list, paper_features_list):
    """Builds a feature vector for the originating set of papers by looking to see if each paper in the paper_
    features_list is cited by any of the originating set of papers. Adds a one to the feature vector if the paper is 
    cited and a 0 if it is not. 
    
    Arguments:
    paper_list - list; list of paper IDs (str) corresponding to the originating set of papers
    paper_features_list - list; list of all the papers cited by every author in the biologist_cited_papers_dict
    
    Returns:
    comparision_binary_vector - list; list of 1s and 0s that indicate if the originating set of papers cited a paper
    in the paper_features_list or not
    """
    comparison_binary_vector = []
    comparison_refs = get_and_compile_refs(chosen_papers)
    for i in paper_features_list:
        if i in comparison_refs:
            comparison_binary_vector.append(1)
        else:
            comparison_binary_vector.append(0)
    return comparison_binary_vector

# %%
def create_comparison_binary_vector_using_refs(ref_IDs, paper_features_list):
    """Builds a feature vector for the originating set of papers by looking to see if each paper in the paper_
    features_list is cited by any of the originating set of papers. Adds a one to the feature vector if the paper is 
    cited and a 0 if it is not. 
    
    Arguments:
    paper_list - list; list of paper IDs (str) corresponding to the originating set of papers
    paper_features_list - list; list of all the papers cited by every author in the biologist_cited_papers_dict
    
    Returns:
    comparision_binary_vector - list; list of 1s and 0s that indicate if the originating set of papers cited a paper
    in the paper_features_list or not
    """
    comparison_binary_vector = []
    for i in paper_features_list:
        if i in ref_IDs:
            comparison_binary_vector.append(1)
        else:
            comparison_binary_vector.append(0)
    return comparison_binary_vector

# %%
the_comparision_binary_vector = create_comparison_binary_vector_using_refs(all_ref_IDs, the_paper_features_list)

# %%
def create_biologist_finder_df(binary_feature_vectors, paper_features_list, biologist_cited_papers_dict, comparison_vector):
    """Takes the binary feature vectors and comparison binary vector and builds a pandas dataframe that has biologist's names
    as the index and paper IDs as the columns.  Dataframe is filled with 1s and 0s to indicate if a biologist has cited
    the column paper or not. The last row contains the data for the originating set of papers. 
    
    Arguments: 
    binary_feature_vectors - list of lists; lists of 0s and 1s that indicate if a biologist cited a paper in the 
    paper_features_list
    paper_features_list - list; list of all the papers cited by every author in the starting dict
    biologist_cited_papers_dict - dict; keys are biologist names (str) and the values are a list of paper IDS 
    corresponding to papers cited by the biologist
    comparison_vector - list; list of 0s and 1s that indicates if the originating set of papers cited a paper
    in the paper_features_list
    
    Returns:
    final_df - Pandas df; has biologist's names as the index and paper IDs as the columns.  Dataframe is filled with 
    1s and 0s to indicate if a biologist has cited the column paper or not. The last row represents the originating 
    set of papers and is indexed as "comparison" 
    """
    temp_df = pd.DataFrame(binary_feature_vectors, columns=paper_features_list, index=biologist_cited_papers_dict.keys())
    comp_series = pd.Series(comparison_vector).to_frame("comparison").T
    comp_series.columns = temp_df.columns
    final_df = pd.concat([temp_df, comp_series])
    final_df.dropna(axis=0, inplace=True)
    return final_df

# %%
bf_df = create_biologist_finder_df(the_binary_feature_vectors, the_paper_features_list, the_biologist_cited_papers_dict, 
                                   the_comparision_binary_vector)

# %%
bf_df.shape
# Out:
# (278, 251858)

# %%
bf_df.head()
# Out:
#                         15184506  27934476  26343504  26316679  8647346  \
# Abram, Michael E               0         0         0         0        0
# Abreu, Celina M                0         0         0         0        0
# Adachi, A                      0         0         0         0        0
# Aditya, Suruchi                0         0         0         0        0
# Aguiar, Renato Santana         0         0         0         0        0
#
#                         24257436  25450805  8790603  17540168  10679007  ...  \
# Abram, Michael E               0         0        0         0         0  ...
# Abreu, Celina M                0         0        0         0         0  ...
# Adachi, A                      0         0        0         0         0  ...
# Aditya, Suruchi                0         0        0         0         0  ...
# Aguiar, Renato Santana         0         0        0         0         0  ...
#
#                         3584988  22410007  17382883  16935573  27924033  \
# Abram, Michael E              0         0         0         0         0
# Abreu, Celina M               0         0         0         0         0
# Adachi, A                     0         0         0         0         0
# Aditya, Suruchi               0         0         0         0         0
# Aguiar, Renato Santana        0         0         0         0         0
#
#                         21989829  27325287  22955054  1572977  16567715
# Abram, Michael E               0         0         0        0         0
# Abreu, Celina M                0         0         0        0         0
# Adachi, A                      0         0         0        0         0
# Aditya, Suruchi                0         0         0        0         0
# Aguiar, Renato Santana         0         0         0        0         0
#
# [5 rows x 251858 columns]

# %%
bf_df.tail()
# Out:
#                      15184506  27934476  26343504  26316679  8647346  \
# Zou, Wen                    0         0         0         0        0
# Zuo, Zhong                  0         0         0         0        0
# van Kooyk, Y                0         0         0         0        0
# van der Kooy, Frank         0         0         0         0        0
# comparison                  0         0         0         0        0
#
#                      24257436  25450805  8790603  17540168  10679007  ...  \
# Zou, Wen                    0         0        0         0         0  ...
# Zuo, Zhong                  0         0        0         0         0  ...
# van Kooyk, Y                0         0        0         0         0  ...
# van der Kooy, Frank         0         0        0         0         0  ...
# comparison                  0         0        0         0         0  ...
#
#                      3584988  22410007  17382883  16935573  27924033  \
# Zou, Wen                   0         0         0         0         0
# Zuo, Zhong                 0         0         0         0         0
# van Kooyk, Y               0         0         0         0         0
# van der Kooy, Frank        0         0         0         0         0
# comparison                 0         0         0         0         0
#
#                      21989829  27325287  22955054  1572977  16567715
# Zou, Wen                    0         0         0        0         0
# Zuo, Zhong                  0         0         0        0         0
# van Kooyk, Y                0         0         0        0         0
# van der Kooy, Frank         0         0         0        0         0
# comparison                  0         0         0        0         0
#
# [5 rows x 251858 columns]

# %%
from fastparquet import write

write('Ian_6_refs_df.parq',bf_df)

# %%
bf_df = pd.read_parquet('Rasmussen_ver3_df.parq', engine='fastparquet')

# %%
bf_df.head()
# Out:
#                            18337155  20379956  20974816  15048123  24249263  \
# index
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            30178601  20625003  25657044  20926419  23711327  \
# index
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            ...  23970914  11877373  12239373  24012599  \
# index                      ...
# Abrash, Emily B            ...         0         0         0         0
# Ambrose, Jn                ...         0         0         0         0
# Anderson, Charles T        ...         0         0         0         0
# Andrey, Philippe           ...         0         0         0         0
# Arganda-Carreras, Ignacio  ...         0         0         0         0
#
#                            26523777  24921257  23318657  25089249  11430871  \
# index
# Abrash, Emily B                   0         0         0         0         0
# Ambrose, Jn                       0         0         0         0         0
# Anderson, Charles T               0         0         0         0         0
# Andrey, Philippe                  0         0         0         0         0
# Arganda-Carreras, Ignacio         0         0         0         0         0
#
#                            12195433
# index
# Abrash, Emily B                   0
# Ambrose, Jn                       0
# Anderson, Charles T               0
# Andrey, Philippe                  0
# Arganda-Carreras, Ignacio         0
#
# [5 rows x 137462 columns]

# %%
# Find out which scientists are closest to the original scientist.
def create_similarity_scores_df(biologist_finder_df):
    """Calculates pearsonr correlation coefficients between the last row of a dataframe and all the remaining rows. 
    Reports the coefficient ("similarity") in a new dataframe with the same row index as the original dataframe.
    
    Arguments:
    biologist_finder_df - pandas dataframe; rows are individual feature vectors and the last row is compared to all 
    other rows
    
    Returns:
    sorted_sim_df - pandas dataframe; 2 columns - "scientist" which is the biologist's name and "similarity" which is
    the pearsonr coefficient between scientist's feature vector and the last row of biologist_finder_df.  Dataframe is 
    sorted based on similarity scores from highest to lowest. 
    """
    sim_score = {}
    for i in range(len(biologist_finder_df)):
        score = pearsonr(biologist_finder_df.iloc[-1, :], biologist_finder_df.iloc[i, :])
        sim_score.update({i: score[0]})
    sim_df = pd.Series(sim_score).to_frame("similarity")
    sim_df["scientist"] = biologist_finder_df.index
    sorted_sim_df = sim_df.sort_values('similarity', ascending=False)
    return sorted_sim_df

# %%
ss_df = create_similarity_scores_df(bf_df)
# Out:
# /Users/ajwright/anaconda3/envs/my_conda/lib/python3.7/site-packages/scipy/stats/stats.py:3399: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
ss_df.shape
# Out:
# (278, 2)

# %%
# function to return a list of the X% of scientists on the list

def most_sim_biologists(similarity_df, per):
    """Takes a sorted dataframe and a float representing a percent.  Returns that percentage of the dataframe.
    
    Arguments:
    similarity_df - pandas dataframe; sorted dataframe
    per - float; represents a percentage
    
    Returns:
    similarity_df_per- pandas dataframe; truncated version of starting dataframe containing the user-specified percentage
    of rows
    """
    num_biologists = similarity_df.shape[0]
    top_per = int(num_biologists * per)
    similarity_df_per = similarity_df.head(top_per)
    print(similarity_df_per)
    return similarity_df_per

# %%
top_sim_bio_df = most_sim_biologists(ss_df, 0.2)
# Out:
#      similarity                  scientist
# 277    1.000000                 comparison
# 272    0.168154             Zhu, Huanzhang
# 190    0.145142                 Qu, Xiying
# 54     0.137949    Delagreverie, Heloise M
# 19     0.137747         Beans, Elizabeth J
# 218    0.134886             Spivak, Adam M
# 51     0.122545             Darcis, Gilles
# 12     0.122386           Archin, Nancie M
# 110    0.119494                 Ji, Haiyan
# 36     0.118871            Cary, Daniele C
# 260    0.110801                Xing, Sifei
# 176    0.098735        Pandelo Jose, Diego
# 28     0.097985            Bouchat, Sophie
# 111    0.097621             Jiang, Guochun
# 152    0.093277           McKernan, Lisa N
# 124    0.092959           Laird, Gregory M
# 186    0.092170         Planelles, Vicente
# 233    0.091449  Valadao, Ana Luiza Chaves
# 150    0.087350          Margolis, David M
# 1      0.085998            Abreu, Celina M
# 217    0.084136             Spina, Celsa A
# 195    0.083677              Reuse, Sophie
# 227    0.082797               Tietjen, Ian
# 212    0.077652        Siliciano, Robert F
# 99     0.077509            Hezareh, Marjan
# 203    0.074778             Sadowski, Ivan
# 235    0.074614           Van Lint, Carine
# 192    0.073547  Rasmussen, Thomas Aagaard
# 228    0.073253           Tolstrup, Martin
# 248    0.072756             Wender, Paul A
# 63     0.072025        Dougherty, Joseph P
# 21     0.070044            Bernhard, Wendy
# 121    0.069521              Korin, Yael D
# 4      0.067497     Aguiar, Renato Santana
# 49     0.067122            Dandekar, Satya
# 133    0.065641                Li, Zichong
# 26     0.065464             Blazkova, Jana
# 132    0.064420             Li, Jonathan Z
# 122    0.062864           Kulkosky, Joseph
# 158    0.061983        Mousseau, Guillaume
# 201    0.061698        Rouzioux, Christine
# 83     0.061598                Gama, Lucio
# 256    0.060575                   Wong, JK
# 225    0.060516            Tanuri, Amilcar
# 87     0.060441           Greene, Warner C
# 42     0.058019                   Chun, TW
# 214    0.057865      Sluis-Cremer, Nicolas
# 130    0.057789            Lewin, Sharon R
# 157    0.057340           Moreno, Santiago
# 250    0.057297              White, Cory H
# 53     0.055908            Deeks, Steven G
# 71     0.052716          Elliott, Julian H
# 31     0.051753           Brockman, Mark A
# 64     0.051628           Doyon, Genevieve
# 234    0.050353          Valente, Susana T

# %%
def get_citations(rec_paper_list):
    """Takes a list of paper ID numbers and return a PubMed reference for each paper on the list. 
    
    Arguments:
    rec_paper_list - list of strs; paper IDs numbers
    
    Returns:
    None
    (prints the references to the screen)
    """
    id_list = ",".join(rec_paper_list)
    search_results = Entrez.read(Entrez.epost("pubmed", id=id_list))
    query_key = search_results["QueryKey"]
    webenv = search_results["WebEnv"]
    handle = Entrez.efetch(db="pubmed", id=id_list, rettype='medline', retmode='text', webenv=webenv, query_key=query_key)
    records = Medline.parse(handle)
    for index, record in enumerate(records, 1):
        print("{}. {} {}. {}. {}. ({})".format(index, record.get("TI", "?"), record.get("AU", "?"), record.get("JT", "?"),
                                         record.get("DP", "?"), record.get("PMID", "?")))

# %%
# function to return a list of the shared citations of the X% of scientists on the list

def reading_list(biologist_finder_df, most_sim_bio_df):
    """Takes a dataframe containing the most similar biologists as well as the binary feature vector dataframe. Creates a new
    dataframe with paper IDs as the index and biologists as columns and it contains a 1 if the biologist ever cited
    the paper and a 0 if not.  Citations per paper are summed and then the df is sorted so that the most cited
    papers are at the top.  Prints to the terminal the number of papers cited by 10%, 20%, 30%, etc of the most
    similar biologists.  Prints to the terminal citations for the user-specified number of papers. 
    
    Arguments:
    biologist_finder_df - pandas dataframe; rows are individual biologist feature vectors
    most_sim_bio_df - pandas dataframe; 2 columns - "scientist" which is the biologist's name and "similarity" which is
    the pearsonr coefficient between scientist's feature vector and the last row of biologist_finder_df.  
    
    Returns:
    None
    (prints to the terminal citations for a user-specified number of most cited papers)
    """
    top_per_biologists = list(most_sim_bio_df.iloc[1:, 1])
    num_top_biologists = len(top_per_biologists)
    most_cited_papers = biologist_finder_df.loc[top_per_biologists, :][biologist_finder_df.loc[top_per_biologists, :] ==1].fillna(0).T
    most_cited_papers['sum'] = most_cited_papers.sum(axis=1)
    most_cited_papers_sort = most_cited_papers.sort_values('sum', ascending=False)
    total_num_papers = most_cited_papers_sort.shape[0]
    for i in range(10, 110, 10):
        per_of_top_biol = round(num_top_biologists * i/100)
        num_papers = most_cited_papers_sort[most_cited_papers_sort["sum"] >= per_of_top_biol].shape[0]
        if num_papers != 1:
            print("{} papers were cited at least once by {}% ({}) of the most similar biologists.".format(num_papers, i, per_of_top_biol))
        else:
            print("{} paper was cited at least once by {}% ({}) of the most similar biologists.".format(num_papers, i, per_of_top_biol))   
    num_papers = int(input("How many papers do you want on the recommended reading list? "))
    reading_list_ids = most_cited_papers_sort.head(num_papers).index.to_list()
    get_citations(reading_list_ids)

# %%
reading_list(bf_df, top_sim_bio_df)
# Out:
# 1778 papers were cited at least once by 10% (5) of the most similar biologists.
# 440 papers were cited at least once by 20% (11) of the most similar biologists.
# 227 papers were cited at least once by 30% (16) of the most similar biologists.
# 104 papers were cited at least once by 40% (22) of the most similar biologists.
# 54 papers were cited at least once by 50% (27) of the most similar biologists.
# 30 papers were cited at least once by 60% (32) of the most similar biologists.
# 15 papers were cited at least once by 70% (38) of the most similar biologists.
# 3 papers were cited at least once by 80% (43) of the most similar biologists.
# 0 papers were cited at least once by 90% (49) of the most similar biologists.
# 0 papers were cited at least once by 100% (54) of the most similar biologists.
# How many papers do you want on the recommended reading list? 104
# 1. Administration of vorinostat disrupts HIV-1 latency in patients on antiretroviral therapy. ['Archin NM', 'Liberty AL', 'Kashuba AD', 'Choudhary SK', 'Kuruc JD', 'Crooks AM', 'Parker DC', 'Anderson EM', 'Kearney MF', 'Strain MC', 'Richman DD', 'Hudgens MG', 'Bosch RJ', 'Coffin JM', 'Eron JJ', 'Hazuda DJ', 'Margolis DM']. Nature. 2012 Jul 25. (22837004)
# 2. HIV reproducibly establishes a latent infection after acute infection of T cells in vitro. ['Jordan A', 'Bisgrove D', 'Verdin E']. The EMBO journal. 2003 Apr 15. (12682019)
# 3. Identification of a reservoir for HIV-1 in patients on highly active antiretroviral therapy. ['Finzi D', 'Hermankova M', 'Pierson T', 'Carruth LM', 'Buck C', 'Chaisson RE', 'Quinn TC', 'Chadwick K', 'Margolick J', 'Brookmeyer R', 'Gallant J', 'Markowitz M', 'Ho DD', 'Richman DD', 'Siliciano RF']. Science (New York, N.Y.). 1997 Nov 14. (9360927)
# 4. Presence of an inducible HIV-1 latent reservoir during highly active antiretroviral therapy. ['Chun TW', 'Stuyver L', 'Mizell SB', 'Ehler LA', 'Mican JA', 'Baseler M', 'Lloyd AL', 'Nowak MA', 'Fauci AS']. Proceedings of the National Academy of Sciences of the United States of America. 1997 Nov 25. (9371822)
# 5. Expression of latent HIV induced by the potent HDAC inhibitor suberoylanilide hydroxamic acid. ['Archin NM', 'Espeseth A', 'Parker D', 'Cheema M', 'Hazuda D', 'Margolis DM']. AIDS research and human retroviruses. 2009 Feb. (19239360)
# 6. The challenge of finding a cure for HIV infection. ['Richman DD', 'Margolis DM', 'Delaney M', 'Greene WC', 'Hazuda D', 'Pomerantz RJ']. Science (New York, N.Y.). 2009 Mar 6. (19265012)
# 7. Long-term follow-up studies confirm the stability of the latent reservoir for HIV-1 in resting CD4+ T cells. ['Siliciano JD', 'Kajdas J', 'Finzi D', 'Quinn TC', 'Chadwick K', 'Margolick JB', 'Kovacs C', 'Gange SJ', 'Siliciano RF']. Nature medicine. 2003 Jun. (12754504)
# 8. New ex vivo approaches distinguish effective and ineffective single agents for reversing HIV-1 latency in vivo. ['Bullen CK', 'Laird GM', 'Durand CM', 'Siliciano JD', 'Siliciano RF']. Nature medicine. 2014 Apr. (24658076)
# 9. Prostratin antagonizes HIV latency by activating NF-kappaB. ['Williams SA', 'Chen LF', 'Kwon H', 'Fenard D', 'Bisgrove D', 'Verdin E', 'Greene WC']. The Journal of biological chemistry. 2004 Oct 1. (15284245)
# 10. Latent infection of CD4+ T cells provides a mechanism for lifelong persistence of HIV-1, even in patients on effective combination therapy. ['Finzi D', 'Blankson J', 'Siliciano JD', 'Margolick JB', 'Chadwick K', 'Pierson T', 'Smith K', 'Lisziewicz J', 'Lori F', 'Flexner C', 'Quinn TC', 'Chaisson RE', 'Rosenberg E', 'Walker B', 'Gange S', 'Gallant J', 'Siliciano RF']. Nature medicine. 1999 May. (10229227)
# 11. Depletion of latent HIV-1 infection in vivo: a proof-of-concept study. ['Lehrman G', 'Hogue IB', 'Palmer S', 'Jennings C', 'Spina CA', 'Wiegand A', 'Landay AL', 'Coombs RW', 'Richman DD', 'Mellors JW', 'Coffin JM', 'Bosch RJ', 'Margolis DM']. Lancet (London, England). 2005 Aug 13-19. (16099290)
# 12. Activation of HIV transcription with short-course vorinostat in HIV-infected patients on suppressive antiretroviral therapy. ['Elliott JH', 'Wightman F', 'Solomon A', 'Ghneim K', 'Ahlers J', 'Cameron MJ', 'Smith MZ', 'Spelman T', 'McMahon J', 'Velayudham P', 'Brown G', 'Roney J', 'Watson J', 'Prince MH', 'Hoy JF', 'Chomont N', 'Fromentin R', 'Procopio FA', 'Zeidan J', 'Palmer S', 'Odevall L', 'Johnstone RW', 'Martin BP', 'Sinclair E', 'Deeks SG', 'Hazuda DJ', 'Cameron PU', 'Sekaly RP', 'Lewin SR']. PLoS pathogens. 2014 Oct. (25393648)
# 13. Recovery of replication-competent HIV despite prolonged suppression of plasma viremia. ['Wong JK', 'Hezareh M', 'Gunthard HF', 'Havlir DV', 'Ignacio CC', 'Spina CA', 'Richman DD']. Science (New York, N.Y.). 1997 Nov 14. (9360926)
# 14. Bryostatin modulates latent HIV-1 infection via PKC and AMPK signaling but inhibits acute infection in a receptor independent manner. ['Mehla R', 'Bivalkar-Mehla S', 'Zhang R', 'Handy I', 'Albrecht H', 'Giri S', 'Nagarkatti P', 'Nagarkatti M', 'Chauhan A']. PloS one. 2010 Jun 16. (20585398)
# 15. Synergistic activation of HIV-1 expression by deacetylase inhibitors and prostratin: implications for treatment of latent infection. ['Reuse S', 'Calao M', 'Kabeya K', 'Guiguen A', 'Gatot JS', 'Quivy V', 'Vanhulle C', 'Lamine A', 'Vaira D', 'Demonte D', 'Martinelli V', 'Veithen E', 'Cherrier T', 'Avettand V', 'Poutrel S', 'Piette J', 'de Launoit Y', 'Moutschen M', 'Burny A', 'Rouzioux C', 'De Wit S', 'Herbein G', 'Rohr O', 'Collette Y', 'Lambotte O', 'Clumeck N', 'Van Lint C']. PloS one. 2009 Jun 30. (19564922)
# 16. An in-depth comparison of latent HIV-1 reactivation in multiple cell model systems and resting CD4+ T cells from aviremic patients. ['Spina CA', 'Anderson J', 'Archin NM', 'Bosque A', 'Chan J', 'Famiglietti M', 'Greene WC', 'Kashuba A', 'Lewin SR', 'Margolis DM', 'Mau M', 'Ruelas D', 'Saleh S', 'Shirakawa K', 'Siliciano RF', 'Singhania A', 'Soto PC', 'Terry VH', 'Verdin E', 'Woelk C', 'Wooden S', 'Xing S', 'Planelles V']. PLoS pathogens. 2013. (24385908)
# 17. Suberoylanilide hydroxamic acid reactivates HIV from latently infected cells. ['Contreras X', 'Schweneker M', 'Chen CS', 'McCune JM', 'Deeks SG', 'Martin J', 'Peterlin BM']. The Journal of biological chemistry. 2009 Mar 13. (19136668)
# 18. Quantification of latent tissue reservoirs and total body viral load in HIV-1 infection. ['Chun TW', 'Carruth L', 'Finzi D', 'Shen X', 'DiGiuseppe JA', 'Taylor H', 'Hermankova M', 'Chadwick K', 'Margolick J', 'Quinn TC', 'Kuo YH', 'Brookmeyer R', 'Zeiger MA', 'Barditch-Crovo P', 'Siliciano RF']. Nature. 1997 May 8. (9144289)
# 19. Ex vivo analysis identifies effective HIV-1 latency-reversing drug combinations. ['Laird GM', 'Bullen CK', 'Rosenbloom DI', 'Martin AR', 'Hill AL', 'Durand CM', 'Siliciano JD', 'Siliciano RF']. The Journal of clinical investigation. 2015 May. (25822022)
# 20. The Depsipeptide Romidepsin Reverses HIV-1 Latency In Vivo. ['Sogaard OS', 'Graversen ME', 'Leth S', 'Olesen R', 'Brinkmann CR', 'Nissen SK', 'Kjaer AS', 'Schleimann MH', 'Denton PW', 'Hey-Cunningham WJ', 'Koelsch KK', 'Pantaleo G', 'Krogsgaard K', 'Sommerfelt M', 'Fromentin R', 'Chomont N', 'Rasmussen TA', 'Ostergaard L', 'Tolstrup M']. PLoS pathogens. 2015 Sep. (26379282)
# 21. Stimulation of HIV-1-specific cytolytic T lymphocytes facilitates elimination of latent viral reservoir after virus reactivation. ['Shan L', 'Deng K', 'Shroff NS', 'Durand CM', 'Rabi SA', 'Yang HC', 'Zhang H', 'Margolick JB', 'Blankson JN', 'Siliciano RF']. Immunity. 2012 Mar 23. (22406268)
# 22. HIV reservoir size and persistence are driven by T cell survival and homeostatic proliferation. ['Chomont N', 'El-Far M', 'Ancuta P', 'Trautmann L', 'Procopio FA', 'Yassine-Diab B', 'Boucher G', 'Boulassel MR', 'Ghattas G', 'Brenchley JM', 'Schacker TW', 'Hill BJ', 'Douek DC', 'Routy JP', 'Haddad EK', 'Sekaly RP']. Nature medicine. 2009 Aug. (19543283)
# 23. Prostratin: activation of latent HIV-1 expression suggests a potential inductive adjuvant therapy for HAART. ['Kulkosky J', 'Culnan DM', 'Roman J', 'Dornadula G', 'Schnell M', 'Boyd MR', 'Pomerantz RJ']. Blood. 2001 Nov 15. (11698284)
# 24. Panobinostat, a histone deacetylase inhibitor, for latent-virus reactivation in HIV-infected patients on suppressive antiretroviral therapy: a phase 1/2, single group, clinical trial. ['Rasmussen TA', 'Tolstrup M', 'Brinkmann CR', 'Olesen R', 'Erikstrup C', 'Solomon A', 'Winckelmann A', 'Palmer S', 'Dinarello C', 'Buzon M', 'Lichterfeld M', 'Lewin SR', 'Ostergaard L', 'Sogaard OS']. The lancet. HIV. 2014 Oct. (26423811)
# 25. Replication-competent noninduced proviruses in the latent reservoir increase barrier to HIV-1 cure. ['Ho YC', 'Shan L', 'Hosmane NN', 'Wang J', 'Laskey SB', 'Rosenbloom DI', 'Lai J', 'Blankson JN', 'Siliciano JD', 'Siliciano RF']. Cell. 2013 Oct 24. (24243014)
# 26. NF-kappaB p50 promotes HIV latency through HDAC recruitment and repression of transcriptional initiation. ['Williams SA', 'Chen LF', 'Kwon H', 'Ruiz-Jarabo CM', 'Verdin E', 'Greene WC']. The EMBO journal. 2006 Jan 11. (16319923)
# 27. Coaxing HIV-1 from resting CD4 T cells: histone deacetylase inhibition allows latent viral expression. ['Ylisastigui L', 'Archin NM', 'Lehrman G', 'Bosch RJ', 'Margolis DM']. AIDS (London, England). 2004 May 21. (15166525)
# 28. Epigenetic regulation of HIV-1 latency by cytosine methylation. ['Kauder SE', 'Bosque A', 'Lindqvist A', 'Planelles V', 'Verdin E']. PLoS pathogens. 2009 Jun. (19557157)
# 29. Histone deacetylase inhibitor romidepsin induces HIV expression in CD4 T cells from patients on suppressive antiretroviral therapy at concentrations achieved by clinical dosing. ['Wei DG', 'Chiang V', 'Fyne E', 'Balakrishnan M', 'Barnes T', 'Graupe M', 'Hesselgesser J', 'Irrinki A', 'Murry JP', 'Stepan G', 'Stray KM', 'Tsai A', 'Yu H', 'Spindler J', 'Kearney M', 'Spina CA', 'McMahon D', 'Lalezari J', 'Sloan D', 'Mellors J', 'Geleziunas R', 'Cihlar T']. PLoS pathogens. 2014 Apr. (24722454)
# 30. HIV: Shock and kill. ['Deeks SG']. Nature. 2012 Jul 25. (22836995)
# 31. Epigenetic silencing of HIV-1 by the histone H3 lysine 27 methyltransferase enhancer of Zeste 2. ['Friedman J', 'Cho WK', 'Chu CK', 'Keedy KS', 'Archin NM', 'Margolis DM', 'Karn J']. Journal of virology. 2011 Sep. (21715480)
# 32. HIV-1 and T cell dynamics after interruption of highly active antiretroviral therapy (HAART) in patients with a history of sustained viral suppression. ['Davey RT Jr', 'Bhat N', 'Yoder C', 'Chun TW', 'Metcalf JA', 'Dewar R', 'Natarajan V', 'Lempicki RA', 'Adelsberger JW', 'Miller KD', 'Kovacs JA', 'Polis MA', 'Walker RE', 'Falloon J', 'Masur H', 'Gee D', 'Baseler M', 'Dimitrov DS', 'Fauci AS', 'Lane HC']. Proceedings of the National Academy of Sciences of the United States of America. 1999 Dec 21. (10611346)
# 33. HIV-1 expression within resting CD4+ T cells after multiple doses of vorinostat. ['Archin NM', 'Bateson R', 'Tripathy MK', 'Crooks AM', 'Yang KH', 'Dahl NP', 'Kearney MF', 'Anderson EM', 'Coffin JM', 'Strain MC', 'Richman DD', 'Robertson KR', 'Kashuba AD', 'Bosch RJ', 'Hazuda DJ', 'Kuruc JD', 'Eron JJ', 'Margolis DM']. The Journal of infectious diseases. 2014 Sep 1. (24620025)
# 34. Small-molecule screening using a human primary cell model of HIV latency identifies compounds that reverse latency without cellular activation. ['Yang HC', 'Xing S', 'Shan L', "O'Connell K", 'Dinoso J', 'Shen A', 'Zhou Y', 'Shrum CK', 'Han Y', 'Liu JO', 'Zhang H', 'Margolick JB', 'Siliciano RF']. The Journal of clinical investigation. 2009 Nov. (19805909)
# 35. Induction of HIV-1 latency and reactivation in primary memory CD4+ T cells. ['Bosque A', 'Planelles V']. Blood. 2009 Jan 1. (18849485)
# 36. Effects of prostratin on T-cell activation and human immunodeficiency virus latency. ['Korin YD', 'Brooks DG', 'Brown S', 'Korotzer A', 'Zack JA']. Journal of virology. 2002 Aug. (12134017)
# 37. In vivo fate of HIV-1-infected T cells: quantitative analysis of the transition to stable latency. ['Chun TW', 'Finzi D', 'Margolick J', 'Chadwick K', 'Schwartz D', 'Siliciano RF']. Nature medicine. 1995 Dec. (7489410)
# 38. BET bromodomain-targeting compounds reactivate HIV from latency via a Tat-independent mechanism. ['Boehm D', 'Calvanese V', 'Dar RD', 'Xing S', 'Schroeder S', 'Martins L', 'Aull K', 'Li PC', 'Planelles V', 'Bradner JE', 'Zhou MM', 'Siliciano RF', 'Weinberger L', 'Verdin E', 'Ott M']. Cell cycle (Georgetown, Tex.). 2013 Feb 1. (23255218)
# 39. Transcriptional activation and chromatin remodeling of the HIV-1 promoter in response to histone acetylation. ['Van Lint C', 'Emiliani S', 'Ott M', 'Verdin E']. The EMBO journal. 1996 Mar 1. (8605881)
# 40. BET bromodomain inhibition as a novel strategy for reactivation of HIV-1. ['Banerjee C', 'Archin N', 'Michaels D', 'Belkina AC', 'Denis GV', 'Bradner J', 'Sebastiani P', 'Margolis DM', 'Montano M']. Journal of leukocyte biology. 2012 Dec. (22802445)
# 41. IL-7 is a potent and proviral strain-specific inducer of latent HIV-1 cellular reservoirs of infected individuals on virally suppressive HAART. ['Wang FX', 'Xu Y', 'Sullivan J', 'Souder E', 'Argyris EG', 'Acheampong EA', 'Fisher J', 'Sierra M', 'Thomson MM', 'Najera R', 'Frank I', 'Kulkosky J', 'Pomerantz RJ', 'Nunnari G']. The Journal of clinical investigation. 2005 Jan. (15630452)
# 42. Expression of latent human immunodeficiency type 1 is induced by novel and selective histone deacetylase inhibitors. ['Archin NM', 'Keedy KS', 'Espeseth A', 'Dang H', 'Hazuda DJ', 'Margolis DM']. AIDS (London, England). 2009 Sep 10. (19590405)
# 43. A limited group of class I histone deacetylases acts to repress human immunodeficiency virus type 1 expression. ['Keedy KS', 'Archin NM', 'Gates AT', 'Espeseth A', 'Hazuda DJ', 'Margolis DM']. Journal of virology. 2009 May. (19279091)
# 44. Histone methyltransferase inhibitors induce HIV-1 recovery in resting CD4(+) T cells from HIV-1-infected HAART-treated patients. ['Bouchat S', 'Gatot JS', 'Kabeya K', 'Cardona C', 'Colin L', 'Herbein G', 'De Wit S', 'Clumeck N', 'Lambotte O', 'Rouzioux C', 'Rohr O', 'Van Lint C']. AIDS (London, England). 2012 Jul 31. (22555163)
# 45. Bryostatin-1 synergizes with histone deacetylase inhibitors to reactivate HIV-1 from latency. ['Perez M', 'de Vinuesa AG', 'Sanchez-Duffhues G', 'Marquez N', 'Bellido ML', 'Munoz-Fernandez MA', 'Moreno S', 'Castor TP', 'Calzado MA', 'Munoz E']. Current HIV research. 2010 Sep. (20636281)
# 46. Immuno-activation with anti-CD3 and recombinant human IL-2 in HIV-1-infected patients on potent antiretroviral therapy. ['Prins JM', 'Jurriaans S', 'van Praag RM', 'Blaak H', 'van Rij R', 'Schellekens PT', 'ten Berge IJ', 'Yong SL', 'Fox CH', 'Roos MT', 'de Wolf F', 'Goudsmit J', 'Schuitemaker H', 'Lange JM']. AIDS (London, England). 1999 Dec 3. (10597782)
# 47. Towards an HIV cure: a global scientific strategy. ['Deeks SG', 'Autran B', 'Berkhout B', 'Benkirane M', 'Cairns S', 'Chomont N', 'Chun TW', 'Churchill M', 'Di Mascio M', 'Katlama C', 'Lafeuillade A', 'Landay A', 'Lederman M', 'Lewin SR', 'Maldarelli F', 'Margolis D', 'Markowitz M', 'Martinez-Picado J', 'Mullins JI', 'Mellors J', 'Moreno S', "O'Doherty U", 'Palmer S', 'Penicaud MC', 'Peterlin M', 'Poli G', 'Routy JP', 'Rouzioux C', 'Silvestri G', 'Stevenson M', 'Telenti A', 'Van Lint C', 'Verdin E', 'Woolfrey A', 'Zaia J', 'Barre-Sinoussi F']. Nature reviews. Immunology. 2012 Jul 20. (22814509)
# 48. Comparison of HDAC inhibitors in clinical development: effect on HIV production in latently infected cells and T-cell activation. ['Rasmussen TA', 'Schmeltz Sogaard O', 'Brinkmann C', 'Wightman F', 'Lewin SR', 'Melchjorsen J', 'Dinarello C', 'Ostergaard L', 'Tolstrup M']. Human vaccines & immunotherapeutics. 2013 May. (23370291)
# 49. The human factors YY1 and LSF repress the human immunodeficiency virus type 1 long terminal repeat via recruitment of histone deacetylase 1. ['Coull JJ', 'Romerio F', 'Sun JM', 'Volker JL', 'Galvin KM', 'Davie JR', 'Shi Y', 'Hansen U', 'Margolis DM']. Journal of virology. 2000 Aug. (10888618)
# 50. Stability of the latent reservoir for HIV-1 in patients receiving valproic acid. ['Siliciano JD', 'Lai J', 'Callender M', 'Pitt E', 'Zhang H', 'Margolick JB', 'Gallant JE', 'Cofrancesco J Jr', 'Moore RD', 'Gange SJ', 'Siliciano RF']. The Journal of infectious diseases. 2007 Mar 15. (17299713)
# 51. Synergistic Reactivation of Latent HIV Expression by Ingenol-3-Angelate, PEP005, Targeted NF-kB Signaling in Combination with JQ1 Induced p-TEFb Activation. ['Jiang G', 'Mendes EA', 'Kaiser P', 'Wong DP', 'Tang Y', 'Cai I', 'Fenton A', 'Melcher GP', 'Hildreth JE', 'Thompson GR', 'Wong JK', 'Dandekar S']. PLoS pathogens. 2015 Jul. (26225771)
# 52. Reactivation of latent HIV-1 by inhibition of BRD4. ['Zhu J', 'Gaiha GD', 'John SP', 'Pertel T', 'Chin CR', 'Gao G', 'Qu H', 'Walker BD', 'Elledge SJ', 'Brass AL']. Cell reports. 2012 Oct 25. (23041316)
# 53. The BET bromodomain inhibitor JQ1 activates HIV latency through antagonizing Brd4 inhibition of Tat-transactivation. ['Li Z', 'Guo J', 'Wu Y', 'Zhou Q']. Nucleic acids research. 2013 Jan 7. (23087374)
# 54. Reactivation of HIV latency by a newly modified Ingenol derivative via protein kinase Cdelta-NF-kappaB signaling. ['Jiang G', 'Mendes EA', 'Kaiser P', 'Sankaran-Walters S', 'Tang Y', 'Weber MG', 'Melcher GP', 'Thompson GR 3rd', 'Tanuri A', 'Pianowski LF', 'Wong JK', 'Dandekar S']. AIDS (London, England). 2014 Jul 17. (24804860)
# 55. Cytokine-induced expression of HIV-1 in a chronically infected promonocyte cell line. ['Folks TM', 'Justement J', 'Kinter A', 'Dinarello CA', 'Fauci AS']. Science (New York, N.Y.). 1987 Nov 6. (3313729)
# 56. CpG methylation controls reactivation of HIV from latency. ['Blazkova J', 'Trejbalova K', 'Gondois-Rey F', 'Halfon P', 'Philibert P', 'Guiguen A', 'Verdin E', 'Olive D', 'Van Lint C', 'Hejnar J', 'Hirsch I']. PLoS pathogens. 2009 Aug. (19696893)
# 57. Valproic acid in association with highly active antiretroviral therapy for reducing systemic HIV-1 reservoirs: results from a multicentre randomized clinical study. ['Routy JP', 'Tremblay CL', 'Angel JB', 'Trottier B', 'Rouleau D', 'Baril JG', 'Harris M', 'Trottier S', 'Singer J', 'Chomont N', 'Sekaly RP', 'Boulassel MR']. HIV medicine. 2012 May. (22276680)
# 58. An In-Depth Comparison of Latency-Reversing Agent Combinations in Various In Vitro and Ex Vivo HIV-1 Latency Models Identified Bryostatin-1+JQ1 and Ingenol-B+JQ1 to Potently Reactivate Viral Gene Expression. ['Darcis G', 'Kula A', 'Bouchat S', 'Fujinaga K', 'Corazza F', 'Ait-Ammar A', 'Delacourt N', 'Melard A', 'Kabeya K', 'Vanhulle C', 'Van Driessche B', 'Gatot JS', 'Cherrier T', 'Pianowski LF', 'Gama L', 'Schwartz C', 'Vila J', 'Burny A', 'Clumeck N', 'Moutschen M', 'De Wit S', 'Peterlin BM', 'Rouzioux C', 'Rohr O', 'Van Lint C']. PLoS pathogens. 2015 Jul. (26225566)
# 59. Valproic acid without intensified antiviral therapy has limited impact on persistent HIV infection of resting CD4+ T cells. ['Archin NM', 'Eron JJ', 'Palmer S', 'Hartmann-Duff A', 'Martinson JA', 'Wiegand A', 'Bandarenko N', 'Schmitz JL', 'Bosch RJ', 'Landay AL', 'Coffin JM', 'Margolis DM']. AIDS (London, England). 2008 Jun 19. (18525258)
# 60. Prolonged valproic acid treatment does not reduce the size of latent HIV reservoir. ['Sagot-Lerolle N', 'Lamine A', 'Chaix ML', 'Boufassa F', 'Aboulker JP', 'Costagliola D', 'Goujard C', 'Pallier C', 'Delfraissy JF', 'Lambotte O']. AIDS (London, England). 2008 Jun 19. (18525257)
# 61. Molecular control of HIV-1 postintegration latency: implications for the development of new therapeutic strategies. ['Colin L', 'Van Lint C']. Retrovirology. 2009 Dec 4. (19961595)
# 62. Antiretroviral intensification and valproic acid lack sustained effect on residual HIV-1 viremia or resting CD4+ cell infection. ['Archin NM', 'Cheema M', 'Parker D', 'Wiegand A', 'Bosch RJ', 'Coffin JM', 'Eron J', 'Cohen M', 'Margolis DM']. PloS one. 2010 Feb 23. (20186346)
# 63. HIV latency. ['Siliciano RF', 'Greene WC']. Cold Spring Harbor perspectives in medicine. 2011 Sep. (22229121)
# 64. Quantification of HIV-1 latency reversal in resting CD4+ T cells from patients on suppressive antiretroviral therapy. ['Cillo AR', 'Sobolewski MD', 'Bosch RJ', 'Fyne E', 'Piatak M Jr', 'Coffin JM', 'Mellors JW']. Proceedings of the National Academy of Sciences of the United States of America. 2014 May 13. (24706775)
# 65. Rapid seeding of the viral reservoir prior to SIV viraemia in rhesus monkeys. ['Whitney JB', 'Hill AL', 'Sanisetty S', 'Penaloza-MacMaster P', 'Liu J', 'Shetty M', 'Parenteau L', 'Cabral C', 'Shields J', 'Blackmore S', 'Smith JY', 'Brinkman AL', 'Peter LE', 'Mathew SI', 'Smith KM', 'Borducchi EN', 'Rosenbloom DI', 'Lewis MG', 'Hattersley J', 'Li B', 'Hesselgesser J', 'Geleziunas R', 'Robb ML', 'Kim JH', 'Michael NL', 'Barouch DH']. Nature. 2014 Aug 7. (25042999)
# 66. Rapid quantification of the latent reservoir for HIV-1 using a viral outgrowth assay. ['Laird GM', 'Eisele EE', 'Rabi SA', 'Lai J', 'Chioma S', 'Blankson JN', 'Siliciano JD', 'Siliciano RF']. PLoS pathogens. 2013. (23737751)
# 67. Effect of histone deacetylase inhibitors on HIV production in latently infected, resting CD4(+) T cells from infected individuals receiving effective antiretroviral therapy. ['Blazkova J', 'Chun TW', 'Belay BW', 'Murray D', 'Justement JS', 'Funk EK', 'Nelson A', 'Hallahan CW', 'Moir S', 'Wender PA', 'Fauci AS']. The Journal of infectious diseases. 2012 Sep 1. (22732922)
# 68. Interleukin-7 induces expression of latent human immunodeficiency virus type 1 with minimal effects on T-cell phenotype. ['Scripture-Adams DD', 'Brooks DG', 'Korin YD', 'Zack JA']. Journal of virology. 2002 Dec. (12438635)
# 69. Disulfiram reactivates latent HIV-1 in a Bcl-2-transduced primary CD4+ T cell model without inducing global T cell activation. ['Xing S', 'Bullen CK', 'Shroff NS', 'Shan L', 'Yang HC', 'Manucci JL', 'Bhat S', 'Zhang H', 'Margolick JB', 'Quinn TC', 'Margolis DM', 'Siliciano JD', 'Siliciano RF']. Journal of virology. 2011 Jun. (21471244)
# 70. An inducible transcription factor activates expression of human immunodeficiency virus in T cells. ['Nabel G', 'Baltimore D']. Nature. 1987 Apr 16-22. (3031512)
# 71. HMBA releases P-TEFb from HEXIM1 and 7SK snRNA via PI3K/Akt and activates HIV transcription. ['Contreras X', 'Barboric M', 'Lenasi T', 'Peterlin BM']. PLoS pathogens. 2007 Oct 12. (17937499)
# 72. A pilot study assessing the safety and latency-reversing activity of disulfiram in HIV-1-infected adults on antiretroviral therapy. ['Spivak AM', 'Andrade A', 'Eisele E', 'Hoh R', 'Bacchetti P', 'Bumpus NN', 'Emad F', 'Buckheit R 3rd', 'McCance-Katz EF', 'Lai J', 'Kennedy M', 'Chander G', 'Siliciano RF', 'Siliciano JD', 'Deeks SG']. Clinical infectious diseases : an official publication of the Infectious Diseases Society of America. 2014 Mar. (24336828)
# 73. The site of HIV-1 integration in the human genome determines basal transcriptional activity and response to Tat transactivation. ['Jordan A', 'Defechereux P', 'Verdin E']. The EMBO journal. 2001 Apr 2. (11285236)
# 74. HIV type 1 inhibition by protein kinase C modulatory compounds. ['Warrilow D', 'Gardner J', 'Darnell GA', 'Suhrbier A', 'Harrich D']. AIDS research and human retroviruses. 2006 Sep. (16989610)
# 75. HIV-1 integration in the human genome favors active genes and local hotspots. ['Schroder AR', 'Shinn P', 'Chen H', 'Berry C', 'Ecker JR', 'Bushman F']. Cell. 2002 Aug 23. (12202041)
# 76. Redefining the viral reservoirs that prevent HIV-1 eradication. ['Eisele E', 'Siliciano RF']. Immunity. 2012 Sep 21. (22999944)
# 77. Suv39H1 and HP1gamma are responsible for chromatin-mediated HIV-1 transcriptional silencing and post-integration latency. ['du Chene I', 'Basyuk E', 'Lin YL', 'Triboulet R', 'Knezevich A', 'Chable-Bessia C', 'Mettling C', 'Baillat V', 'Reynes J', 'Corbeau P', 'Bertrand E', 'Marcello A', 'Emiliani S', 'Kiernan R', 'Benkirane M']. The EMBO journal. 2007 Jan 24. (17245432)
# 78. Dual role of novel ingenol derivatives from Euphorbia tirucalli in HIV replication: inhibition of de novo infection and activation of viral LTR. ['Abreu CM', 'Price SL', 'Shirk EN', 'Cunha RD', 'Pianowski LF', 'Clements JE', 'Tanuri A', 'Gama L']. PloS one. 2014. (24827152)
# 79. Tumor necrosis factor alpha induces expression of human immunodeficiency virus in a chronically infected T-cell clone. ['Folks TM', 'Clouse KA', 'Justement J', 'Rabson A', 'Duh E', 'Kehrl JH', 'Fauci AS']. Proceedings of the National Academy of Sciences of the United States of America. 1989 Apr. (2784570)
# 80. Post-treatment HIV-1 controllers with a long-term virological remission after the interruption of early initiated antiretroviral therapy ANRS VISCONTI Study. ['Saez-Cirion A', 'Bacchus C', 'Hocqueloux L', 'Avettand-Fenoel V', 'Girault I', 'Lecuroux C', 'Potard V', 'Versmisse P', 'Melard A', 'Prazuck T', 'Descours B', 'Guergnon J', 'Viard JP', 'Boufassa F', 'Lambotte O', 'Goujard C', 'Meyer L', 'Costagliola D', 'Venet A', 'Pancino G', 'Autran B', 'Rouzioux C']. PLoS pathogens. 2013 Mar. (23516360)
# 81. Establishment of HIV latency in primary CD4+ cells is due to epigenetic transcriptional silencing and P-TEFb restriction. ['Tyagi M', 'Pearson RJ', 'Karn J']. Journal of virology. 2010 Jul. (20410271)
# 82. Comparative analysis of measures of viral reservoirs in HIV-1 eradication studies. ['Eriksson S', 'Graf EH', 'Dahl V', 'Strain MC', 'Yukl SA', 'Lysenko ES', 'Bosch RJ', 'Lai J', 'Chioma S', 'Emad F', 'Abdel-Mohsen M', 'Hoh R', 'Hecht F', 'Hunt P', 'Somsouk M', 'Wong J', 'Johnston R', 'Siliciano RF', 'Richman DD', "O'Doherty U", 'Palmer S', 'Deeks SG', 'Siliciano JD']. PLoS pathogens. 2013 Feb. (23459007)
# 83. Long-term control of HIV by CCR5 Delta32/Delta32 stem-cell transplantation. ['Hutter G', 'Nowak D', 'Mossner M', 'Ganepola S', 'Mussig A', 'Allers K', 'Schneider T', 'Hofmann J', 'Kucherer C', 'Blau O', 'Blau IW', 'Hofmann WK', 'Thiel E']. The New England journal of medicine. 2009 Feb 12. (19213682)
# 84. CBF-1 promotes transcriptional silencing during the establishment of HIV-1 latency. ['Tyagi M', 'Karn J']. The EMBO journal. 2007 Dec 12. (18007589)
# 85. Histone deacetylase inhibitors (HDACis) that release the positive transcription elongation factor b (P-TEFb) from its inhibitory complex also activate HIV transcription. ['Bartholomeeusen K', 'Fujinaga K', 'Xiang Y', 'Peterlin BM']. The Journal of biological chemistry. 2013 May 17. (23539624)
# 86. Antireplicative and anticytopathic activities of prostratin, a non-tumor-promoting phorbol ester, against human immunodeficiency virus (HIV). ['Gulakowski RJ', 'McMahon JB', 'Buckheit RW Jr', 'Gustafson KR', 'Boyd MR']. Antiviral research. 1997 Jan. (9021050)
# 87. Treatment intensification does not reduce residual HIV-1 viremia in patients on highly active antiretroviral therapy. ['Dinoso JB', 'Kim SY', 'Wiegand AM', 'Palmer SE', 'Gange SJ', 'Cranmer L', "O'Shea A", 'Callender M', 'Spivak A', 'Brennan T', 'Kearney MF', 'Proschan MA', 'Mican JM', 'Rehm CA', 'Coffin JM', 'Mellors JW', 'Siliciano RF', 'Maldarelli F']. Proceedings of the National Academy of Sciences of the United States of America. 2009 Jun 9. (19470482)
# 88. HIV-1 transcription and latency: an update. ['Van Lint C', 'Bouchat S', 'Marcello A']. Retrovirology. 2013 Jun 26. (23803414)
# 89. Combinatorial latency reactivation for HIV-1 subtypes and variants. ['Burnett JC', 'Lim KI', 'Calafi A', 'Rossi JJ', 'Schaffer DV', 'Arkin AP']. Journal of virology. 2010 Jun. (20357084)
# 90. Reactivation of latent HIV-1 by new semi-synthetic ingenol esters. ['Pandelo Jose D', 'Bartholomeeusen K', 'da Cunha RD', 'Abreu CM', 'Glinski J', 'da Costa TB', 'Bacchi Rabay AF', 'Pianowski Filho LF', 'Dudycz LW', 'Ranga U', 'Peterlin BM', 'Pianowski LF', 'Tanuri A', 'Aguiar RS']. Virology. 2014 Aug. (25014309)
# 91. Cellular microRNAs contribute to HIV-1 latency in resting primary CD4+ T lymphocytes. ['Huang J', 'Wang F', 'Argyris E', 'Chen K', 'Liang Z', 'Tian H', 'Huang W', 'Squires K', 'Verlinghieri G', 'Zhang H']. Nature medicine. 2007 Oct. (17906637)
# 92. HIV latency. Specific HIV integration sites are linked to clonal expansion and persistence of infected cells. ['Maldarelli F', 'Wu X', 'Su L', 'Simonetti FR', 'Shao W', 'Hill S', 'Spindler J', 'Ferris AL', 'Mellors JW', 'Kearney MF', 'Coffin JM', 'Hughes SH']. Science (New York, N.Y.). 2014 Jul 11. (24968937)
# 93. Chromatin disruption in the promoter of human immunodeficiency virus type 1 during transcriptional activation. ['Verdin E', 'Paras P Jr', 'Van Lint C']. The EMBO journal. 1993 Aug. (8344262)
# 94. Hexamethylbisacetamide and disruption of human immunodeficiency virus type 1 latency in CD4(+) T cells. ['Choudhary SK', 'Archin NM', 'Margolis DM']. The Journal of infectious diseases. 2008 Apr 15. (18419522)
# 95. Genome-wide analysis of chromosomal features repressing human immunodeficiency virus transcription. ['Lewinski MK', 'Bisgrove D', 'Shinn P', 'Chen H', 'Hoffmann C', 'Hannenhalli S', 'Verdin E', 'Berry CC', 'Ecker JR', 'Bushman FD']. Journal of virology. 2005 Jun. (15890899)
# 96. Transcriptional interference antagonizes proviral gene expression to promote HIV latency. ['Lenasi T', 'Contreras X', 'Peterlin BM']. Cell host & microbe. 2008 Aug 14. (18692772)
# 97. Stochastic gene expression in a lentiviral positive-feedback loop: HIV-1 Tat fluctuations drive phenotypic diversity. ['Weinberger LS', 'Burnett JC', 'Toettcher JE', 'Arkin AP', 'Schaffer DV']. Cell. 2005 Jul 29. (16051143)
# 98. HIV latency. Proliferation of cells with HIV integrated into cancer genes contributes to persistent infection. ['Wagner TA', 'McLaughlin S', 'Garg K', 'Cheung CY', 'Larsen BB', 'Styrchak S', 'Huang HC', 'Edlefsen PT', 'Mullins JI', 'Frenkel LM']. Science (New York, N.Y.). 2014 Aug 1. (25011556)
# 99. A nonpromoting phorbol from the samoan medicinal plant Homalanthus nutans inhibits cell killing by HIV-1. ['Gustafson KR', 'Cardellina JH 2nd', 'McMahon JB', 'Gulakowski RJ', 'Ishitoya J', 'Szallasi Z', 'Lewin NE', 'Blumberg PM', 'Weislow OS', 'Beutler JA', 'et al.']. Journal of medicinal chemistry. 1992 May 29. (1597853)
# 100. Relationship between pre-existing viral reservoirs and the re-emergence of plasma viremia after discontinuation of highly active anti-retroviral therapy. ['Chun TW', 'Davey RT Jr', 'Ostrowski M', 'Shawn Justement J', 'Engel D', 'Mullins JI', 'Fauci AS']. Nature medicine. 2000 Jul. (10888923)
# 101. Transcriptional control of HIV latency: cellular signaling pathways, epigenetics, happenstance and the hope for a cure. ['Mbonye U', 'Karn J']. Virology. 2014 Apr. (24565118)
# 102. Histone deacetylase inhibitors impair the elimination of HIV-infected cells by cytotoxic T-lymphocytes. ['Jones RB', "O'Connor R", 'Mueller S', 'Foley M', 'Szeto GL', 'Karel D', 'Lichterfeld M', 'Kovacs C', 'Ostrowski MA', 'Trocha A', 'Irvine DJ', 'Walker BD']. PLoS pathogens. 2014 Aug. (25122219)
# 103. c-Myc and Sp1 contribute to proviral latency by recruiting histone deacetylase 1 to the human immunodeficiency virus type 1 promoter. ['Jiang G', 'Espeseth A', 'Hazuda DJ', 'Margolis DM']. Journal of virology. 2007 Oct. (17670825)
# 104. Effect of interleukin-2 on the pool of latently infected, resting CD4+ T cells in HIV-1-infected patients receiving highly active anti-retroviral therapy. ['Chun TW', 'Engel D', 'Mizell SB', 'Hallahan CW', 'Fischette M', 'Park S', 'Davey RT Jr', 'Dybul M', 'Kovacs JA', 'Metcalf JA', 'Mican JM', 'Berrey MM', 'Corey L', 'Lane HC', 'Fauci AS']. Nature medicine. 1999 Jun. (10371503)
